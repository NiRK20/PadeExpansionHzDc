# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import quad

# %%
def LCDM(z, theta):
    H0, Om = theta
    return H0*np.sqrt(Om*(1+z)**3+1-Om)

def Ez(z, theta):
    H0, Om = theta
    return np.sqrt(Om*(1+z)**3+1-Om)

def DcLCDM(z, theta):
    dc = np.zeros_like(z)

    ez = lambda z2, theta: 1/Ez(z2, theta)
    
    for i in range(len(z)):
        if i == 0:
            dc[i], _ = quad(ez, 0, z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
            if not np.isfinite(dc[i]):
                dc[i] = np.inf
        else:
            dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
            dc[i] = dc_aux + dc[i-1]
            if not np.isfinite(dc[i]):
                dc[i] = np.inf
    return (c/H0)*dc

# %%
def HzP11(z,theta):
    M, H0, q0, j0 = theta
    a0 = H0
    a1 = (0.5 * H0 * (2 -j0 + 4 * q0 + 3 * (q0 ** 2))) / (1 + q0)
    b1 = (0.5 * (-j0 + q0 ** 2)) / (1 + q0)
        
    H = (a0+a1*z)/(1+b1*z)

    return H

def DcModelP11(z,theta):#Integrando e substituindo
    M, H0, q0, j0 = theta
    a0 = H0
    a1 = (0.5 * H0 * (2 -j0 + 4 * q0 + 3 * (q0 ** 2))) / (1 + q0)
    b1 = (0.5 * (-j0 + q0 ** 2)) / (1 + q0)

    dc = ((1-(b1*a0)/a1)*np.log(np.abs((a0+a1*z)/a0))+b1*z)/a1

    return c*dc

def DcModelP11_num(z,theta):#Integrando e substituindo
    M, H0, q0, j0 = theta
    dc = np.zeros_like(z)
    
    ez = lambda z2, theta: H0/HzP11(z2, theta)
    
    for i in range(len(z)):
        if i == 0:
            dc[i], _ = quad(ez, 0, z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
            if not np.isfinite(dc[i]):
                dc[i] = np.inf
        else:
            dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
            dc[i] = dc_aux + dc[i-1]
            if not np.isfinite(dc[i]):
                dc[i] = np.inf
    return (c/H0)*dc

# %%
def HzP21(z,theta):
    M, H0, q0, j0, s0 = theta
    a0 = H0
    a1 = (H0*(7*j0*q0+6*j0-6*q0**2-6*q0**2+s0))/(3*(j0-q0**2))
    a2 = (H0*(3*j0**2+2*j0*q0**2+14*j0*q0+6*j0-3*q0**4-12*q0**3-6*q0**2+2*q0*s0+2*s0))/(6*(j0-q0**2))
    b1 = (4*j0*q0+3*j0-3*q0**3-3*q0**2+s0)/(3*(j0 - q0**2))
        
    H = (a0+a1*z+a2*z**2)/(1+b1*z)

    return H

#Distancia comovel adimensional

def DcModelP21_num(z,theta):#Integrando e substituindo
    M, H0, q0, j0, s0 = theta
    dc = np.zeros_like(z)
    a0 = H0
    a1 = (H0*(7*j0*q0+6*j0-6*q0**2-6*q0**2+s0))/(3*(j0-q0**2))
    a2 = (H0*(3*j0**2+2*j0*q0**2+14*j0*q0+6*j0-3*q0**4-12*q0**3-6*q0**2+2*q0*s0+2*s0))/(6*(j0-q0**2))
    b1 = (4*j0*q0+3*j0-3*q0**3-3*q0**2+s0)/(3*(j0 - q0**2))   

    ez = lambda z2, theta: H0/HzP21(z2, theta)
    
    for i in range(len(z)):
        if i == 0:
            dc[i], _ = quad(ez, 0, z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
            if not np.isfinite(dc[i]):
                dc[i] = np.inf
        else:
            dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
            dc[i] = dc_aux + dc[i-1]
            if not np.isfinite(dc[i]):
                dc[i] = np.inf
    return (c/H0)*dc

def DcModelP21(z,theta):#Integrando e substituindo
    M, H0, q0, j0, s0 = theta
    a0 = H0
    a1 = (H0*(7*j0*q0+6*j0-6*q0**2-6*q0**2+s0))/(3*(j0-q0**2))
    a2 = (H0*(3*j0**2+2*j0*q0**2+14*j0*q0+6*j0-3*q0**4-12*q0**3-6*q0**2+2*q0*s0+2*s0))/(6*(j0-q0**2))
    b1 = (4*j0*q0+3*j0-3*q0**3-3*q0**2+s0)/(3*(j0 - q0**2))   
        
    if (a1**2-4*a0*a2) > 0:
        r1 = (-a1 + np.sqrt(a1**2-4*a2*a0))/(2*a2)
        r2 = (-a1 - np.sqrt(a1**2-4*a2*a0))/(2*a2)

        dc = (((1+b1*r2)/(r2-r1))*np.log(np.abs((z-r2)/(-r2)))-((1+b1*r1)/(r2-r1))*np.log(np.abs((z-r1)/(-r1))))/a2
        
    elif (a1**2-4*a0*a2) == 0:
        dc = ((1 + (a1*b1)/(2*a2))*2*a2*z)/(a1*(a1/(2*a2) + z)) + (b1*np.log(2*np.abs((a2*(a1/(2*a2) + z))/a1)))/a2
        
    elif (a1**2-4*a0*a2) < 0:
        dc = (b1/(2*a2))*np.log(np.abs((a0+a1*z+a2*z**2)/a0)) + (((2*a2-b1*a1))/(a2*np.sqrt(4*a2*a0-a1**2)))*(np.arctan((2*a2*z+a1)/np.sqrt(4*a2*a0-a1**2)) - np.arctan(a1/np.sqrt(4*a2*a0-a1**2)))

    return c*dc

# %%
def HzP22(z, theta):
    M, H0, q0, j0, s0, l0 = theta
    a0 = H0
    a1 = 1/2 * H0 * ( ( 6 * j0 + ( 3 * ( j0 )**( 2 ) + ( 14 * j0 * q0 + ( -6 *(q0)**( 2 ) + ( 2 * j0 * ( q0 )**( 2 ) + ( -12 * ( q0 )**( 3 ) +
                    (-3 * ( q0 )**( 4 ) + ( 2 * s0 + 2 * q0 * s0 ) ) ) ) ) ) ) ) )**( -1 )* ( 24 * j0 + ( 8 * ( j0 )**( 2 ) + ( l0 + ( 84 * j0 * q0 +
                    10 * (j0 )**( 2 ) * q0 + ( l0 * q0 + ( -24 * ( q0 )**( 2 ) + ( 77 * j0 * (q0 )**( 2 ) + ( -72 * ( q0 )**( 3 ) + ( 15 * j0 * ( q0 )**( 3 ) +
                    (-63 * ( q0 )**( 4 ) + ( -15 * ( q0 )**( 5 ) + ( 12 * s0 + ( 2 * j0 *s0 + ( 23 * q0 * s0 + 9 * ( q0 )**( 2 ) * s0 ) ) ) ) ) ) ) ) ) ) ) ) ))
    a2 = 1/12 * H0 * ( ( 6 * j0 + ( 3 * ( j0 )**( 2 ) + ( 14 * j0 * q0 + ( -6 *( q0 )**( 2 ) + ( 2 * j0 * ( q0 )**( 2 ) + ( -12 * ( q0 )**( 3 ) +
                    (-3 * ( q0 )**( 4 ) + ( 2 * s0 + 2 * q0 * s0 ) ) ) ) ) ) ) ) )**( -1 )* ( 72 * j0 + ( 48 * ( j0 )**( 2 ) + ( 30 * ( j0 )**( 3 ) +
                    ( 6 * l0 +( -3 * j0 * l0 + ( 336 * j0 * q0 + ( 120 * ( j0 )**( 2 ) * q0 + ( 12 *l0 * q0 + ( -72 * ( q0 )**( 2 ) + ( 462 * j0 * ( q0 )**( 2 )+
                    ( -5 * ( j0 )**( 2 ) * ( q0 )**( 2 ) + ( 9 * l0 * ( q0 )**( 2 ) + ( -288 * (q0 )**( 3 ) + ( 180 * j0 * ( q0 )**( 3 ) + ( -378 * ( q0 )**( 4 )+
                    (60 * j0 * ( q0 )**( 4 ) + ( -180 * ( q0 )**( 5 ) + ( -45 * ( q0 )**(6) + ( 48 * s0 + ( 24 * j0 * s0 + ( 138 * q0 * s0 + ( 35 * j0 * q0 *s0 +
                    ( 108 * ( q0 )**( 2 ) * s0 + ( 15 * ( q0 )**( 3 ) * s0 + 4 * (s0 )**( 2 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    b1 = 1/2 * ( ( 6 * j0 + ( 3 * ( j0 )**( 2 ) + ( 14 * j0 * q0 + ( -6 * ( q0)**( 2 ) + ( 2 * j0 * ( q0 )**( 2 ) + ( -12 * ( q0 )**( 3 ) + ( -3 * (q0 )**( 4 ) +
                ( 2 * s0 + 2 * q0 * s0 ) ) ) ) ) ) ) ) )**( -1 ) * ( 12* j0 + ( 2 * ( j0 )**( 2 ) + ( l0 + ( 44 * j0 * q0 + ( 4 * ( j0 )**(2 ) * q0 + ( l0 * q0 +
                ( -12 * ( q0 )**( 2 ) + ( 45 * j0 * ( q0 )**(2 ) + ( -36 * ( q0 )**( 3 ) + ( 11 * j0 * ( q0 )**( 3 ) + ( -33 * (q0 )**( 4 ) + ( -9 * ( q0 )**( 5 ) +
                ( 8 * s0 + ( 2 * j0 * s0 + ( 15 * q0 * s0 + 5 * ( q0 )**( 2 ) * s0 ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    b2 = ( ( -72 * j0 + ( -36 * ( j0 )**( 2 ) + ( -168 * j0 * q0 + ( 72 * ( q0)**( 2 ) + ( -24 * j0 * ( q0 )**( 2 ) + ( 144 * ( q0 )**( 3 ) + ( 36 *( q0 )**( 4 ) +
        ( -24 * s0 + -24 * q0 * s0)))))))))**( -1 )*( -12 * ( j0 )**( 3 ) + ( 3 * j0 * l0 + ( 23 * ( j0 )**( 2 ) * ( q0 )**(2 ) + ( -3 * l0 * ( q0 )**( 2 ) +
        ( -24 * j0 * ( q0 )**( 4 ) + ( 9 * (q0 )**( 6 ) + ( -11 * j0 * q0 * s0 + ( 3 * ( q0 )**( 3 ) * s0 + -4 * (s0 )**( 2 ) ) ) ) ) ) ) ) )
        
    H = (a0+a1*z+a2*z**2)/(1+b1*z+b2*z**2)

    return H

def DcModelP22(z, theta):#Integrando e substituindo
    M, H0, q0, j0, s0, l0 = theta
    a0 = H0
    a1 = 1/2 * H0 * ( ( 6 * j0 + ( 3 * ( j0 )**( 2 ) + ( 14 * j0 * q0 + ( -6 *(q0)**( 2 ) + ( 2 * j0 * ( q0 )**( 2 ) + ( -12 * ( q0 )**( 3 ) +
                    (-3 * ( q0 )**( 4 ) + ( 2 * s0 + 2 * q0 * s0 ) ) ) ) ) ) ) ) )**( -1 )* ( 24 * j0 + ( 8 * ( j0 )**( 2 ) + ( l0 + ( 84 * j0 * q0 +
                    10 * (j0 )**( 2 ) * q0 + ( l0 * q0 + ( -24 * ( q0 )**( 2 ) + ( 77 * j0 * (q0 )**( 2 ) + ( -72 * ( q0 )**( 3 ) + ( 15 * j0 * ( q0 )**( 3 ) +
                    (-63 * ( q0 )**( 4 ) + ( -15 * ( q0 )**( 5 ) + ( 12 * s0 + ( 2 * j0 *s0 + ( 23 * q0 * s0 + 9 * ( q0 )**( 2 ) * s0 ) ) ) ) ) ) ) ) ) ) ) ) ))
    a2 = 1/12 * H0 * ( ( 6 * j0 + ( 3 * ( j0 )**( 2 ) + ( 14 * j0 * q0 + ( -6 *( q0 )**( 2 ) + ( 2 * j0 * ( q0 )**( 2 ) + ( -12 * ( q0 )**( 3 ) +
                    (-3 * ( q0 )**( 4 ) + ( 2 * s0 + 2 * q0 * s0 ) ) ) ) ) ) ) ) )**( -1 )* ( 72 * j0 + ( 48 * ( j0 )**( 2 ) + ( 30 * ( j0 )**( 3 ) +
                    ( 6 * l0 +( -3 * j0 * l0 + ( 336 * j0 * q0 + ( 120 * ( j0 )**( 2 ) * q0 + ( 12 *l0 * q0 + ( -72 * ( q0 )**( 2 ) + ( 462 * j0 * ( q0 )**( 2 )+
                    ( -5 * ( j0 )**( 2 ) * ( q0 )**( 2 ) + ( 9 * l0 * ( q0 )**( 2 ) + ( -288 * (q0 )**( 3 ) + ( 180 * j0 * ( q0 )**( 3 ) + ( -378 * ( q0 )**( 4 )+
                    (60 * j0 * ( q0 )**( 4 ) + ( -180 * ( q0 )**( 5 ) + ( -45 * ( q0 )**(6) + ( 48 * s0 + ( 24 * j0 * s0 + ( 138 * q0 * s0 + ( 35 * j0 * q0 *s0 +
                    ( 108 * ( q0 )**( 2 ) * s0 + ( 15 * ( q0 )**( 3 ) * s0 + 4 * (s0 )**( 2 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    b1 = 1/2 * ( ( 6 * j0 + ( 3 * ( j0 )**( 2 ) + ( 14 * j0 * q0 + ( -6 * ( q0)**( 2 ) + ( 2 * j0 * ( q0 )**( 2 ) + ( -12 * ( q0 )**( 3 ) + ( -3 * (q0 )**( 4 ) +
                ( 2 * s0 + 2 * q0 * s0 ) ) ) ) ) ) ) ) )**( -1 ) * ( 12* j0 + ( 2 * ( j0 )**( 2 ) + ( l0 + ( 44 * j0 * q0 + ( 4 * ( j0 )**(2 ) * q0 + ( l0 * q0 +
                ( -12 * ( q0 )**( 2 ) + ( 45 * j0 * ( q0 )**(2 ) + ( -36 * ( q0 )**( 3 ) + ( 11 * j0 * ( q0 )**( 3 ) + ( -33 * (q0 )**( 4 ) + ( -9 * ( q0 )**( 5 ) +
                ( 8 * s0 + ( 2 * j0 * s0 + ( 15 * q0 * s0 + 5 * ( q0 )**( 2 ) * s0 ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    b2 = ( ( -72 * j0 + ( -36 * ( j0 )**( 2 ) + ( -168 * j0 * q0 + ( 72 * ( q0)**( 2 ) + ( -24 * j0 * ( q0 )**( 2 ) + ( 144 * ( q0 )**( 3 ) + ( 36 *( q0 )**( 4 ) +
        ( -24 * s0 + -24 * q0 * s0)))))))))**( -1 )*( -12 * ( j0 )**( 3 ) + ( 3 * j0 * l0 + ( 23 * ( j0 )**( 2 ) * ( q0 )**(2 ) + ( -3 * l0 * ( q0 )**( 2 ) +
        ( -24 * j0 * ( q0 )**( 4 ) + ( 9 * (q0 )**( 6 ) + ( -11 * j0 * q0 * s0 + ( 3 * ( q0 )**( 3 ) * s0 + -4 * (s0 )**( 2 ) ) ) ) ) ) ) ) )

    if (a1**2-4*a0*a2) > 0:
        r1 = (-a1 + np.sqrt(a1**2-4*a2*a0))/(2*a2)
        r2 = (-a1 - np.sqrt(a1**2-4*a2*a0))/(2*a2)
        dc = (((1 + b1*r2 + b2*r2**2)/(r2 - r1))*np.log(np.abs((z - r2)/(-r2))) - ((1 + b1*r1 + b2*r1**2)/(r2 - r1))*np.log(np.abs((z-r1)/(-r1))) + b2*z)/a2
        
    elif (a1**2-4*a0*a2) == 0:
        dc = ((b1 + 2*r*b2)*np.log(np.abs((z-r)/r)) + ((1+b1*r-b2*r)*z)/((z-r)*r) +b2*z)/a2
        
    elif (a1**2-4*a0*a2) < 0:
        dc = (((np.sqrt(4*a0*a2 - a1**2) * ((4*a0*a2 - 2*a1**2)*b2 + 2*a1*a2*b1 - 4*a2**2) * np.arctan(a1 / np.sqrt(4*a0*a2 - a1**2))) + (np.log(np.abs(a0)) * ((4*a0*a1*a2 - a1**3)*b2 + (a1**2*a2 - 4*a0*a2**2)*b1)) ) - ( (((4*a0*a1*a2 - a1**3)*b2 + (a1**2*a2 - 4*a0*a2**2)*b1) * np.log(np.abs(a2*z**2 + a1*z + a0))) + (np.sqrt(4*a0*a2 - a1**2) * (((2*a0*a2 - a1**2)*b2 + a1*a2*b1 - 2*a2**2) * np.arctan((2*a2*z + a1) / np.sqrt(4*a0*a2 - a1**2)) + ((a1**2 - 2*a0*a2)*b2 - a1*a2*b1 + 2*a2**2) * np.arctan2(2*a2*z + a1, -np.sqrt(4*a0*a2 - a1**2)) + np.pi * ((a1**2 - 2*a0*a2)*b2 - a1*a2*b1 + 2*a2**2))) + ((2*a1**2*a2 - 8*a0*a2**2) * b2 * z)))/(8*a0*a2**3 - 2*a1**2*a2**2)

    return c*dc

def DcModelP22_num(z,theta):#Integrando e substituindo
    M, H0, q0, j0, s0, l0 = theta
    dc = np.zeros_like(z)
    
    ez = lambda z2, theta: H0/HzP22(z2, theta)
    
    for i in range(len(z)):
        if i == 0:
            dc[i], _ = quad(ez, 0, z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
            if not np.isfinite(dc[i]):
                dc[i] = np.inf
        else:
            dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
            dc[i] = dc_aux + dc[i-1]
            if not np.isfinite(dc[i]):
                dc[i] = np.inf
    return (c/H0)*dc

# %%
def HzP31(z, theta):
    M, H0, q0, j0, s0, l0 = theta
    a0 = H0
    a1 = (-0.25 * H0 * (-24 * j0 + 4 * (j0 ** 2) -l0 -60 * j0 * q0 + 24 * (q0 **2) -41 * j0 * (q0 ** 2) + 48 * (q0 ** 3) + 27 * (q0 ** 4) -
                        12 * s0-11 * q0 * s0)) / (3 * j0 + 4 * j0 * q0 -3 * (q0 ** 2) -3 * (q0 ** 3)+ s0)
    a2 = (0.25 * H0 * (12 * j0 + 2 * (j0 ** 2) + l0 + 44 * j0 * q0 + 4 * (j0 **2) * q0 + l0 * q0 -12 * (q0 ** 2) + 45 * j0 * (q0 ** 2) -36 * (q0 **3) +
                       11 * j0 * (q0 ** 3) -33 * (q0 ** 4) -9 * (q0 ** 5) + 8 * s0 + 2 * j0 * s0 + 15 * q0 * s0 + 5 * (q0 ** 2) * s0)) / (3 * j0 + 4 * j0 * q0-
                        3 * (q0 ** 2) -3 * (q0 ** 3) + s0)
    a3 = (-0.04166666666666667 * H0 * (12 * (j0 ** 3) -3 * j0 * l0 -23 * (j0 **2) * (q0 ** 2) + 3 * l0 * (q0 ** 2) + 24 * j0 * (q0 ** 4) -9 * (q0 **6) + 
        11 * j0 * q0 * s0 -3 * (q0 ** 3) * s0 + 4 * (s0 ** 2))) / (3 *j0 + 4 * j0 * q0 -3 * (q0 ** 2) -3 * (q0 ** 3) + s0)
    b1 = (0.25 * (12 * j0 -4 * (j0 ** 2) + l0 + 32 * j0 * q0 -12 * (q0 ** 2) +25 * j0 * (q0 ** 2) -24 * (q0 ** 3) -15 * (q0 ** 4) + 8 * s0 + 7 * q0* s0)) / (3*j0+
        4 * j0 * q0 -3 * (q0 ** 2) -3 * (q0 ** 3) + s0)

    H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)

    return H

def EzP31(z, theta):
    M, H0, q0, j0, s0, l0 = theta
    a0 = H0
    a1 = (-0.25 * H0 * (-24 * j0 + 4 * (j0 ** 2) -l0 -60 * j0 * q0 + 24 * (q0 **2) -41 * j0 * (q0 ** 2) + 48 * (q0 ** 3) + 27 * (q0 ** 4) -
                        12 * s0-11 * q0 * s0)) / (3 * j0 + 4 * j0 * q0 -3 * (q0 ** 2) -3 * (q0 ** 3)+ s0)
    a2 = (0.25 * H0 * (12 * j0 + 2 * (j0 ** 2) + l0 + 44 * j0 * q0 + 4 * (j0 **2) * q0 + l0 * q0 -12 * (q0 ** 2) + 45 * j0 * (q0 ** 2) -36 * (q0 **3) +
                       11 * j0 * (q0 ** 3) -33 * (q0 ** 4) -9 * (q0 ** 5) + 8 * s0 + 2 * j0 * s0 + 15 * q0 * s0 + 5 * (q0 ** 2) * s0)) / (3 * j0 + 4 * j0 * q0-
                        3 * (q0 ** 2) -3 * (q0 ** 3) + s0)
    a3 = (-0.04166666666666667 * H0 * (12 * (j0 ** 3) -3 * j0 * l0 -23 * (j0 **2) * (q0 ** 2) + 3 * l0 * (q0 ** 2) + 24 * j0 * (q0 ** 4) -9 * (q0 **6) + 
        11 * j0 * q0 * s0 -3 * (q0 ** 3) * s0 + 4 * (s0 ** 2))) / (3 *j0 + 4 * j0 * q0 -3 * (q0 ** 2) -3 * (q0 ** 3) + s0)
    b1 = (0.25 * (12 * j0 -4 * (j0 ** 2) + l0 + 32 * j0 * q0 -12 * (q0 ** 2) +25 * j0 * (q0 ** 2) -24 * (q0 ** 3) -15 * (q0 ** 4) + 8 * s0 + 7 * q0* s0)) / (3*j0+
        4 * j0 * q0 -3 * (q0 ** 2) -3 * (q0 ** 3) + s0)

    H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)

    return H/H0

#Distancia comovel adimensional
def DcModelP31(z,theta):#Integrando e substituindo
    M, H0, q0, j0, s0, l0 = theta
    dc = np.zeros_like(z)
    
    ez = lambda z2, theta: 1/EzP31(z2, theta)
    
    for i in range(len(z)):
        if i == 0:
            dc[i], _ = quad(ez, 0, z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
            if not np.isfinite(dc[i]):
                dc[i] = np.inf
        else:
            dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
            dc[i] = dc_aux + dc[i-1]
            if not np.isfinite(dc[i]):
                dc[i] = np.inf
    return (c/H0)*dc

# %%
M = -19
Om = 0.3
H0 = 73
q0 = -0.55
j0 = 1
s0 = -0.35
l0 = 1
c = 299792.458#km/s
z = np.linspace(0,2.5, 200)

# %%
a0 = H0
a1 = 1/2 * H0 * ( ( 6 * j0 + ( 3 * ( j0 )**( 2 ) + ( 14 * j0 * q0 + ( -6 *(q0)**( 2 ) + ( 2 * j0 * ( q0 )**( 2 ) + ( -12 * ( q0 )**( 3 ) +
                    (-3 * ( q0 )**( 4 ) + ( 2 * s0 + 2 * q0 * s0 ) ) ) ) ) ) ) ) )**( -1 )* ( 24 * j0 + ( 8 * ( j0 )**( 2 ) + ( l0 + ( 84 * j0 * q0 +
                    10 * (j0 )**( 2 ) * q0 + ( l0 * q0 + ( -24 * ( q0 )**( 2 ) + ( 77 * j0 * (q0 )**( 2 ) + ( -72 * ( q0 )**( 3 ) + ( 15 * j0 * ( q0 )**( 3 ) +
                    (-63 * ( q0 )**( 4 ) + ( -15 * ( q0 )**( 5 ) + ( 12 * s0 + ( 2 * j0 *s0 + ( 23 * q0 * s0 + 9 * ( q0 )**( 2 ) * s0 ) ) ) ) ) ) ) ) ) ) ) ) ))
a2 = 1/12 * H0 * ( ( 6 * j0 + ( 3 * ( j0 )**( 2 ) + ( 14 * j0 * q0 + ( -6 *( q0 )**( 2 ) + ( 2 * j0 * ( q0 )**( 2 ) + ( -12 * ( q0 )**( 3 ) +
                    (-3 * ( q0 )**( 4 ) + ( 2 * s0 + 2 * q0 * s0 ) ) ) ) ) ) ) ) )**( -1 )* ( 72 * j0 + ( 48 * ( j0 )**( 2 ) + ( 30 * ( j0 )**( 3 ) +
                    ( 6 * l0 +( -3 * j0 * l0 + ( 336 * j0 * q0 + ( 120 * ( j0 )**( 2 ) * q0 + ( 12 *l0 * q0 + ( -72 * ( q0 )**( 2 ) + ( 462 * j0 * ( q0 )**( 2 )+
                    ( -5 * ( j0 )**( 2 ) * ( q0 )**( 2 ) + ( 9 * l0 * ( q0 )**( 2 ) + ( -288 * (q0 )**( 3 ) + ( 180 * j0 * ( q0 )**( 3 ) + ( -378 * ( q0 )**( 4 )+
                    (60 * j0 * ( q0 )**( 4 ) + ( -180 * ( q0 )**( 5 ) + ( -45 * ( q0 )**(6) + ( 48 * s0 + ( 24 * j0 * s0 + ( 138 * q0 * s0 + ( 35 * j0 * q0 *s0 +
                    ( 108 * ( q0 )**( 2 ) * s0 + ( 15 * ( q0 )**( 3 ) * s0 + 4 * (s0 )**( 2 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
b1 = 1/2 * ( ( 6 * j0 + ( 3 * ( j0 )**( 2 ) + ( 14 * j0 * q0 + ( -6 * ( q0)**( 2 ) + ( 2 * j0 * ( q0 )**( 2 ) + ( -12 * ( q0 )**( 3 ) + ( -3 * (q0 )**( 4 ) +
                ( 2 * s0 + 2 * q0 * s0 ) ) ) ) ) ) ) ) )**( -1 ) * ( 12* j0 + ( 2 * ( j0 )**( 2 ) + ( l0 + ( 44 * j0 * q0 + ( 4 * ( j0 )**(2 ) * q0 + ( l0 * q0 +
                ( -12 * ( q0 )**( 2 ) + ( 45 * j0 * ( q0 )**(2 ) + ( -36 * ( q0 )**( 3 ) + ( 11 * j0 * ( q0 )**( 3 ) + ( -33 * (q0 )**( 4 ) + ( -9 * ( q0 )**( 5 ) +
                ( 8 * s0 + ( 2 * j0 * s0 + ( 15 * q0 * s0 + 5 * ( q0 )**( 2 ) * s0 ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
b2 = ( ( -72 * j0 + ( -36 * ( j0 )**( 2 ) + ( -168 * j0 * q0 + ( 72 * ( q0)**( 2 ) + ( -24 * j0 * ( q0 )**( 2 ) + ( 144 * ( q0 )**( 3 ) + ( 36 *( q0 )**( 4 ) +
        ( -24 * s0 + -24 * q0 * s0)))))))))**( -1 )*( -12 * ( j0 )**( 3 ) + ( 3 * j0 * l0 + ( 23 * ( j0 )**( 2 ) * ( q0 )**(2 ) + ( -3 * l0 * ( q0 )**( 2 ) +
        ( -24 * j0 * ( q0 )**( 4 ) + ( 9 * (q0 )**( 6 ) + ( -11 * j0 * q0 * s0 + ( 3 * ( q0 )**( 3 ) * s0 + -4 * (s0 )**( 2 ) ) ) ) ) ) ) ) )

print(a1**2 - 4*a0*a2)
# Out:
# -11255.096536895697

# %%
plt.plot(z, LCDM(z, [H0, Om]), label="LCDM")
plt.plot(z, HzP11(z, [M, H0, q0, j0]), label="P11")
plt.plot(z, HzP21(z, [M, H0, q0, j0, s0]), label="P21")
plt.plot(z, HzP22(z, [M, H0, q0, j0, s0, l0]), label="P22")
plt.plot(z, HzP31(z, [M, H0, q0, j0, s0, l0]), label="P31")
plt.legend()
plt.xlim(0,2.5)
plt.ylim(0,400)
plt.xlabel('z')
plt.ylabel('H(z)')
#plt.savefig('HzTeste_NoP22.jpg')
plt.show()

# %%
plt.plot(z, DcLCDM(z, [H0, Om]), label="LCDM")
plt.plot(z, DcModelP11(z, [M, H0, q0, j0]), label="P11")
#plt.plot(z, DcModelP11_num(z, [M, H0, q0, j0]), label="P11_num")
plt.plot(z, DcModelP21(z, [M, H0, q0, j0, s0]), label="P21")
#plt.plot(z, DcModelP21_num(z, [M, H0, q0, j0, s0]), label="P21_num")
plt.plot(z, DcModelP22(z, [M, H0, q0, j0, s0, l0]), label="P22")
plt.plot(z, DcModelP22_num(z, [M, H0, q0, j0, s0, l0]), label="P22_num")
plt.plot(z, DcModelP31(z, [M, H0, q0, j0, s0, l0]), label="P31")
plt.legend()
plt.xlim(0,2.5)
plt.xlabel('z')
plt.ylabel('Dc(z)')
#plt.savefig('DcTeste_certo.jpg')
plt.show()

# %%
plt.plot(z, DcLCDM(z, [H0, Om]), label="LCDM")
plt.plot(z, DcModelP21(z, [M, H0, q0, j0]), label="P21")
plt.plot(z, DcModelP22(z, [M, H0, q0, j0, s0]), label="P22")
plt.plot(z, DcModelP31(z, [M, H0, q0, j0, s0]), label="P31")
plt.legend()
plt.xlim(0,2.5)
plt.ylim(0, 120)
plt.xlabel('z')
plt.ylabel('Dc(z)')
plt.savefig('DcTeste_certo_num.jpg')
plt.show()
# Out:
# /tmp/ipykernel_35616/4068201035.py:55: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(ez, 0, z[i], args=(theta))
# /tmp/ipykernel_35616/4068201035.py:55: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(ez, 0, z[i], args=(theta))
# /tmp/ipykernel_35616/4068201035.py:55: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
# ...

# %%
print(LCDM(2, [H0, Om]))
print(HzP21(2, [M, H0, q0, j0]))
print(HzP22(2, [M, H0, q0, j0, s0]))
print(HzP31(2, [M, H0, q0, j0, s0]))
# Out:
# 216.55299582319333
# 157.24445858625418
# 19.201249876560638
# 240.63306959631166

# %%
print(DcLCDM([2], [H0, Om]))
print(DcModelP21(2, [M, H0, q0, j0]))
print(DcModelP22(2, [M, H0, q0, j0, s0]))
print(DcModelP31([2], [M, H0, q0, j0, s0]))
# Out:
# [219]
# 1.3445910723112995
# 2.7440561982455782
# [219]
