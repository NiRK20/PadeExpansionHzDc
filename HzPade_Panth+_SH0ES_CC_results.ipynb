# %%
from getdist import loadMCSamples, plots
import matplotlib.pyplot as plt

# %%
def MCResult_cobaya(gdsamples, file):
    stats = gdsamples.getMargeStats()

    for par in stats.names[:gdsamples.samples.shape[1]-2]:
        par_stats = stats.parWithName(par.name)
        mean = par_stats.mean

        # Erros de 1-sigma (68% CL)
        lower_1s = par_stats.limits[0].lower
        upper_1s = par_stats.limits[0].upper
        err_plus_1s = upper_1s - mean
        err_minus_1s = mean - lower_1s

        # Erros de 2-sigma (95% CL)
        lower_2s = par_stats.limits[1].lower
        upper_2s = par_stats.limits[1].upper
        err_plus_2s = upper_2s - mean
        err_minus_2s = mean - lower_2s
            
        label = f"{par.name}"
            
        print(f"{label} = {mean:.4f} +{err_plus_1s:.4f} +{err_plus_2s:.4f} -{err_plus_1s:.4f} -{err_plus_2s:.4f}")

    with open(file, 'r') as f:
        lines = f.readlines()
        logz = float(lines[1].replace("logZ: ", ""))
        std = float(lines[2].replace("logZstd: ", ""))
        print("\nEvidência Bayesiana:")
        print(f"logZ = {logz:.3f} +/- {std:.3f}")

# %% [markdown]
# ## P21

# %% [markdown]
# ### CC+SH0ES+Pantheon+

# %%
samplesPSHz_21 = loadMCSamples("chains/P21/PSHz_21")
# Out:
# WARNING:root:outlier fraction 0.12452591656131479
# chains/P21/PSHz_21.1.txt
# Removed no burn in

# %%
MCResult_cobaya(samplesPSHz_21, "chains/P21/PSHz_21.logZ")
# Out:
# M = -19.2547 +0.0289 +0.0517 -0.0289 -0.0517
# h0 = 73.2759 +0.9829 +1.8210 -0.9829 -1.8210
# q0 = -0.5720 +0.0718 +0.1556 -0.0718 -0.1556
# j0 = 2.2075 +0.5458 +0.9813 -0.5458 -0.9813
#
# Evidência Bayesiana:
# logZ = -752.131 +/- 0.365

# %%
gPSHz21 = plots.getSubplotPlotter()
gPSHz21.triangle_plot([samplesPSHz_21], ["h0", "q0", "j0"], filled=False, legend_labels=["CC+SH0ES+Pantheon+"])
plt.show()

# %% [markdown]
# ### CC+Pantheon+

# %%
samplesPPHz_21 = loadMCSamples("chains/P21/PPHz_21")
# Out:
# WARNING:root:outlier fraction 0.15616438356164383
# chains/P21/PPHz_21.1.txt
# Removed no burn in

# %%
MCResult_cobaya(samplesPPHz_21, "chains/P21/PPHz_21.logZ")
# Out:
# WARNING:root:auto bandwidth for M very small or failed (h=0.000698961610242407,N_eff=483.15062763900437). Using fallback (h=0.1091994775978896)
# M = 0.7220 +18.7780 +18.7780 -18.7780 -18.7780
# h0 = 69.1401 +3.6965 +7.1009 -3.6965 -7.1009
# q0 = -0.5875 +0.0759 +0.1538 -0.0759 -0.1538
# j0 = 2.3969 +0.5845 +1.0437 -0.5845 -1.0437
#
# Evidência Bayesiana:
# logZ = -717.743 +/- 0.227

# %%
gPPHz21 = plots.getSubplotPlotter()
gPPHz21.triangle_plot([samplesPPHz_21], ["h0", "q0", "j0"], filled=False, legend_labels=["CC+Pantheon+"])
plt.show()

# %%
gPSPPHz21 = plots.getSubplotPlotter()
gPSPPHz21.triangle_plot([samplesPSHz_21, samplesPPHz_21], ["h0", "q0", "j0"], filled=False, legend_labels=["CC+SH0ES+Pantheon+", "CC+Pantheon+"])
plt.show()

# %% [markdown]
# ## P22

# %% [markdown]
# ### CC+SH0ES+Pantheon+

# %%
samplesPSHz_22 = loadMCSamples("chains/P22/PS/PSHz_22")
logzPS22 = "chains/P22/PS/PSHz_22.logZ"
# Out:
# chains/P22/PS/PSHz_22.1.txt
# Removed no burn in

# %%
MCResult_cobaya(samplesPSHz_22, logzPS22)
# Out:
# WARNING:root:fine_bins not large enough to well sample smoothing scale - j0
# WARNING:root:fine_bins not large enough to well sample smoothing scale - s0
# M = -19.2581 +0.0295 +0.0576 -0.0295 -0.0576
# h0 = 72.6310 +1.0196 +2.0274 -1.0196 -2.0274
# q0 = -0.3259 +0.0388 +0.0963 -0.0388 -0.0963
# j0 = 0.3102 +0.0578 +0.0716 -0.0578 -0.0716
# s0 = -0.0152 +0.0844 +0.1604 -0.0844 -0.1604
#
# Evidência Bayesiana:
# logZ = -759.539 +/- 0.209

# %%
gPSHz22 = plots.getSubplotPlotter()
gPSHz22.triangle_plot([samplesPSHz_22], ["h0", "q0", "j0", "s0"], filled=False, legend_labels=["CC+SH0ES+Pantheon+"])
plt.show()
# Out:
# WARNING:root:fine_bins not large enough to well sample smoothing scale - j0
# WARNING:root:fine_bins not large enough to well sample smoothing scale - s0
# WARNING:root:fine_bins_2D not large enough for optimal density: j0, s0

# %% [markdown]
# ### CC+Pantheon+

# %%
samplesPPHz_22 = loadMCSamples("chains/P22/PPHz_22")
logzPP22 = "chains/P22/PPHz_22.logZ"

# %%
MCResult_cobaya(samplesPPHz_22, logzPP22)
# Out:
# WARNING:root:auto bandwidth for j0 very small or failed (h=0.0005174141604785151,N_eff=1258.6923701857231). Using fallback (h=0.000757173207593503)
# WARNING:root:fine_bins not large enough to well sample smoothing scale - j0
# WARNING:root:auto bandwidth for s0 very small or failed (h=0.0008904180238195829,N_eff=1258.6923701857231). Using fallback (h=0.0011369004376084138)
# M = -0.0310 +19.5310 +19.5310 -19.5310 -19.5310
# h0 = 64.7194 +3.8405 +10.4194 -3.8405 -10.4194
# q0 = -0.2947 +0.0855 +0.1821 -0.0855 -0.1821
# j0 = 0.5343 +-0.1618 +2.9809 --0.1618 -2.9809
# s0 = 0.4178 +-0.3619 +7.9997 --0.3619 -7.9997
#
# Evidência Bayesiana:
# logZ = -722.595 +/- 0.331

# %%
gPPHz22 = plots.getSubplotPlotter()
gPPHz22.triangle_plot([samplesPPHz_22], ["h0", "q0", "j0", "s0"], filled=False, legend_labels=["CC+Pantheon+"])
plt.show()
# Out:
# WARNING:root:auto bandwidth for j0 very small or failed (h=0.0005174141604785151,N_eff=1258.6923701857231). Using fallback (h=0.000757173207593503)
# WARNING:root:fine_bins not large enough to well sample smoothing scale - j0
# WARNING:root:auto bandwidth for s0 very small or failed (h=0.0008904180238195829,N_eff=1258.6923701857231). Using fallback (h=0.0011369004376084138)
# WARNING:root:fine_bins_2D not large enough for optimal density: h0, j0
# WARNING:root:fine_bins_2D not large enough for optimal density: h0, s0
# WARNING:root:fine_bins_2D not large enough for optimal density: q0, j0
