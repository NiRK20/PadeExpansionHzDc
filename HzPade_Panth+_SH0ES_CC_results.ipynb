# %%
from getdist import loadMCSamples, plots
import matplotlib.pyplot as plt

# %%
def MCResult_cobaya(gdsamples, file):
    stats = gdsamples.getMargeStats()

    for par in stats.names[:gdsamples.samples.shape[1]-2]:
        par_stats = stats.parWithName(par.name)
        mean = par_stats.mean

        # Erros de 1-sigma (68% CL)
        lower_1s = par_stats.limits[0].lower
        upper_1s = par_stats.limits[0].upper
        err_plus_1s = upper_1s - mean
        err_minus_1s = mean - lower_1s

        # Erros de 2-sigma (95% CL)
        lower_2s = par_stats.limits[1].lower
        upper_2s = par_stats.limits[1].upper
        err_plus_2s = upper_2s - mean
        err_minus_2s = mean - lower_2s
            
        label = f"{par.name}"
            
        print(f"{label} = {mean:.4f} +{err_plus_1s:.4f} +{err_plus_2s:.4f} -{err_plus_1s:.4f} -{err_plus_2s:.4f}")

    with open(file, 'r') as f:
        lines = f.readlines()
        logz = float(lines[1].replace("logZ: ", ""))
        std = float(lines[2].replace("logZstd: ", ""))
        print("\nEvidência Bayesiana:")
        print(f"logZ = {logz:.3f} +/- {std:.3f}")

# %% [markdown]
# ## P21

# %% [markdown]
# ### CC+SH0ES+Pantheon+

# %%
samplesPSHz_21 = loadMCSamples("chains/P21/PS/PSHz_21")
# Out:
# WARNING:root:outlier fraction 0.0009315323707498836
# chains/P21/PS/PSHz_21.1.txt
# Removed no burn in

# %%
MCResult_cobaya(samplesPSHz_21, "chains/P21/PS/PSHz_21.logZ")
# Out:
# M = -19.2548 +0.0291 +0.0525 -0.0291 -0.0525
# H0 = 73.1908 +0.9386 +1.8174 -0.9386 -1.8174
# q0 = 0.2204 +1.0536 +1.0836 -1.0536 -1.0836
# j0 = 0.8508 +0.3164 +0.4154 -0.3164 -0.4154
# s0 = 0.7057 +1.2943 +1.2943 -1.2943 -1.2943
#
# Evidência Bayesiana:
# logZ = -754.089 +/- 0.278

# %%
gPSHz21 = plots.getSubplotPlotter()
gPSHz21.triangle_plot([samplesPSHz_21], ["H0", "q0", "j0", "s0"], filled=False, legend_labels=["CC+SH0ES+Pantheon+"])
plt.savefig('P21_PS_s0_2.pdf')
plt.show()
# Out:
# WARNING:root:fine_bins_2D not large enough for optimal density: q0, j0

# %%
#Velho
MCResult_cobaya(samplesPSHz_21, "chains/P21/PS/PSHz_21.logZ")
# Out:
# M = -19.2534 +0.0282 +0.0531 -0.0282 -0.0531
# h0 = 73.3197 +0.9013 +1.9061 -0.9013 -1.9061
# q0 = -0.5736 +0.0639 +0.1374 -0.0639 -0.1374
# j0 = 2.2200 +0.4913 +0.8979 -0.4913 -0.8979
#
# Evidência Bayesiana:
# logZ = -752.126 +/- 0.261

# %%
gPSHz21 = plots.getSubplotPlotter()
gPSHz21.triangle_plot([samplesPSHz_21], ["h0", "q0", "j0"], filled=False, legend_labels=["CC+SH0ES+Pantheon+"])
plt.show()

# %% [markdown]
# ### CC+Pantheon+

# %%
samplesPPHz_21 = loadMCSamples("chains/P21/PP/PPHz_21")
# Out:
# chains/P21/PP/PPHz_21.1.txt
# Removed no burn in

# %%
MCResult_cobaya(samplesPPHz_21, "chains/P21/PP/PPHz_21.logZ")
# Out:
# M = 0.3684 +19.1316 +19.1316 -19.1316 -19.1316
# h0 = 68.9453 +3.6646 +7.3884 -3.6646 -7.3884
# q0 = -0.5918 +0.0704 +0.1560 -0.0704 -0.1560
# j0 = 2.4351 +0.5493 +0.9654 -0.5493 -0.9654
#
# Evidência Bayesiana:
# logZ = -717.532 +/- 0.158

# %%
gPPHz21 = plots.getSubplotPlotter()
gPPHz21.triangle_plot([samplesPPHz_21], ["h0", "q0", "j0"], filled=False, legend_labels=["CC+Pantheon+"])
plt.show()

# %%
gPSPPHz21 = plots.getSubplotPlotter()
gPSPPHz21.triangle_plot([samplesPSHz_21, samplesPPHz_21], ["h0", "q0", "j0"], filled=False, legend_labels=["CC+SH0ES+Pantheon+", "CC+Pantheon+"])
plt.show()

# %% [markdown]
# ## P22

# %% [markdown]
# ### CC+SH0ES+Pantheon+

# %%
samplesPSHz_22 = loadMCSamples("chains/P22/PS/PSHz_22")
logzPS22 = "chains/P22/PS/PSHz_22.logZ"
# Out:
# chains/P22/PS/PSHz_22.1.txt
# Removed no burn in

# %%
MCResult_cobaya(samplesPSHz_22, logzPS22)
# Out:
# M = -19.2539 +0.0255 +0.0577 -0.0255 -0.0577
# h0 = 72.8522 +0.9326 +1.9463 -0.9326 -1.9463
# q0 = -0.3637 +0.0382 +0.1158 -0.0382 -0.1158
# j0 = -0.0488 +0.5106 +0.5755 -0.5106 -0.5755
# s0 = -3.2360 +2.5584 +3.5380 -2.5584 -3.5380
#
# Evidência Bayesiana:
# logZ = -755.468 +/- 0.287

# %%
gPSHz22 = plots.getSubplotPlotter()
gPSHz22.triangle_plot([samplesPSHz_22], ["h0", "q0", "j0", "s0"], filled=False, legend_labels=["CC+SH0ES+Pantheon+"])
plt.show()

# %%
gPSPPHz21 = plots.getSubplotPlotter()
gPSPPHz21.triangle_plot([samplesPSHz_22, samplesPPHz_22], ["h0", "q0", "j0", "s0"], filled=False, legend_labels=["CC+SH0ES+Pantheon+", "CC+Pantheon+"])
plt.show()

# %% [markdown]
# ### CC+Pantheon+

# %%
samplesPPHz_22 = loadMCSamples("chains/P22/PP/PPHz_22")
logzPP22 = "chains/P22/PP/PPHz_22.logZ"
# Out:
# chains/P22/PP/PPHz_22.1.txt
# Removed no burn in

# %%
MCResult_cobaya(samplesPPHz_22, logzPP22)
# Out:
# WARNING:root:auto bandwidth for M very small or failed (h=0.0007717727180826166,N_eff=1019.2227791189101). Using fallback (h=0.0975095446547947)
# M = -0.1119 +19.6119 +19.6119 -19.6119 -19.6119
# h0 = 67.7775 +3.3608 +6.9808 -3.3608 -6.9808
# q0 = -0.3647 +0.0464 +0.1150 -0.0464 -0.1150
# j0 = -0.0138 +0.4970 +0.5779 -0.4970 -0.5779
# s0 = -3.3573 +2.4160 +3.5844 -2.4160 -3.5844
#
# Evidência Bayesiana:
# logZ = -719.860 +/- 0.189

# %%
gPPHz22 = plots.getSubplotPlotter()
gPPHz22.triangle_plot([samplesPPHz_22], ["h0", "q0", "j0", "s0"], filled=False, legend_labels=["CC+Pantheon+"])
plt.show()

# %% [markdown]
# ### P31

# %%
samplesPSHz_31 = loadMCSamples("chains/P31/PSHz_31")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 samplesPSHz_31 = loadMCSamples("chains/P31/PSHz_31")
#
# File ~/jupyter_venv/lib/python3.12/site-packages/getdist/mcsamples.py:119, in loadMCSamples(file_root, ini, jobItem, no_cache, settings, chain_exclude)
#     117         pass
#     118 if not len(files):
# --> 119     raise OSError("No chains found: " + file_root)
#     120 samples.readChains(files)
#     121 if no_cache:
#
# OSError: No chains found: chains/P31/PSHz_31
