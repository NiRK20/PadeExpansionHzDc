# %%
import numpy as np
import numpy.linalg as linalg
import scipy.optimize as op
import scipy.interpolate
from scipy.integrate import quad
import pandas as pd
import time
from cobaya import run
import getdist.plots as gdplt
from getdist import MCSamples
import matplotlib.pyplot as plt
import os

c = 299792.458#km/s

# %% [markdown]
# ## CC data

# %%
zHz, Hzi, errHz = np.genfromtxt('data/32CCdata.dat', comments='#', usecols=(0,1,2), unpack=True, delimiter=',')
zmod, imf, slib, sps, spsooo = np.genfromtxt('data/data_MM20.dat', comments='#', usecols=(0,1,2,3,4), unpack=True)

cov_mat_diag = np.zeros((len(zHz), len(zHz)), dtype='float64') 

for i in range(len(zHz)):
    cov_mat_diag[i,i] = errHz[i]**2#Erros estatísticos

#Erros sistemáticos
imf_intp = np.interp(zHz, zmod, imf)/100
spsooo_intp = np.interp(zHz, zmod, spsooo)/100

cov_mat_imf = np.zeros((len(zHz), len(zHz)), dtype='float64')
cov_mat_spsooo = np.zeros((len(zHz), len(zHz)), dtype='float64')

for i in range(len(zHz)):
    for j in range(len(zHz)):
        cov_mat_imf[i,j] = Hzi[i] * imf_intp[i] * Hzi[j] * imf_intp[j]
        cov_mat_spsooo[i,j] = Hzi[i] * spsooo_intp[i] * Hzi[j] * spsooo_intp[j]
        
#Sistemático+estatístico:
cov_mat = cov_mat_spsooo+cov_mat_imf+cov_mat_diag
inv_cov_mat = np.linalg.inv(cov_mat)

# %% [markdown]
# ## Pantheon+SH0ES data

# %%
def build_data(datafile,SH0ES):
    """
    Run once at the start to load in the data vectors.
    
    Returns x, y where x is the independent variable (redshift in this case)
    and y is the Gaussian-distribured measured variable (magnitude in this case).
    """
    
    global origlen, wwPS, wwPPlus, cepheid_distance, is_calibrator, zHELPS, zHELPPlus

    print("Loading data from {}".format(datafile))
    data = pd.read_csv(datafile, sep=r'\s+')
    origlen = len(data)
    
    if SH0ES:
        ww = (data['zHD']>0.01) | (np.array(data['IS_CALIBRATOR'],dtype=bool))
        wwPS = ww
        zHELPS = data['zHEL'][ww]
    else:
        ww = (data['zHD']>0.01)
        wwPPlus = ww
        zHELPPlus = data['zHEL'][ww]

    zCMB = data['zHD'][ww] #use the vpec corrected redshift for zCMB 
    
    m_obs = data['m_b_corr'][ww]
    if SH0ES:
        is_calibrator = data['IS_CALIBRATOR'][ww]
        cepheid_distance = data['CEPH_DIST'][ww]

    return zCMB, m_obs

def build_covariance(covdatafile, SH0ES):
    """
    Run once at the start to build the covariance matrix for the data
    The file format for the covariance has the first line as an integer
    indicating the number of covariance elements, and the the subsequent
    lines being the elements.
    This function reads in the file and the nasty for loops trim down the covariance
    to match the only rows of data that are used for cosmology    
    """
    print("Loading covariance from {}".format(covdatafile))


    f = open(covdatafile)
    line = f.readline()
    if SH0ES:
        n = int(len(zCMBPS))
        ww = wwPS
    else:
        n = int(len(zCMBPPlus))
        ww = wwPPlus
    C = np.zeros((n,n))
    ii = -1
    jj = -1
    mine = 999
    maxe = -999
    for i in range(origlen):
        jj = -1
        if ww[i]:
            ii += 1
        for j in range(origlen):
            if ww[j]:
                jj += 1
            val = float(f.readline())
            if ww[i]:
                if ww[j]:
                    C[ii,jj] = val
    f.close()
    
    print('Done')

        # Return the covariance; the parent class knows to invert this
        # later to get the precision matrix that we need for the likelihood.
    return C

# %% [markdown]
# ### Pantheon+SH0ES

# %%
zCMBPS, m_obsPS = build_data('data/Pantheon+SH0ES.dat',SH0ES=True)

covPS = build_covariance('data/Pantheon+SH0ES_STAT+SYS.cov', SH0ES=True)
invcovPS = linalg.inv(covPS)
# Out:
# Loading data from data/Pantheon+SH0ES.dat
# Loading covariance from data/Pantheon+SH0ES_STAT+SYS.cov
# Done

# %% [markdown]
# ### Pantheon+

# %%
zCMBPPlus, m_obsPPlus = build_data('data/Pantheon+SH0ES.dat',SH0ES=False)

covPPlus = build_covariance('data/Pantheon+SH0ES_STAT+SYS.cov', SH0ES=False)
invcovPPlus = linalg.inv(covPPlus)
# Out:
# Loading data from data/Pantheon+SH0ES.dat
# Loading covariance from data/Pantheon+SH0ES_STAT+SYS.cov
# Done

# %% [markdown]
# ## Model functions

# %%
#Theory points for Pantheon+ and Pantheon+&SH0ES
def extract_theory_points(theory_x, theory_y, pars, SH0ES):
    """
    Run once per parameter set to extract the mean vector that our
    data points are compared to.  For the Hubble flow set, we compare to the 
    cosmological model. For the calibrators we compare to the Cepheid distances.
    """
    M = pars[0]

    # Pull out theory mu and z from the block.
    #theory_x = block[self.x_section, self.x_name]
    #theory_y = block[self.y_section, self.y_name]

    # Interpolation function of theory so we can evaluate at redshifts of the data
    f = scipy.interpolate.interp1d(theory_x, theory_y)#, kind=self.kind)
    
    if SH0ES:
        theory_ynew = zCMBPS*np.nan
        #Here we use the Cepheid host distances as the "theory". 
        #This is the 2nd rung of the distance ladder and is what calibrates M
        theory_ynew[np.array(is_calibrator,dtype='bool')] = cepheid_distance[np.array(is_calibrator,dtype='bool')]
        
        # Actually do the interpolation at the data redshifts
        zcmb = zCMBPS[~np.array(is_calibrator,dtype='bool')]
        zhel = zHELPS[~np.array(is_calibrator,dtype='bool')]
    else:
        theory_ynew = zCMBPPlus*np.nan
        # Actually do the interpolation at the data redshifts
        zcmb = zCMBPPlus
        zhel = zHELPPlus
    
    fz = f(zcmb)
    if np.any(fz<=0):
        NegDist = True
        return 1
    if SH0ES:
        theory_ynew[~np.array(is_calibrator,dtype='bool')] = 5.0*np.log10((1.0+zcmb)*(1.0+zhel)*\
                                                                          np.atleast_1d(fz))+25.
    else:
        theory_ynew = 5.0*np.log10((1.0+zcmb)*(1.0+zhel)*np.atleast_1d(fz))+25.
                
    # Add the absolute supernova magnitude and return
    #M = block[names.supernova_params, "M"]
    return theory_ynew + M

def extract_theory_pointsHz(theory_x, theory_y, pars):
    theory_ynew = zHz*np.nan  

    f = scipy.interpolate.interp1d(theory_x, theory_y)#, kind=self.kind)
    theory_ynew = np.atleast_1d(f(zHz))
    return theory_ynew

#Points for theory interpolation
N = 3000
zt = np.linspace(0,2.5,N)

# %% [markdown]
# ### P21

# %%
def EzP21(z,theta):
    M, H0, q0, j0 = theta
    a0 = H0
    a1 = (H0*(6 + 10*j0 + 12*q0 + 7*j0*q0 - 3*q0**2 - 6*q0**3))/(3*(j0 - q0**2))
    a2 = (H0*(12 + 14*j0 + 3*j0**2 + 36*q0 + 22*j0*q0 + 24*q0**2 + 2*j0*q0**2 - 6*q0**3 - 3*q0**4))/(6*(j0 - q0**2))
    b1 = (6 + 7*j0 + 12*q0 + 4*j0*q0 - 3*q0**3)/(3*(j0 - q0**2))
        
    H = (a0+a1*z+a2*z**2)/(1+b1*z)

    return H/H0

#Distancia comovel adimensional
def DcModelP21(z,theta):#Integrando e substituindo
    M, H0, q0, j0 = theta
    a0 = H0
    a1 = (H0*(6 + 10*j0 + 12*q0 + 7*j0*q0 - 3*q0**2 - 6*q0**3))/(3*(j0 - q0**2))
    a2 = (H0*(12 + 14*j0 + 3*j0**2 + 36*q0 + 22*j0*q0 + 24*q0**2 + 2*j0*q0**2 - 6*q0**3 - 3*q0**4))/(6*(j0 - q0**2))
    b1 = (6 + 7*j0 + 12*q0 + 4*j0*q0 - 3*q0**3)/(3*(j0 - q0**2))

    if (a1**2-4*a0*a2) > 0:
        r1 = (-a1 + np.sqrt(a1**2-4*a2*a0))/(2*a2)
        r2 = (-a1 - np.sqrt(a1**2-4*a2*a0))/(2*a2)

        dc = (((1+b1*r2)/(r2-r1))*np.log(np.abs((z-r2)/(-r2)))-((1+b1*r1)/(r2-r1))*np.log(np.abs((z-r1)/(-r1))))/a2
        
    elif (a1**2-4*a0*a2) == 0:
        dc = ((1 + (a1*b1)/(2*a2))*2*a2*z)/(a1*(a1/(2*a2) + z)) + (b1*np.log(2*np.abs((a2*(a1/(2*a2) + z))/a1)))/a2
        
    elif (a1**2-4*a0*a2) < 0:
        dc = (b1/(2*a2))*np.log(np.abs((a0+a1*z+a2*z**2)/a0)) + (((2*a2-b1*a1))/(a2*np.sqrt(4*a2*a0-a1**2)))*(np.arctan((2*a2*z+a1)/np.sqrt(4*a2*a0-a1**2)) - np.arctan(a1/np.sqrt(4*a2*a0-a1**2)))

    return H0*dc

#Distancia comovel transversal in pc
def dmModelP21(z, theta):
    M, H0, q0, j0 = theta
    
    dH = c/H0
    wk = 0
    Dcm = DcModelP21(z, theta)
    if wk < 0:
        return dH*np.sin(np.sqrt(-wk)*Dcm)/np.sqrt(-wk)
    elif wk > 0:
        return dH*np.sinh(np.sqrt(wk)*Dcm)/np.sqrt(wk)
    return dH*Dcm

#Distancia comovel transversal in pc
def dmModelP21(z, theta):
    M, H0, q0, j0 = theta
    
    dH = c/H0
    wk = 0
    Dcm = DcModelP21(z, theta)
    if wk < 0:
        return dH*np.sin(np.sqrt(-wk)*Dcm)/np.sqrt(-wk)
    elif wk > 0:
        return dH*np.sinh(np.sqrt(wk)*Dcm)/np.sqrt(wk)
    return dH*Dcm

#distancia de luminosidade in pc
def dlModelP21(z,theta):
    return (1+z)*dmModelP21(z,theta)

def daModelP21(z,theta):
    return dmModelP21(z,theta)/(1+z)

def muModelP21(z,pars):
    return 5.*np.log10(dlModelP21(z,pars))+25

# %% [markdown]
# ### P22

# %%
def EzP22(z, theta):
    M, H0, q0, j0, s0 = theta
    a0 = H0
    a1 = (H0*(-24 + 4*j0 + 8*j0**2 - 84*q0 + 54*j0*q0 + 10*j0**2*q0 - 114*q0**2 + 67*j0*q0**2 - 102*q0**3 + 15*j0*q0**3 - 63*q0**4 - 15*q0**5
              + 17*s0 + 2*j0*s0 + 28*q0*s0 + 9*q0**2*s0))/(2.*(6*j0 + 3*j0**2 + 14*j0*q0 - 6*q0**2 + 2*j0*q0**2 - 12*q0**3 - 3*q0**4 + 2*s0 + 2*q0*s0))
    a2 = (H0*(-144 + 24*j0 + 108*j0**2 + 30*j0**3 - 648*q0 + 216*j0*q0 + 150*j0**2*q0 - 1188*q0**2 + 252*j0*q0**2 - 5*j0**2*q0**2 - 1188*q0**3
              + 90*j0*q0**3 - 648*q0**4 + 60*j0*q0**4 - 180*q0**5 - 45*q0**6 + 78*s0 + 9*j0*s0 + 198*q0*s0 + 35*j0*q0*s0 + 153*q0**2*s0 +
              15*q0**3*s0 + 4*s0**2))/(12.*(6*j0 + 3*j0**2 + 14*j0*q0 - 6*q0**2 + 2*j0*q0**2 - 12*q0**3 - 3*q0**4 + 2*s0 + 2*q0*s0))
    b1 = (24 + 8*j0 - 2*j0**2 + 84*q0 - 14*j0*q0 - 4*j0**2*q0 + 102*q0**2 - 35*j0*q0**2 + 66*q0**3 - 11*j0*q0**3 + 33*q0**4 + 9*q0**5 -
              13*s0 - 2*j0*s0 - 20*q0*s0 - 5*q0**2*s0)/(-12*j0 - 6*j0**2 - 28*j0*q0 + 12*q0**2 - 4*j0*q0**2 + 24*q0**3 + 6*q0**4 - 4*s0 - 4*q0*s0)
    b2 = (-72*j0 - 60*j0**2 - 12*j0**3 - 180*j0*q0 - 30*j0**2*q0 + 72*q0**2 - 30*j0*q0**2 + 23*j0**2*q0**2 + 180*q0**3 + 30*j0*q0**3 +
          90*q0**4 - 24*j0*q0**4 + 9*q0**6 + 15*j0*s0 - 11*j0*q0*s0 - 15*q0**2*s0 + 3*q0**3*s0 - 4*s0**2)/(-72*j0 - 36*j0**2 - 168*j0*q0 
                                                                                                           + 72*q0**2 - 24*j0*q0**2 + 144*q0**3 + 36*q0**4 - 24*s0 - 24*q0*s0)
        
    H = (a0+a1*z+a2*z**2)/(1+b1*z+b2*z**2)

    return H/H0

def DcModelP22(z, theta):#Integrando e substituindo
    M, H0, q0, j0, s0 = theta
    a0 = H0
    a1 = (H0*(-24 + 4*j0 + 8*j0**2 - 84*q0 + 54*j0*q0 + 10*j0**2*q0 - 114*q0**2 + 67*j0*q0**2 - 102*q0**3 + 15*j0*q0**3 - 63*q0**4 - 15*q0**5
              + 17*s0 + 2*j0*s0 + 28*q0*s0 + 9*q0**2*s0))/(2.*(6*j0 + 3*j0**2 + 14*j0*q0 - 6*q0**2 + 2*j0*q0**2 - 12*q0**3 - 3*q0**4 + 2*s0 + 2*q0*s0))
    a2 = (H0*(-144 + 24*j0 + 108*j0**2 + 30*j0**3 - 648*q0 + 216*j0*q0 + 150*j0**2*q0 - 1188*q0**2 + 252*j0*q0**2 - 5*j0**2*q0**2 - 1188*q0**3
              + 90*j0*q0**3 - 648*q0**4 + 60*j0*q0**4 - 180*q0**5 - 45*q0**6 + 78*s0 + 9*j0*s0 + 198*q0*s0 + 35*j0*q0*s0 + 153*q0**2*s0 +
              15*q0**3*s0 + 4*s0**2))/(12.*(6*j0 + 3*j0**2 + 14*j0*q0 - 6*q0**2 + 2*j0*q0**2 - 12*q0**3 - 3*q0**4 + 2*s0 + 2*q0*s0))
    b1 = (24 + 8*j0 - 2*j0**2 + 84*q0 - 14*j0*q0 - 4*j0**2*q0 + 102*q0**2 - 35*j0*q0**2 + 66*q0**3 - 11*j0*q0**3 + 33*q0**4 + 9*q0**5 -
              13*s0 - 2*j0*s0 - 20*q0*s0 - 5*q0**2*s0)/(-12*j0 - 6*j0**2 - 28*j0*q0 + 12*q0**2 - 4*j0*q0**2 + 24*q0**3 + 6*q0**4 - 4*s0 - 4*q0*s0)
    #Coeficiente b2 correto
    b2 = (-72*j0 - 60*j0**2 - 12*j0**3 - 180*j0*q0 - 30*j0**2*q0 + 72*q0**2 - 30*j0*q0**2 + 23*j0**2*q0**2 + 180*q0**3 + 30*j0*q0**3 +
          90*q0**4 - 24*j0*q0**4 + 9*q0**6 + 15*j0*s0 - 11*j0*q0*s0 - 15*q0**2*s0 + 3*q0**3*s0 - 4*s0**2)/(-72*j0 - 36*j0**2 - 168*j0*q0
              + 72*q0**2 - 24*j0*q0**2 + 144*q0**3 + 36*q0**4 - 24*s0 - 24*q0*s0)
    #Coeficiente b2 errado?
    #b2 = (-72*j0 - 60*j0**2 - 12*j0**3 - 180*j0*q0 - 30*j0**2*q0 + 72*q0**2 - 30*j0*q0**2 + 23*j0**2*q0**2 + 180*q0**3 + 30*j0*q0**3 +
    #      90*q0**4 - 24*j0*q0**4 + 9*q0**6 + 15*j0*s0 - 11*j0*q0*s0 - 15*q0**2*s0 + 3*q0**3*s0 - 4*s0**2)/(-72*j0 - 36*j0**2 - 168*j0*q0)

    if (a1**2-4*a0*a2) > 0:
        r1 = (-a1 + np.sqrt(a1**2-4*a2*a0))/(2*a2)
        r2 = (-a1 - np.sqrt(a1**2-4*a2*a0))/(2*a2)
        dc = (((1 + b1*r2 + r2**2)/(r2 - r1))*np.log(np.abs((z - r2)/(-r2))) - ((1 + b1*r1 + r1**2)/(r2 - r1))*np.log(np.abs((z-r1)/(-r1))) + z)/a2
        
    elif (a1**2-4*a0*a2) == 0:
        dc = ((b1 - (b2*a1)/(2*a2))*np.log(np.abs((2*a2*z + a1)/a1)) - (1 - (b1*a1)/(2*a2) + (b2*a1)/(4*a2**2))*(1/(a1*(2*a2*z +a1)) - b2)*z)/a2
        
    elif (a1**2-4*a0*a2) < 0:
        dc = ((b2*z)/a2 + (b1/(2*a2) - (b2*a1)/(2*a2**2))*np.log(np.abs((a0+a1*z+a2*z**2)/a0)) + (((2*a2-b1*a1 - b2*(2*a2*a0 - a1**2)/a2))/(a2*np.sqrt(4*a2*a0-a1**2)))*(np.arctan((2*a2*z+a1)/np.sqrt(4*a2*a0-a1**2))
                    - np.arctan(a1/np.sqrt(4*a2*a0-a1**2))))/a2

    return H0*dc

#Distancia comovel transversal in pc
def dmModelP22(z, theta):
    M, H0, q0, j0, s0 = theta
    
    dH = c/H0
    wk = 0
    Dcm = DcModelP22(z, theta)
    if wk < 0:
        return dH*np.sin(np.sqrt(-wk)*Dcm)/np.sqrt(-wk)
    elif wk > 0:
        return dH*np.sinh(np.sqrt(wk)*Dcm)/np.sqrt(wk)
    return dH*Dcm

#distancia de luminosidade in pc
def dlModelP22(z,theta):
    return (1+z)*dmModelP22(z,theta)

def daModelP22(z,theta):
    return dmModelP22(z,theta)/(1+z)

def muModelP22(z,pars):
    return 5.*np.log10(dlModelP22(z,pars))+25

# %% [markdown]
# ### P31

# %%
def EzP31(z, theta):
    M, H0, q0, j0, s0 = theta
    a0 = H0
    a1 = -0.25*(H0*(24 - 4*j0 + 4*j0**2 + 60*q0 - 50*j0*q0 + 54*q0**2 - 41*j0*q0**2 + 48*q0**3 + 27*q0**4 - 17*s0 - 11*q0*s0))/(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0)
    a2 = (H0*(-24 - 8*j0 + 2*j0**2 - 84*q0 + 14*j0*q0 + 4*j0**2*q0 - 102*q0**2 + 35*j0*q0**2 - 66*q0**3 + 
              11*j0*q0**3 - 33*q0**4 - 9*q0**5 + 13*s0 + 2*j0*s0 + 20*q0*s0 + 5*q0**2*s0))/(4.*(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0))
    a3 = -0.0417*(H0*(72*j0 + 60*j0**2 + 12*j0**3 + 180*j0*q0 + 30*j0**2*q0 - 72*q0**2 + 30*j0*q0**2 - 
                      23*j0**2*q0**2 - 180*q0**3 - 30*j0*q0**3 - 90*q0**4 + 24*j0*q0**4 - 9*q0**6 - 15*j0*s0 + 11*j0*q0*s0 + 
                      15*q0**2*s0 - 3*q0**3*s0 + 4*s0**2))/(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0) #0.041666666666666664
    b1 = (-24 - 8*j0 - 4*j0**2 - 60*q0 + 22*j0*q0 - 42*q0**2 + 25*j0*q0**2 - 24*q0**3 - 15*q0**4 + 13*s0 + 7*q0*s0)/(4.*(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0))

    H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)

    return H/H0

#Distancia comovel adimensional
def DcModelP31(z,theta):#Integrando e substituindo
    M, H0, q0, j0, s0 = theta
    dc = np.zeros_like(z)
    
    a0 = H0
    a1 = -0.25*(H0*(24 - 4*j0 + 4*j0**2 + 60*q0 - 50*j0*q0 + 54*q0**2 - 41*j0*q0**2 + 48*q0**3 + 27*q0**4 - 17*s0 - 11*q0*s0))/(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0)
    
    a2 = (H0*(-24 - 8*j0 + 2*j0**2 - 84*q0 + 14*j0*q0 + 4*j0**2*q0 - 102*q0**2 + 35*j0*q0**2 - 66*q0**3 + 11*j0*q0**3 - 
              33*q0**4 - 9*q0**5 + 13*s0 + 2*j0*s0 + 20*q0*s0 + 5*q0**2*s0))/(4.*(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0))
    
    a3 = -0.0417*(H0*(72*j0 + 60*j0**2 + 12*j0**3 + 180*j0*q0 + 30*j0**2*q0 - 72*q0**2 + 30*j0*q0**2 - 
                      23*j0**2*q0**2 - 180*q0**3 - 30*j0*q0**3 - 90*q0**4 + 24*j0*q0**4 - 9*q0**6 - 15*j0*s0 + 11*j0*q0*s0 + 
                      15*q0**2*s0 - 3*q0**3*s0 + 4*s0**2))/(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0) #0.041666666666666664
    
    b1 = (-24 - 8*j0 - 4*j0**2 - 60*q0 + 22*j0*q0 - 42*q0**2 + 25*j0*q0**2 - 24*q0**3 - 15*q0**4 + 13*s0 + 7*q0*s0)/(4.*(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0))

    for i in range(len(z)):
        dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
        if not np.isfinite(dc[i]):
            dc[i] = np.inf

    return (H0)*dc

#Distancia comovel transversal in pc
def dmModelP31(z, theta):
    M, H0, q0, j0, s0= theta
    
    dH = c/H0
    wk = 0
    Dcm = DcModelP31(z, theta)
    if wk < 0:
        return dH*np.sin(np.sqrt(-wk)*Dcm)/np.sqrt(-wk)
    elif wk > 0:
        return dH*np.sinh(np.sqrt(wk)*Dcm)/np.sqrt(wk)
    return dH*Dcm

#distancia de luminosidade in pc
def dlModelP31(z,theta):
    return (1+z)*dmModelP31(z,theta)

def daModelP31(z,theta):
    return dmModelP31(z,theta)/(1+z)

def muModelP31(z,pars):
    return 5.*np.log10(dlModelP31(z,pars))+25

# %% [markdown]
# ## Statistical functions

# %% [markdown]
# ### P21

# %%
def getpar_PSHz_21(theta):
    M, h0, q0, j0 = theta
    return lnprobPSHz_21(M, h0, q0, j0)

def getpar_PPHz_21(theta):
    M, h0, q0, j0 = theta
    return lnprobPPHz_21(M, h0, q0, j0)

def chi2PS_21(theta):#Pantheon+SH0ES
    zsni = zCMBPS
    Ez2i = EzP21(zsni,theta)
    if np.any(Ez2i <= 0):
        return np.inf

    dAt = daModelP21(zt,theta)
    NegDist = False
    mmod = extract_theory_points(zt, dAt, theta, SH0ES=True)
    if NegDist:
        return np.inf
    dm = mmod-m_obsPS
    
    return np.dot(np.dot(dm.T,invcovPS),dm)
        
def chi2PP_21(theta):#Pantheon+
    zsni = zCMBPPlus
    Ez2i = EzP21(zsni,theta)
    if np.any(Ez2i <= 0):
        return np.inf

    dAt = daModelP21(zt,theta)
    NegDist = False
    mmod = extract_theory_points(zt, dAt, theta,SH0ES=False) #5.*np.log10((1+zsni)*(1+zheli)*dAmodi/10)#(dlmodi/10)
    if NegDist:
        return np.inf
    dmu = mmod-m_obsPPlus
    SA  = np.sum(invcovPPlus)
    Sr  = np.sum(np.dot(dmu.T,invcovPPlus))#np.sum(dmu*invcov)
    Srr = np.dot(np.dot(dmu.T,invcovPPlus),dmu)#np.sum(dmu*dmu*invcov)
    return Srr - Sr**2./SA
        
def chi2Hz_21(theta):#CC Hz
    M, H0, q0, j0 = theta
        
    Ezt = EzP21(zt,theta)
    if np.any(Ezt<0):
        return np.inf
    Hzt = H0*Ezt#Hz(zt,pars)
    Hzm = extract_theory_pointsHz(zt, Hzt, theta)
   
    dh = Hzm-Hzi
    
    return np.dot(np.dot(dh.T,inv_cov_mat),dh)

def lnlikePS_21(theta):
    return -0.5*chi2PS_21(theta)

def lnlikePP_21(theta):
    return -0.5*chi2PP_21(theta)

def lnlikeHz_21(theta):
    return -0.5*chi2Hz_21(theta)

def lnprobPSHz_21(M, h0, q0, j0):
    theta = [M, h0, q0, j0]
    return lnlikePS_21(theta)+lnlikeHz_21(theta)
    
def lnprobPPHz_21(M, h0, q0, j0):
    theta = [M, h0, q0, j0]
    return lnlikePP_21(theta)+lnlikeHz_21(theta)

# %% [markdown]
# ### P22

# %%
def getpar_PSHz_22(theta):
    M, h0, q0, j0, s0 = theta
    return lnprobPSHz_22(M, h0, q0, j0, s0)

def getpar_PPHz_22(theta):
    M, h0, q0, j0, s0 = theta
    return lnprobPPHz_22(M, h0, q0, j0, s0)

def chi2PS_22(theta):#Pantheon+SH0ES
    zsni = zCMBPS
    Ez2i = EzP22(zsni,theta)
    if np.any(Ez2i <= 0):
        return np.inf

    dAt = daModelP22(zt,theta)
    NegDist = False
    mmod = extract_theory_points(zt, dAt, theta, SH0ES=True)
    if NegDist:
        return np.inf
    dm = mmod-m_obsPS
    
    return np.dot(np.dot(dm.T,invcovPS),dm)
        
def chi2PP_22(theta):#Pantheon+
    zsni = zCMBPPlus
    Ez2i = EzP22(zsni,theta)
    if np.any(Ez2i <= 0):
        return np.inf

    dAt = daModelP22(zt,theta)
    NegDist = False
    mmod = extract_theory_points(zt, dAt, theta,SH0ES=False) #5.*np.log10((1+zsni)*(1+zheli)*dAmodi/10)#(dlmodi/10)
    if NegDist:
        return np.inf
    dmu = mmod-m_obsPPlus
    SA  = np.sum(invcovPPlus)
    Sr  = np.sum(np.dot(dmu.T,invcovPPlus))#np.sum(dmu*invcov)
    Srr = np.dot(np.dot(dmu.T,invcovPPlus),dmu)#np.sum(dmu*dmu*invcov)
    return Srr - Sr**2./SA
        
def chi2Hz_22(theta):#CC Hz
    M, H0, q0, j0, s0 = theta
        
    Ezt = EzP22(zt,theta)
    if np.any(Ezt<0):
        return np.inf
    Hzt = H0*Ezt#Hz(zt,pars)
    Hzm = extract_theory_pointsHz(zt, Hzt, theta)
   
    dh = Hzm-Hzi
    
    return np.dot(np.dot(dh.T,inv_cov_mat),dh)

def lnlikePS_22(theta):
    return -0.5*chi2PS_22(theta)

def lnlikePP_22(theta):
    return -0.5*chi2PP_22(theta)

def lnlikeHz_22(theta):
    return -0.5*chi2Hz_22(theta)

def lnprobPSHz_22(M, h0, q0, j0, s0):
    theta = [M, h0, q0, j0, s0]
    return lnlikePS_22(theta)+lnlikeHz_22(theta)
    
def lnprobPPHz_22(M, h0, q0, j0, s0):
    theta = [M, h0, q0, j0, s0]
    return lnlikePP_22(theta)+lnlikeHz_22(theta)

# %% [markdown]
# ### P31

# %%
def getpar_PSHz_31(theta):
    M, h0, q0, j0, s0 = theta
    return lnprobPSHz_31(M, h0, q0, j0, s0)

def getpar_PPHz_31(theta):
    M, h0, q0, j0, s0 = theta
    return lnprobPPHz_31(M, h0, q0, j0, s0)

def chi2PS_31(theta):#Pantheon+SH0ES
    zsni = zCMBPS
    Ez2i = EzP31(zsni,theta)
    if np.any(Ez2i <= 0):
        return np.inf

    dAt = daModelP31(zt,theta)
    NegDist = False
    mmod = extract_theory_points(zt, dAt, theta, SH0ES=True)
    if NegDist:
        return np.inf
    dm = mmod-m_obsPS
    
    return np.dot(np.dot(dm.T,invcovPS),dm)
        
def chi2PP_31(theta):#Pantheon+
    zsni = zCMBPPlus
    Ez2i = EzP31(zsni,theta)
    if np.any(Ez2i <= 0):
        return np.inf

    dAt = daModelP31(zt,theta)
    NegDist = False
    mmod = extract_theory_points(zt, dAt, theta,SH0ES=False) #5.*np.log10((1+zsni)*(1+zheli)*dAmodi/10)#(dlmodi/10)
    if NegDist:
        return np.inf
    dmu = mmod-m_obsPPlus
    SA  = np.sum(invcovPPlus)
    Sr  = np.sum(np.dot(dmu.T,invcovPPlus))#np.sum(dmu*invcov)
    Srr = np.dot(np.dot(dmu.T,invcovPPlus),dmu)#np.sum(dmu*dmu*invcov)
    return Srr - Sr**2./SA
        
def chi2Hz_31(theta):#CC Hz
    M, H0, q0, j0, s0 = theta
        
    Ezt = EzP31(zt,theta)
    if np.any(Ezt<0):
        return np.inf
    Hzt = H0*Ezt#Hz(zt,pars)
    Hzm = extract_theory_pointsHz(zt, Hzt, theta)
   
    dh = Hzm-Hzi
    
    return np.dot(np.dot(dh.T,inv_cov_mat),dh)

def lnlikePS_31(theta):
    return -0.5*chi2PS_31(theta)

def lnlikePP_31(theta):
    return -0.5*chi2PP_31(theta)

def lnlikeHz_31(theta):
    return -0.5*chi2Hz_31(theta)

def lnprobPSHz_31(M, h0, q0, j0, s0):
    theta = [M, h0, q0, j0, s0]
    return lnlikePS_31(theta)+lnlikeHz_31(theta)
    
def lnprobPPHz_31(M, h0, q0, j0, s0):
    theta = [M, h0, q0, j0, s0]
    return lnlikePP_31(theta)+lnlikeHz_31(theta)

# %% [markdown]
# ## Analysis functions

# %%
def find_bestfit(lnlike, parnames, par_ml):#,data):
    t1 = time.time()
    ndim = len(par_ml)
    chi2 = lambda *args: -2 * lnlike(*args)
    result = op.minimize(chi2, par_ml)#, args=data)
    if not result['success']:
        result = op.minimize(chi2, par_ml, method='Nelder-Mead',options={'maxiter': 10000})#, args=data
    par_ml = result["x"]
    print('Maximum likelihood result:')
    for i in range(ndim):
        print(parnames[i],' = ',par_ml[i])
    print('chi2min =',result['fun'])
    #ndof = len(data[0])-ndim
    #print('chi2red =',result['fun']/ndof)
    #print(result)
    t2 = time.time()
    print("tempo total: {0:5.3f} seg".format(t2-t1))
    return result

def run_cobaya(info, info_post):
    print("----- INICIANDO SAMPLER -----")
    t1 = time.time()

    # Roda o sampler
    updated_info, sampler = run(info)

    # Retira o início 
    print("----- RETIRANDO O INICIO -----")
    updated_info_post, sampler_post = run(info_post)

    print(f"Tempo de execução: {time.time()-t1} s")

    return sampler, sampler_post

def MCResult_cobaya(sampler):
    gdsamples = sampler.products()["sample"][0].to_getdist()
    stats = gdsamples.getMargeStats()

    for par in stats.names[:gdsamples.samples.shape[1]-2]:
        par_stats = stats.parWithName(par.name)
        mean = par_stats.mean

        # Erros de 1-sigma (68% CL)
        lower_1s = par_stats.limits[0].lower
        upper_1s = par_stats.limits[0].upper
        err_plus_1s = upper_1s - mean
        err_minus_1s = mean - lower_1s

        # Erros de 2-sigma (95% CL)
        lower_2s = par_stats.limits[1].lower
        upper_2s = par_stats.limits[1].upper
        err_plus_2s = upper_2s - mean
        err_minus_2s = mean - lower_2s
            
        label = f"{par.name}"
        
            
        print(f"{label} = {mean:.4f} +{err_plus_1s:.4f} +{err_plus_2s:.4f} -{err_plus_1s:.4f} -{err_plus_2s:.4f}") 
    
def plot_getdist(samples, params, legends, width=8, fill=False):
    gsamples = []
    for i in samples:
        gsamples.append(i.products()["sample"][0].to_getdist())

    g = gdplt.getSubplotPlotter(width_inch=width)
    g.triangle_plot(gsamples, params, filled=fill, legend_labels=legends)
    plt.show()

def lnlikePPHz_21(M, h0, q0, j0):
    theta = [M, h0, q0, j0]
    return lnlikePP_21(theta)+lnlikeHz_21(theta)

# %% [markdown]
# ## Models analysis

# %% [markdown]
# ### P21

# %%
parlabels_21 = ["M","H_0",'q_0','j_0']
parlabtex_21 = ["$M$","$H_0$",'$q_0$','$j_0$']
parnames_21 = ['M','H0','q0','j0']
par0_21=[-19.2, 73.03398760350208, -0.5280171275112104, 1]
ndim_21 = len(par0_21)

# %% [markdown]
# #### CC+SH0ES+Pantheon+

# %%
par_mlHzPS_21 = par0_21

# %%
resultHzPS_21 = find_bestfit(getpar_PSHz_21, parnames_21, par_mlHzPS_21)
par_mlHzPS_21=resultHzPS_21['x']
print('\n',par_mlHzPS_21,'\n')
print(resultHzPS_21,'\n')
# Out:
# /home/nirk20/jupyter_venv/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:596: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0
# Maximum likelihood result:
# M  =  -19.253427502449398
# H0  =  73.32840195934713
# q0  =  -0.5798951804861703
# j0  =  2.2694028184834334
# chi2min = 1469.5326661208758
# tempo total: 3.883 seg
#
#  [-19.2534275   73.32840196  -0.57989518   2.26940282]
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1469.5326661208758
#              x: [-1.925e+01  7.333e+01 -5.799e-01  2.269e+00]
#            nit: 217
#           nfev: 361
#  final_simplex: (array([[-1.925e+01,  7.333e+01, -5.799e-01,  2.269e+00],
#                        [-1.925e+01,  7.333e+01, -5.799e-01,  2.269e+00],
#                        ...,
#                        [-1.925e+01,  7.333e+01, -5.799e-01,  2.269e+00],
#                        [-1.925e+01,  7.333e+01, -5.799e-01,  2.269e+00]],
#                       shape=(5, 4)), array([ 1.470e+03,  1.470e+03,  1.470e+03,  1.470e+03,
#                         1.470e+03]))

# %%
info_PSHz21 = {
    "likelihood": {
        "lnlikehz": lnprobPSHz_21
    },

    "params": {
        "M": {"prior": {"min": -19.5, "max": 19.5}, "proposal": par_mlHzPS_21[0], "latex": "M"},
        "h0": {"prior": {"min": 40.0, "max": 100.0}, "proposal": par_mlHzPS_21[1], "latex": r"H_{0}"},
        "q0": {"prior": {"min": -2, "max": 2}, "proposal": par_mlHzPS_21[2], "latex": r"q_{0}"},
        "j0": {"prior": {"min": -5, "max": 5}, "proposal": par_mlHzPS_21[3], "latex": r"j_{0}"}
    },

    "sampler": {
        "polychord": {
            "nlive": 100
        }
    },

    "output": "chains/P21/PSHz_21"
}

info_post_PSHz21 = {
    "output": "chains/P21/PSHz_21",
    "post": {
        "skip_samples": 0.3,
        "suffix": "_post"
    }
}

# %%
_, sampler_PSHz_21 = run_cobaya(info_PSHz21, info_post_PSHz21)
# Out:
# ----- INICIANDO SAMPLER -----
# [output] Output to be read-from/written-into folder 'chains/P21', with prefix 'PSHz_21'
# [lnlikehz] Initialized external likelihood.
# [polychord] `pypolychord` module loaded successfully from /home/nirk20/jupyter_venv/lib/python3.12/site-packages/pypolychord
# [polychord] Storing raw PolyChord output in 'chains/P21/PSHz_21_polychord_raw'.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {lnlikehz: 128.0}
# [polychord] Parameter blocks and their oversampling factors:
# [polychord] * 1 : ['M', 'h0', 'q0', 'j0']
# [polychord] Calling PolyChord...
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     100
# nDims    :       4
# nDerived :       2
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/P21/PSHz_21_polychord_raw/PSHz_21.resume
#
# generating live points
#
#
# all live points generated
#
# number of repeats:            8
# started sampling
#
# ________________
# lives      |100 |
# phantoms   |  7 |
# posteriors |901 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 901
# nposterior =                 901
# nequals    =                   1
# nlike      =                1010
# <nlike>    =           0.10   (           0.01 per slice )
# log(Z)     =      -472254.54 +/-  0.83
# log(Z_1)   =      -472254.54 +/-  0.83 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 422 |
# posteriors |1002 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1002
# nposterior =                1002
# nequals    =                   1
# nlike      =                2726
# <nlike>    =          17.16   (           2.15 per slice )
# log(Z)     =       -39842.52 +/-  0.84
# log(Z_1)   =       -39842.52 +/-  0.84 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 525 |
# posteriors |1103 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1103
# nposterior =                1103
# nequals    =                   1
# nlike      =                4586
# <nlike>    =          18.60   (           2.33 per slice )
# log(Z)     =        -4170.76 +/-  0.84
# log(Z_1)   =        -4170.76 +/-  0.84 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 665 |
# posteriors |1204 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1204
# nposterior =                1204
# nequals    =                   1
# nlike      =                6622
# <nlike>    =          20.36   (           2.54 per slice )
# log(Z)     =        -1795.35 +/-  0.85
# log(Z_1)   =        -1795.35 +/-  0.85 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 637 |
# posteriors |1305 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1305
# nposterior =                1305
# nequals    =                   1
# nlike      =                8892
# <nlike>    =          22.70   (           2.84 per slice )
# log(Z)     =        -1173.63 +/-  0.85
# log(Z_1)   =        -1173.63 +/-  0.85 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 720 |
# posteriors |1406 |
# equals     |   3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1406
# nposterior =                1406
# nequals    =                   2
# nlike      =               11335
# <nlike>    =          24.43   (           3.05 per slice )
# log(Z)     =         -980.51 +/-  0.62
# log(Z_1)   =         -980.51 +/-  0.62 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 615 |
# posteriors |1507 |
# equals     |   3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1507
# nposterior =                1507
# nequals    =                   2
# nlike      =               14020
# <nlike>    =          26.85   (           3.36 per slice )
# log(Z)     =         -854.86 +/-  0.60
# log(Z_1)   =         -854.86 +/-  0.60 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 701 |
# posteriors |1608 |
# equals     |   3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1608
# nposterior =                1608
# nequals    =                   4
# nlike      =               16856
# <nlike>    =          28.36   (           3.54 per slice )
# log(Z)     =         -810.04 +/-  0.49
# log(Z_1)   =         -810.04 +/-  0.49 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 701 |
# posteriors |1709 |
# equals     |   6 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1709
# nposterior =                1709
# nequals    =                   7
# nlike      =               20046
# <nlike>    =          31.90   (           3.99 per slice )
# log(Z)     =         -782.43 +/-  0.39
# log(Z_1)   =         -782.43 +/-  0.39 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 742 |
# posteriors |1810 |
# equals     |  10 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1810
# nposterior =                1810
# nequals    =                   7
# nlike      =               23510
# <nlike>    =          34.64   (           4.33 per slice )
# log(Z)     =         -769.52 +/-  0.38
# log(Z_1)   =         -769.52 +/-  0.38 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 718 |
# posteriors |1911 |
# equals     |  21 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1911
# nposterior =                1911
# nequals    =                  17
# nlike      =               27143
# <nlike>    =          36.33   (           4.54 per slice )
# log(Z)     =         -761.40 +/-  0.36
# log(Z_1)   =         -761.40 +/-  0.36 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 716 |
# posteriors |2012 |
# equals     |  40 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2012
# nposterior =                2012
# nequals    =                  29
# nlike      =               30930
# <nlike>    =          37.87   (           4.73 per slice )
# log(Z)     =         -756.86 +/-  0.35
# log(Z_1)   =         -756.86 +/-  0.35 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 718 |
# posteriors |2113 |
# equals     |  53 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2113
# nposterior =                2113
# nequals    =                  48
# nlike      =               34829
# <nlike>    =          38.99   (           4.87 per slice )
# log(Z)     =         -754.53 +/-  0.35
# log(Z_1)   =         -754.53 +/-  0.35 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 770 |
# posteriors |2214 |
# equals     | 102 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2214
# nposterior =                2214
# nequals    =                  96
# nlike      =               38793
# <nlike>    =          39.64   (           4.96 per slice )
# log(Z)     =         -753.22 +/-  0.35
# log(Z_1)   =         -753.22 +/-  0.35 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 738 |
# posteriors |2315 |
# equals     | 172 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2315
# nposterior =                2315
# nequals    =                 173
# nlike      =               42713
# <nlike>    =          39.20   (           4.90 per slice )
# log(Z)     =         -752.45 +/-  0.36
# log(Z_1)   =         -752.45 +/-  0.36 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 802 |
# posteriors |2416 |
# equals     | 256 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2416
# nposterior =                2416
# nequals    =                 253
# nlike      =               46593
# <nlike>    =          38.80   (           4.85 per slice )
# log(Z)     =         -752.05 +/-  0.36
# log(Z_1)   =         -752.05 +/-  0.36 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 680 |
# posteriors |2517 |
# equals     | 309 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2517
# nposterior =                2517
# nequals    =                 301
# nlike      =               50564
# <nlike>    =          39.71   (           4.96 per slice )
# log(Z)     =         -751.87 +/-  0.36
# log(Z_1)   =         -751.87 +/-  0.36 (still evaluating)
#
#
#
# _______________________
# lives      |  88 |  12 |
# phantoms   | 623 | 128 |
# posteriors |2595 |2541 |
# equals     | 331 | 320 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                2619
# nposterior =                2619
# nequals    =                 331
# nlike      =               56230
# <nlike>    =          56.66   (           7.08 per slice )
# log(Z)     =         -751.78 +/-  0.36
# log(Z_1)   =         -752.08 +/-  0.36 (still evaluating)
# log(Z_2)   =         -753.14 +/-  0.37 (still evaluating)
#
#
#
# _____________________________
# lives      |   5 |  90 |   5 |
# phantoms   |  77 | 620 |  42 |
# posteriors |2554 |2676 |2600 |
# equals     | 323 | 339 | 331 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       3
# ndead      =                2718
# nposterior =                2718
# nequals    =                 347
# nlike      =               61488
# <nlike>    =          52.58   (           6.57 per slice )
# log(Z)     =         -751.74 +/-  0.36
# log(Z_1)   =         -752.11 +/-  0.37 (still evaluating)
# log(Z_2)   =         -753.10 +/-  0.37 (still evaluating)
# log(Z_3)   =         -754.80 +/-  0.39 (still evaluating)
#
#
#
# _______________________
# lives      |   4 |  96 |
# phantoms   |  57 | 765 |
# posteriors |2559 |2758 |
# equals     | 324 | 341 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       4
# ndead      =                2817
# nposterior =                2817
# nequals    =                 352
# nlike      =               66669
# <nlike>    =          51.81   (           6.48 per slice )
# log(Z)     =         -751.73 +/-  0.36
# log(Z_1)   =         -752.13 +/-  0.37 (still evaluating)
# log(Z_2)   =         -753.10 +/-  0.37 (still evaluating)
# log(Z_3)   =         -754.77 +/-  0.39
# log(Z_4)   =         -755.32 +/-  0.41
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 736 |
# posteriors |2842 |
# equals     | 342 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       4
# ndead      =                2906
# nposterior =                2906
# nequals    =                 358
# nlike      =               70484
# <nlike>    =          38.15   (           4.77 per slice )
# log(Z)     =         -751.72 +/-  0.36
# log(Z_1)   =         -752.12 +/-  0.37 (still evaluating)
# log(Z_2)   =         -753.09 +/-  0.37
# log(Z_3)   =         -754.77 +/-  0.39
# log(Z_4)   =         -755.32 +/-  0.41
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 636 |
# posteriors |2943 |
# equals     | 344 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       4
# ndead      =                3007
# nposterior =                3007
# nequals    =                 359
# nlike      =               74405
# <nlike>    =          39.21   (           4.90 per slice )
# log(Z)     =         -751.72 +/-  0.36
# log(Z_1)   =         -752.12 +/-  0.37 (still evaluating)
# log(Z_2)   =         -753.09 +/-  0.37
# log(Z_3)   =         -754.77 +/-  0.39
# log(Z_4)   =         -755.32 +/-  0.41
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =         3144                              |
# | log(Z) =         -751.71830 +/-            0.36485 |
# |____________________________________________________|
# [polychord] Loading PolyChord's results: samples and evidences.
# [polychord] Finished! Raw PolyChord output stored in 'chains/P21/PSHz_21_polychord_raw', with prefix 'PSHz_21'
# [polychord] log(Z) = -752.131 +/- 0.364847 ; Z in [0, 0] (68% C.L. log-gaussian)
# ----- RETIRANDO O INICIO -----
# [output] Output to be read-from/written-into folder 'chains/P21', with prefix 'PSHz_21'
# [output] Found existing info files with the requested output prefix: 'chains/P21/PSHz_21'
# [samplecollection] Loaded 1898 sample points from 'chains/P21/PSHz_21.1.txt'
# [post] Will process 1898 sample points.
# [output] Output to be read-from/written-into folder 'chains/P21', with prefix 'PSHz_21.post._post'
# [post] Running post-processing...
# [post]  |--------------------|   0%  (0/1898)
# [post]  |@-------------------|   5%  (86/1898)
# [post]  |@@------------------|  10%  (181/1898)
# [post]  |@@@-----------------|  15%  (276/1898)
# [post]  |@@@@----------------|  20%  (371/1898)
# [post]  |@@@@@---------------|  25%  (466/1898)
# [post]  |@@@@@@--------------|  30%  (560/1898)
# [post]  |@@@@@@@-------------|  35%  (655/1898)
# [post]  |@@@@@@@@------------|  40%  (750/1898)
# [post]  |@@@@@@@@@-----------|  45%  (845/1898)
# [post]  |@@@@@@@@@@----------|  50%  (940/1898)
# [post]  |@@@@@@@@@@@---------|  55%  (1035/1898)
# [post]  |@@@@@@@@@@@@--------|  60%  (1130/1898)
# [post]  |@@@@@@@@@@@@@-------|  65%  (1225/1898)
# [post]  |@@@@@@@@@@@@@@------|  70%  (1320/1898)
# [post]  |@@@@@@@@@@@@@@@-----|  75%  (1415/1898)
# [post]  |@@@@@@@@@@@@@@@@----|  80%  (1509/1898)
# [post]  |@@@@@@@@@@@@@@@@@---|  85%  (1604/1898)
# [post]  |@@@@@@@@@@@@@@@@@@--|  90%  (1699/1898)
# [post]  |@@@@@@@@@@@@@@@@@@@-|  95%  (1794/1898)
# [post]  |@@@@@@@@@@@@@@@@@@@@| 100%  (1889/1898)
# [post] Finished! Final number of distinct sample points: 1898
# [post] Importance weight range: 1 -- 1
# [post] Effective number of single samples if independent (sum w)/max(w): 360
# [post] Effective number of weighted samples if independent (sum w)^2/sum(w^2): 551
# Tempo de execução: 436.43566250801086 s

# %% [markdown]
# #### CC+Pantheon+

# %%
par_mlHzPP_21 = par0_21

# %%
resultHzPP_21 = find_bestfit(getpar_PPHz_21, parnames_21, par_mlHzPP_21)
par_mlHzPP_21=resultHzPP_21['x']
print('\n',par_mlHzPP_21,'\n')
print(resultHzPP_21,'\n')
# Out:
# Maximum likelihood result:
# M  =  -12.351193838336917
# H0  =  69.1043329589236
# q0  =  -0.5961098582696993
# j0  =  2.4549315819076085
# chi2min = 1418.4627051569305
# tempo total: 3.030 seg
#
#  [-12.35119384  69.10433296  -0.59610986   2.45493158]
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1418.4627051569305
#              x: [-1.235e+01  6.910e+01 -5.961e-01  2.455e+00]
#            nit: 127
#           nfev: 224
#  final_simplex: (array([[-1.235e+01,  6.910e+01, -5.961e-01,  2.455e+00],
#                        [-1.235e+01,  6.910e+01, -5.961e-01,  2.455e+00],
#                        ...,
#                        [-1.235e+01,  6.910e+01, -5.961e-01,  2.455e+00],
#                        [-1.235e+01,  6.910e+01, -5.961e-01,  2.455e+00]],
#                       shape=(5, 4)), array([ 1.418e+03,  1.418e+03,  1.418e+03,  1.418e+03,
#                         1.418e+03]))

# %%
info_PPHz21 = {
    "likelihood": {
        "lnlikehz": lnprobPPHz_21
    },

    "params": {
        "M": {"prior": {"min": -19.5, "max": 19.5}, "proposal": par_mlHzPP_21[0], "latex": "M"},
        "h0": {"prior": {"min": 40.0, "max": 100.0}, "proposal": par_mlHzPP_21[1], "latex": r"H_{0}"},
        "q0": {"prior": {"min": -2, "max": 2}, "proposal": par_mlHzPP_21[2], "latex": r"q_{0}"},
        "j0": {"prior": {"min": -5, "max": 5}, "proposal": par_mlHzPP_21[3], "latex": r"j_{0}"}
    },

    "sampler": {
        "polychord": {
            "nlive": 100
        }
    },

    "output": "chains/P21/PPHz_21"
}

info_post_PPHz21 = {
    "output": "chains/P21/PPHz_21",
    "post": {
        "skip_samples": 0.3,
        "suffix": "_post"
    }
}

# %%
_, sampler_PPHz_21 = run_cobaya(info_PPHz21, info_post_PPHz21)
# Out:
# ----- INICIANDO SAMPLER -----
# [output] Output to be read-from/written-into folder 'chains/P21', with prefix 'PPHz_21'
# [lnlikehz] Initialized external likelihood.
# [polychord] `pypolychord` module loaded successfully from /home/nirk20/jupyter_venv/lib/python3.12/site-packages/pypolychord
# [polychord] Storing raw PolyChord output in 'chains/P21/PPHz_21_polychord_raw'.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {lnlikehz: 57.3}
# [polychord] Parameter blocks and their oversampling factors:
# [polychord] * 1 : ['M', 'h0', 'q0', 'j0']
# [polychord] Calling PolyChord...
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     100
# nDims    :       4
# nDerived :       2
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/P21/PPHz_21_polychord_raw/PPHz_21.resume
#
# generating live points
#
#
# all live points generated
#
# number of repeats:            8
# started sampling
#
# ________________
# lives      |100 |
# phantoms   |  7 |
# posteriors |901 |
# equals     |  3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 901
# nposterior =                 901
# nequals    =                   3
# nlike      =                1021
# <nlike>    =           0.21   (           0.03 per slice )
# log(Z)     =         -768.85 +/-  0.46
# log(Z_1)   =         -768.85 +/-  0.46 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 473 |
# posteriors |1002 |
# equals     |   6 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1002
# nposterior =                1002
# nequals    =                   5
# nlike      =                3405
# <nlike>    =          23.84   (           2.98 per slice )
# log(Z)     =         -742.62 +/-  0.34
# log(Z_1)   =         -742.62 +/-  0.34 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 681 |
# posteriors |1103 |
# equals     |   8 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1103
# nposterior =                1103
# nequals    =                   8
# nlike      =                6093
# <nlike>    =          26.88   (           3.36 per slice )
# log(Z)     =         -728.68 +/-  0.25
# log(Z_1)   =         -728.68 +/-  0.25 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 756 |
# posteriors |1204 |
# equals     |  32 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1204
# nposterior =                1204
# nequals    =                  28
# nlike      =                9049
# <nlike>    =          29.56   (           3.69 per slice )
# log(Z)     =         -722.80 +/-  0.21
# log(Z_1)   =         -722.80 +/-  0.21 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 765 |
# posteriors |1305 |
# equals     |  54 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1305
# nposterior =                1305
# nequals    =                  48
# nlike      =               12095
# <nlike>    =          30.46   (           3.81 per slice )
# log(Z)     =         -720.08 +/-  0.21
# log(Z_1)   =         -720.08 +/-  0.21 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 745 |
# posteriors |1406 |
# equals     | 108 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1406
# nposterior =                1406
# nequals    =                  93
# nlike      =               15202
# <nlike>    =          31.07   (           3.88 per slice )
# log(Z)     =         -718.56 +/-  0.22
# log(Z_1)   =         -718.56 +/-  0.22 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 744 |
# posteriors |1507 |
# equals     | 200 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1507
# nposterior =                1507
# nequals    =                 182
# nlike      =               18329
# <nlike>    =          31.27   (           3.91 per slice )
# log(Z)     =         -717.87 +/-  0.22
# log(Z_1)   =         -717.87 +/-  0.22 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 716 |
# posteriors |1608 |
# equals     | 270 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1608
# nposterior =                1608
# nequals    =                 254
# nlike      =               21433
# <nlike>    =          31.04   (           3.88 per slice )
# log(Z)     =         -717.56 +/-  0.22
# log(Z_1)   =         -717.56 +/-  0.22 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 733 |
# posteriors |1709 |
# equals     | 309 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1709
# nposterior =                1709
# nequals    =                 305
# nlike      =               24548
# <nlike>    =          31.15   (           3.89 per slice )
# log(Z)     =         -717.43 +/-  0.23
# log(Z_1)   =         -717.43 +/-  0.23 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 733 |
# posteriors |1810 |
# equals     | 322 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1810
# nposterior =                1810
# nequals    =                 324
# nlike      =               27603
# <nlike>    =          30.55   (           3.82 per slice )
# log(Z)     =         -717.37 +/-  0.23
# log(Z_1)   =         -717.37 +/-  0.23 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 750 |
# posteriors |1911 |
# equals     | 327 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1911
# nposterior =                1911
# nequals    =                 334
# nlike      =               30718
# <nlike>    =          31.15   (           3.89 per slice )
# log(Z)     =         -717.35 +/-  0.23
# log(Z_1)   =         -717.35 +/-  0.23 (still evaluating)
#
#
#
# _________________________________________
# lives      |  60 |  19 |   6 |   7 |   8 |
# phantoms   | 448 | 158 |  35 |  71 |  71 |
# posteriors |1976 |1927 |1917 |1917 |1924 |
# equals     | 328 | 327 | 327 | 327 | 328 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       5 /       5
# ndead      =                2017
# nposterior =                2017
# nequals    =                 336
# nlike      =               37057
# <nlike>    =          63.39   (           7.92 per slice )
# log(Z)     =         -717.34 +/-  0.23
# log(Z_1)   =         -717.88 +/-  0.23 (still evaluating)
# log(Z_2)   =         -719.07 +/-  0.24 (still evaluating)
# log(Z_3)   =         -719.65 +/-  0.25 (still evaluating)
# log(Z_4)   =         -719.89 +/-  0.26 (still evaluating)
# log(Z_5)   =         -720.14 +/-  0.26 (still evaluating)
#
#
#
# _______________________________________________
# lives      |  48 |  21 |   9 |  13 |   7 |   2 |
# phantoms   | 434 | 198 |  54 | 115 |  66 |  22 |
# posteriors |2051 |1941 |1922 |1929 |1925 |1919 |
# equals     | 328 | 328 | 327 | 328 | 327 | 327 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       6 /       6
# ndead      =                2126
# nposterior =                2126
# nequals    =                 337
# nlike      =               43413
# <nlike>    =          63.56   (           7.95 per slice )
# log(Z)     =         -717.34 +/-  0.23
# log(Z_1)   =         -717.88 +/-  0.23 (still evaluating)
# log(Z_2)   =         -719.06 +/-  0.24 (still evaluating)
# log(Z_3)   =         -719.65 +/-  0.25 (still evaluating)
# log(Z_4)   =         -720.14 +/-  0.26 (still evaluating)
# log(Z_5)   =         -720.55 +/-  0.29 (still evaluating)
# log(Z_6)   =         -720.63 +/-  0.30 (still evaluating)
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =         2290                              |
# | log(Z) =         -717.33457 +/-            0.22721 |
# |____________________________________________________|
# [polychord] Loading PolyChord's results: samples and evidences.
# [polychord] Finished! Raw PolyChord output stored in 'chains/P21/PPHz_21_polychord_raw', with prefix 'PPHz_21'
# [polychord] log(Z) = -717.743 +/- 0.227208 ; Z in [1.5464776e-312, 2.4360941e-312] (68% C.L. log-gaussian)
# ----- RETIRANDO O INICIO -----
# [output] Output to be read-from/written-into folder 'chains/P21', with prefix 'PPHz_21'
# [output] Found existing info files with the requested output prefix: 'chains/P21/PPHz_21'
# [samplecollection] Loaded 2093 sample points from 'chains/P21/PPHz_21.1.txt'
# [post] Will process 2093 sample points.
# [output] Output to be read-from/written-into folder 'chains/P21', with prefix 'PPHz_21.post._post'
# [post] Running post-processing...
# [post]  |--------------------|   0%  (0/2093)
# [post]  |@-------------------|   5%  (95/2093)
# [post]  |@@------------------|  10%  (199/2093)
# [post]  |@@@-----------------|  15%  (304/2093)
# [post]  |@@@@----------------|  20%  (409/2093)
# [post]  |@@@@@---------------|  25%  (513/2093)
# [post]  |@@@@@@--------------|  30%  (618/2093)
# [post]  |@@@@@@@-------------|  35%  (723/2093)
# [post]  |@@@@@@@@------------|  40%  (827/2093)
# [post]  |@@@@@@@@@-----------|  45%  (932/2093)
# [post]  |@@@@@@@@@@----------|  50%  (1037/2093)
# [post]  |@@@@@@@@@@@---------|  55%  (1141/2093)
# [post]  |@@@@@@@@@@@@--------|  60%  (1246/2093)
# [post]  |@@@@@@@@@@@@@-------|  65%  (1350/2093)
# [post]  |@@@@@@@@@@@@@@------|  70%  (1455/2093)
# [post]  |@@@@@@@@@@@@@@@-----|  75%  (1560/2093)
# [post]  |@@@@@@@@@@@@@@@@----|  80%  (1664/2093)
# [post]  |@@@@@@@@@@@@@@@@@---|  85%  (1769/2093)
# [post]  |@@@@@@@@@@@@@@@@@@--|  90%  (1874/2093)
# [post]  |@@@@@@@@@@@@@@@@@@@-|  95%  (1978/2093)
# [post]  |@@@@@@@@@@@@@@@@@@@@| 100%  (2083/2093)
# [post] Finished! Final number of distinct sample points: 2093
# [post] Importance weight range: 1 -- 1
# [post] Effective number of single samples if independent (sum w)/max(w): 318
# [post] Effective number of weighted samples if independent (sum w)^2/sum(w^2): 483
# Tempo de execução: 306.35561084747314 s

# %% [markdown]
# ### P22

# %%
parlabels_22 = ["M","H_0",'q_0','j_0', 's_0']
parlabtex_22 = ["$M$","$H_0$",'$q_0$','$j_0$', '$s_0$']
parnames_22 = ['M','H0','q0','j0', 's0']
par0_22=[-19.2, 73.03398760350208, -0.5280171275112104, 1, 4]
ndim_22 = len(par0_22)

# %% [markdown]
# #### CC+SH0ES+Pantheon+

# %%
par_mlHzPS_22 = par0_22

# %%
resultHzPS_22 = find_bestfit(getpar_PSHz_22, parnames_22, par_mlHzPS_22)
par_mlHzPS_22 = resultHzPS_22['x']
print('\n',par_mlHzPS_22,'\n')
print(resultHzPS_22,'\n')
# Out:
# /home/nirk20/jupyter_venv/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:596: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0
# /home/nirk20/jupyter_venv/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:596: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0
# Maximum likelihood result:
# M  =  -19.23608617349228
# H0  =  6.492175289974673
# q0  =  -0.4960879698744289
# j0  =  1.606348009931004
# s0  =  3.785090874213947
# chi2min = 1844.942526901966
# tempo total: 8.923 seg
#
#  [-19.23608617   6.49217529  -0.49608797   1.60634801   3.78509087]
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1844.942526901966
#              x: [-1.924e+01  6.492e+00 -4.961e-01  1.606e+00  3.785e+00]
#            nit: 826
#           nfev: 1323
#  final_simplex: (array([[-1.924e+01,  6.492e+00, ...,  1.606e+00,
#                          3.785e+00],
#                        [-1.924e+01,  6.492e+00, ...,  1.606e+00,
#                          3.785e+00],
#                        ...,
#                        [-1.924e+01,  6.492e+00, ...,  1.606e+00,
#                          3.785e+00],
#                        [-1.924e+01,  6.492e+00, ...,  1.606e+00,
#                          3.785e+00]], shape=(6, 5)), array([ 1.845e+03,  1.845e+03,  1.845e+03,  1.845e+03,
#                         1.845e+03,  1.845e+03]))

# %%
info_PSHz22 = {
    "likelihood": {
        "lnlikehz": lnprobPSHz_22
    },

    "params": {
        "M": {"prior": {"min": -19.5, "max": 19.5}, "proposal": par_mlHzPS_22[0], "latex": "M"},
        "h0": {"prior": {"min": 40.0, "max": 100.0}, "proposal": par_mlHzPS_22[1], "latex": r"H_{0}"},
        "q0": {"prior": {"min": -2, "max": 2}, "proposal": par_mlHzPS_22[2], "latex": r"q_{0}"},
        "j0": {"prior": {"min": -5, "max": 5}, "proposal": par_mlHzPS_22[3], "latex": r"j_{0}"},
        "s0": {"prior": {"min": -10, "max": 10}, "proposal": par_mlHzPS_22[4], "latex": r"s_{0}"}
    },

    "sampler": {
        "polychord": {
            "nlive":500
        }
    },

    "output": "chains/P22/PS/PSHz_22"
}

info_post_PSHz22 = {
    "output": "chains/P22/PS/PSHz_22",
    "post": {
        "skip_samples": 0.3,
        "suffix": "_post"
    }
}

# %%
_, sampler_PSHz_22 = run_cobaya(info_PSHz22, info_post_PSHz22)
# Out:
# ----- INICIANDO SAMPLER -----
# [output] Output to be read-from/written-into folder 'chains/P22/PS', with prefix 'PSHz_22'
# [lnlikehz] Initialized external likelihood.
# [polychord] `pypolychord` module loaded successfully from /home/nirk20/jupyter_venv/lib/python3.12/site-packages/pypolychord
# [polychord] Storing raw PolyChord output in 'chains/P22/PS/PSHz_22_polychord_raw'.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {lnlikehz: 60.2}
# [polychord] Parameter blocks and their oversampling factors:
# [polychord] * 1 : ['M', 'h0', 'q0', 'j0', 's0']
# [polychord] Calling PolyChord...
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     500
# nDims    :       5
# nDerived :       2
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/P22/PS/PSHz_22_polychord_raw/PSHz_22.resume
#
# generating live points
#
#
# all live points generated
#
# number of repeats:           10
# started sampling
#
# _________________
# lives      | 500 |
# phantoms   |   9 |
# posteriors |4501 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4501
# nposterior =                4501
# nequals    =                   1
# nlike      =                5020
# <nlike>    =           0.04   (           0.00 per slice )
# log(Z)     =      -270280.67 +/-  0.83
# log(Z_1)   =      -270280.67 +/-  0.83 (still evaluating)
#
#
#
# _________________
# lives      | 500 |
# phantoms   |2880 |
# posteriors |5002 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5002
# nposterior =                5002
# nequals    =                   1
# nlike      =               18527
# <nlike>    =          27.01   (           2.70 per slice )
# log(Z)     =       -86830.18 +/-  0.83
# log(Z_1)   =       -86830.18 +/-  0.83 (still evaluating)
#
#
#
# _________________
# lives      | 500 |
# phantoms   |3852 |
# posteriors |5503 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5503
# nposterior =                5503
# nequals    =                   1
# nlike      =               32032
# <nlike>    =          27.01   (           2.70 per slice )
# log(Z)     =       -24993.69 +/-  0.83
# log(Z_1)   =       -24993.69 +/-  0.83 (still evaluating)
#
#
#
# _________________
# lives      | 500 |
# phantoms   |4076 |
# posteriors |6004 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6004
# nposterior =                6004
# nequals    =                   1
# nlike      =               44678
# <nlike>    =          25.29   (           2.53 per slice )
# log(Z)     =        -4439.16 +/-  0.77
# log(Z_1)   =        -4439.16 +/-  0.77 (still evaluating)
#
#
#
# _________________
# lives      | 500 |
# phantoms   |4477 |
# posteriors |6505 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6505
# nposterior =                6505
# nequals    =                   2
# nlike      =               57973
# <nlike>    =          26.59   (           2.66 per slice )
# log(Z)     =        -2040.52 +/-  0.53
# log(Z_1)   =        -2040.52 +/-  0.53 (still evaluating)
#
#
#
# _________________
# lives      | 500 |
# phantoms   |4618 |
# posteriors |7006 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                7006
# nposterior =                7006
# nequals    =                   2
# nlike      =               72578
# <nlike>    =          29.21   (           2.92 per slice )
# log(Z)     =        -1449.27 +/-  0.54
# log(Z_1)   =        -1449.27 +/-  0.54 (still evaluating)
#
#
#
# _________________
# lives      | 500 |
# phantoms   |4713 |
# posteriors |7507 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                7507
# nposterior =                7507
# nequals    =                   4
# nlike      =               88694
# <nlike>    =          32.23   (           3.22 per slice )
# log(Z)     =        -1142.55 +/-  0.45
# log(Z_1)   =        -1142.55 +/-  0.45 (still evaluating)
#
#
#
# _________________
# lives      | 500 |
# phantoms   |4653 |
# posteriors |8008 |
# equals     |   3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                8008
# nposterior =                8008
# nequals    =                   2
# nlike      =              105968
# <nlike>    =          34.55   (           3.45 per slice )
# log(Z)     =         -983.31 +/-  0.44
# log(Z_1)   =         -983.31 +/-  0.44 (still evaluating)
#
#
#
# _________________
# lives      | 500 |
# phantoms   |4619 |
# posteriors |8509 |
# equals     |   9 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                8509
# nposterior =                8509
# nequals    =                   3
# nlike      =              124086
# <nlike>    =          36.24   (           3.62 per slice )
# log(Z)     =         -894.39 +/-  0.31
# log(Z_1)   =         -894.39 +/-  0.31 (still evaluating)
#
#
#
# _________________
# lives      | 500 |
# phantoms   |4397 |
# posteriors |9010 |
# equals     |  12 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                9010
# nposterior =                9010
# nequals    =                  16
# nlike      =              143009
# <nlike>    =          37.85   (           3.78 per slice )
# log(Z)     =         -839.11 +/-  0.24
# log(Z_1)   =         -839.11 +/-  0.24 (still evaluating)
#
#
#
# _________________
# lives      | 500 |
# phantoms   |4553 |
# posteriors |9511 |
# equals     |  32 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                9511
# nposterior =                9511
# nequals    =                  36
# nlike      =              163350
# <nlike>    =          40.68   (           4.07 per slice )
# log(Z)     =         -810.84 +/-  0.20
# log(Z_1)   =         -810.84 +/-  0.20 (still evaluating)
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4350 |
# posteriors |10012 |
# equals     |   46 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               10012
# nposterior =               10012
# nequals    =                  48
# nlike      =              185085
# <nlike>    =          43.47   (           4.35 per slice )
# log(Z)     =         -795.50 +/-  0.18
# log(Z_1)   =         -795.50 +/-  0.18 (still evaluating)
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4342 |
# posteriors |10513 |
# equals     |   84 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               10513
# nposterior =               10513
# nequals    =                  74
# nlike      =              207892
# <nlike>    =          45.61   (           4.56 per slice )
# log(Z)     =         -786.25 +/-  0.18
# log(Z_1)   =         -786.25 +/-  0.18 (still evaluating)
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4574 |
# posteriors |11014 |
# equals     |  108 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               11014
# nposterior =               11014
# nequals    =                  92
# nlike      =              231191
# <nlike>    =          46.60   (           4.66 per slice )
# log(Z)     =         -779.73 +/-  0.18
# log(Z_1)   =         -779.73 +/-  0.18 (still evaluating)
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4668 |
# posteriors |11515 |
# equals     |  122 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               11515
# nposterior =               11515
# nequals    =                 113
# nlike      =              254354
# <nlike>    =          46.33   (           4.63 per slice )
# log(Z)     =         -775.19 +/-  0.18
# log(Z_1)   =         -775.19 +/-  0.18 (still evaluating)
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4653 |
# posteriors |12010 |
# equals     |  136 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =               12015
# nposterior =               12015
# nequals    =                 135
# nlike      =              277662
# <nlike>    =          46.62   (           4.66 per slice )
# log(Z)     =         -771.56 +/-  0.18
# log(Z_1)   =         -771.57 +/-  0.18 (still evaluating)
# log(Z_2)   =         -776.30 +/-  0.52
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4422 |
# posteriors |12511 |
# equals     |  169 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =               12516
# nposterior =               12516
# nequals    =                 158
# nlike      =              300496
# <nlike>    =          45.67   (           4.57 per slice )
# log(Z)     =         -768.40 +/-  0.18
# log(Z_1)   =         -768.40 +/-  0.18 (still evaluating)
# log(Z_2)   =         -776.30 +/-  0.52
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4317 |
# posteriors |13012 |
# equals     |  231 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =               13017
# nposterior =               13017
# nequals    =                 230
# nlike      =              323209
# <nlike>    =          45.43   (           4.54 per slice )
# log(Z)     =         -765.69 +/-  0.19
# log(Z_1)   =         -765.69 +/-  0.19 (still evaluating)
# log(Z_2)   =         -776.30 +/-  0.52
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4447 |
# posteriors |13513 |
# equals     |  320 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =               13518
# nposterior =               13518
# nequals    =                 296
# nlike      =              345800
# <nlike>    =          45.18   (           4.52 per slice )
# log(Z)     =         -763.85 +/-  0.19
# log(Z_1)   =         -763.85 +/-  0.19 (still evaluating)
# log(Z_2)   =         -776.30 +/-  0.52
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4306 |
# posteriors |14014 |
# equals     |  414 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =               14019
# nposterior =               14019
# nequals    =                 389
# nlike      =              368035
# <nlike>    =          44.47   (           4.45 per slice )
# log(Z)     =         -762.45 +/-  0.19
# log(Z_1)   =         -762.45 +/-  0.19 (still evaluating)
# log(Z_2)   =         -776.30 +/-  0.52
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4492 |
# posteriors |14515 |
# equals     |  591 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =               14520
# nposterior =               14520
# nequals    =                 584
# nlike      =              390423
# <nlike>    =          44.78   (           4.48 per slice )
# log(Z)     =         -761.42 +/-  0.20
# log(Z_1)   =         -761.42 +/-  0.20 (still evaluating)
# log(Z_2)   =         -776.30 +/-  0.52
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4511 |
# posteriors |15016 |
# equals     |  843 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =               15021
# nposterior =               15021
# nequals    =                 835
# nlike      =              412383
# <nlike>    =          43.92   (           4.39 per slice )
# log(Z)     =         -760.73 +/-  0.20
# log(Z_1)   =         -760.73 +/-  0.20 (still evaluating)
# log(Z_2)   =         -776.30 +/-  0.52
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4638 |
# posteriors |15517 |
# equals     | 1226 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =               15522
# nposterior =               15522
# nequals    =                1229
# nlike      =              434193
# <nlike>    =          43.62   (           4.36 per slice )
# log(Z)     =         -760.25 +/-  0.20
# log(Z_1)   =         -760.25 +/-  0.20 (still evaluating)
# log(Z_2)   =         -776.30 +/-  0.52
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4602 |
# posteriors |16018 |
# equals     | 1711 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =               16023
# nposterior =               16023
# nequals    =                1714
# nlike      =              456182
# <nlike>    =          43.98   (           4.40 per slice )
# log(Z)     =         -759.92 +/-  0.20
# log(Z_1)   =         -759.92 +/-  0.20 (still evaluating)
# log(Z_2)   =         -776.30 +/-  0.52
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4860 |
# posteriors |16519 |
# equals     | 2184 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =               16524
# nposterior =               16524
# nequals    =                2197
# nlike      =              478121
# <nlike>    =          43.88   (           4.39 per slice )
# log(Z)     =         -759.67 +/-  0.20
# log(Z_1)   =         -759.67 +/-  0.20 (still evaluating)
# log(Z_2)   =         -776.30 +/-  0.52
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4532 |
# posteriors |17020 |
# equals     | 2643 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =               17025
# nposterior =               17025
# nequals    =                2660
# nlike      =              499673
# <nlike>    =          43.10   (           4.31 per slice )
# log(Z)     =         -759.49 +/-  0.21
# log(Z_1)   =         -759.49 +/-  0.21 (still evaluating)
# log(Z_2)   =         -776.30 +/-  0.52
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4630 |
# posteriors |17521 |
# equals     | 3038 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =               17526
# nposterior =               17526
# nequals    =                3057
# nlike      =              521228
# <nlike>    =          43.11   (           4.31 per slice )
# log(Z)     =         -759.35 +/-  0.21
# log(Z_1)   =         -759.35 +/-  0.21 (still evaluating)
# log(Z_2)   =         -776.30 +/-  0.52
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4936 |
# posteriors |18022 |
# equals     | 3294 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =               18027
# nposterior =               18027
# nequals    =                3323
# nlike      =              542924
# <nlike>    =          43.39   (           4.34 per slice )
# log(Z)     =         -759.27 +/-  0.21
# log(Z_1)   =         -759.27 +/-  0.21 (still evaluating)
# log(Z_2)   =         -776.30 +/-  0.52
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4762 |
# posteriors |18523 |
# equals     | 3453 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =               18528
# nposterior =               18528
# nequals    =                3492
# nlike      =              564488
# <nlike>    =          43.13   (           4.31 per slice )
# log(Z)     =         -759.22 +/-  0.21
# log(Z_1)   =         -759.22 +/-  0.21 (still evaluating)
# log(Z_2)   =         -776.30 +/-  0.52
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4713 |
# posteriors |19024 |
# equals     | 3554 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =               19029
# nposterior =               19029
# nequals    =                3583
# nlike      =              585996
# <nlike>    =          43.02   (           4.30 per slice )
# log(Z)     =         -759.19 +/-  0.21
# log(Z_1)   =         -759.19 +/-  0.21 (still evaluating)
# log(Z_2)   =         -776.30 +/-  0.52
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4637 |
# posteriors |19525 |
# equals     | 3606 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =               19530
# nposterior =               19530
# nequals    =                3632
# nlike      =              608501
# <nlike>    =          45.01   (           4.50 per slice )
# log(Z)     =         -759.18 +/-  0.21
# log(Z_1)   =         -759.18 +/-  0.21 (still evaluating)
# log(Z_2)   =         -776.30 +/-  0.52
#
#
#
# __________________
# lives      |  500 |
# phantoms   | 4523 |
# posteriors |20026 |
# equals     | 3632 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =               20031
# nposterior =               20031
# nequals    =                3652
# nlike      =              633006
# <nlike>    =          49.01   (           4.90 per slice )
# log(Z)     =         -759.17 +/-  0.21
# log(Z_1)   =         -759.17 +/-  0.21 (still evaluating)
# log(Z_2)   =         -776.30 +/-  0.52
#
#
#
# _________________________
# lives      |  496 |    4 |
# phantoms   | 4390 |   48 |
# posteriors |20523 |20031 |
# equals     | 3642 | 3633 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       3
# ndead      =               20533
# nposterior =               20533
# nequals    =                3665
# nlike      =              659783
# <nlike>    =          53.55   (           5.36 per slice )
# log(Z)     =         -759.17 +/-  0.21
# log(Z_1)   =         -759.18 +/-  0.21 (still evaluating)
# log(Z_2)   =         -763.52 +/-  0.24 (still evaluating)
# log(Z_3)   =         -776.30 +/-  0.52
#
#
#
# ________________________________
# lives      |    5 |  493 |    2 |
# phantoms   |   73 | 4374 |   48 |
# posteriors |20037 |21013 |20531 |
# equals     | 3633 | 3646 | 3642 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       4
# ndead      =               21037
# nposterior =               21037
# nequals    =                3668
# nlike      =              689255
# <nlike>    =          58.94   (           5.89 per slice )
# log(Z)     =         -759.17 +/-  0.21
# log(Z_1)   =         -759.19 +/-  0.21 (still evaluating)
# log(Z_2)   =         -763.52 +/-  0.24 (still evaluating)
# log(Z_3)   =         -763.87 +/-  0.26 (still evaluating)
# log(Z_4)   =         -776.30 +/-  0.52
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =        21959                              |
# | log(Z) =         -759.16754 +/-            0.20873 |
# |____________________________________________________|
# [polychord] Loading PolyChord's results: samples and evidences.
# [polychord] Finished! Raw PolyChord output stored in 'chains/P22/PS/PSHz_22_polychord_raw', with prefix 'PSHz_22'
# [polychord] log(Z) = -759.539 +/- 0.208734 ; Z in [0, 0] (68% C.L. log-gaussian)
# ----- RETIRANDO O INICIO -----
# [output] Output to be read-from/written-into folder 'chains/P22/PS', with prefix 'PSHz_22'
# [output] Found existing info files with the requested output prefix: 'chains/P22/PS/PSHz_22'
# [samplecollection] Loaded 15036 sample points from 'chains/P22/PS/PSHz_22.1.txt'
# [post] Will process 15036 sample points.
# [output] Output to be read-from/written-into folder 'chains/P22/PS', with prefix 'PSHz_22.post._post'
# [post] Running post-processing...
# [post]  |--------------------|   0%  (0/15036)
# [post]  |@-------------------|   5%  (677/15036)
# [post]  |@@------------------|  10%  (1429/15036)
# [post]  |@@@-----------------|  15%  (2181/15036)
# [post]  |@@@@----------------|  20%  (2933/15036)
# [post]  |@@@@@---------------|  25%  (3684/15036)
# [post]  |@@@@@@--------------|  30%  (4436/15036)
# [post]  |@@@@@@@-------------|  35%  (5188/15036)
# [post]  |@@@@@@@@------------|  40%  (5940/15036)
# [post]  |@@@@@@@@@-----------|  45%  (6692/15036)
# [post]  |@@@@@@@@@@----------|  50%  (7443/15036)
# [post]  |@@@@@@@@@@@---------|  55%  (8195/15036)
# [post]  |@@@@@@@@@@@@--------|  60%  (8947/15036)
# [post]  |@@@@@@@@@@@@@-------|  65%  (9699/15036)
# [post]  |@@@@@@@@@@@@@@------|  70%  (10451/15036)
# [post]  |@@@@@@@@@@@@@@@-----|  75%  (11202/15036)
# [post]  |@@@@@@@@@@@@@@@@----|  80%  (11954/15036)
# [post]  |@@@@@@@@@@@@@@@@@---|  85%  (12706/15036)
# [post]  |@@@@@@@@@@@@@@@@@@--|  90%  (13458/15036)
# [post]  |@@@@@@@@@@@@@@@@@@@-|  95%  (14210/15036)
# [post]  |@@@@@@@@@@@@@@@@@@@@| 100%  (14961/15036)
# [post] Finished! Final number of distinct sample points: 15036
# [post] Importance weight range: 0.9999 -- 1
# [post] Effective number of single samples if independent (sum w)/max(w): 3649
# [post] Effective number of weighted samples if independent (sum w)^2/sum(w^2): 4859
# Tempo de execução: 4903.410222053528 s

# %% [markdown]
# #### CC+Pantheon+

# %%
par_mlHzPP_22 = par0_22

# %%
resultHzPP_22 = find_bestfit(getpar_PPHz_22, parnames_22, par_mlHzPP_22)
par_mlHzPP_22 = resultHzPP_22['x']
print('\n',par_mlHzPP_22,'\n')
print(resultHzPP_22,'\n')
# Out:
# Maximum likelihood result:
# M  =  -63.140614053537604
# H0  =  73.27558007430063
# q0  =  -0.6878727916300897
# j0  =  3.483492079808695
# s0  =  9.088470921766225
# chi2min = 1432.0007735232118
# tempo total: 3.758 seg
#
#  [-63.14061405  73.27558007  -0.68787279   3.48349208   9.08847092]
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1432.0007735232118
#              x: [-6.314e+01  7.328e+01 -6.879e-01  3.483e+00  9.088e+00]
#            nit: 213
#           nfev: 379
#  final_simplex: (array([[-6.314e+01,  7.328e+01, ...,  3.483e+00,
#                          9.088e+00],
#                        [-6.314e+01,  7.328e+01, ...,  3.483e+00,
#                          9.088e+00],
#                        ...,
#                        [-6.314e+01,  7.328e+01, ...,  3.483e+00,
#                          9.088e+00],
#                        [-6.314e+01,  7.328e+01, ...,  3.483e+00,
#                          9.088e+00]], shape=(6, 5)), array([ 1.432e+03,  1.432e+03,  1.432e+03,  1.432e+03,
#                         1.432e+03,  1.432e+03]))

# %%
info_PPHz22 = {
    "likelihood": {
        "lnlikehz": lnprobPPHz_22
    },

    "params": {
        "M": {"prior": {"min": -19.5, "max": 19.5}, "proposal": par_mlHzPP_22[0], "latex": "M"},
        "h0": {"prior": {"min": 40.0, "max": 100.0}, "proposal": par_mlHzPP_22[1], "latex": r"H_{0}"},
        "q0": {"prior": {"min": -2, "max": 2}, "proposal": par_mlHzPP_22[2], "latex": r"q_{0}"},
        "j0": {"prior": {"min": -5, "max": 5}, "proposal": par_mlHzPP_22[3], "latex": r"j_{0}"},
        "s0": {"prior": {"min": -10, "max": 10}, "proposal": par_mlHzPP_22[4], "latex": r"s_{0}"}
    },

    "sampler": {
        "polychord": {
            "nlive": 100
        }
    },

    "output": "chains/P22/PPHz_22"
}

info_post_PPHz22 = {
    "output": "chains/P22/PPHz_22",
    "post": {
        "skip_samples": 0.3,
        "suffix": "_post"
    }
}

# %%
_, sampler_PPHz_22 = run_cobaya(info_PPHz22, info_post_PPHz22)
# Out:
# ----- INICIANDO SAMPLER -----
# [output] Output to be read-from/written-into folder 'chains/P22', with prefix 'PPHz_22'
# [lnlikehz] Initialized external likelihood.
# [polychord] `pypolychord` module loaded successfully from /home/nirk20/jupyter_venv/lib/python3.12/site-packages/pypolychord
# [polychord] Storing raw PolyChord output in 'chains/P22/PPHz_22_polychord_raw'.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {lnlikehz: 135.0}
# [polychord] Parameter blocks and their oversampling factors:
# [polychord] * 1 : ['M', 'h0', 'q0', 'j0', 's0']
# [polychord] Calling PolyChord...
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     100
# nDims    :       5
# nDerived :       2
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/P22/PPHz_22_polychord_raw/PPHz_22.resume
#
# generating live points
#
#
# all live points generated
#
# number of repeats:           10
# started sampling
#
# ________________
# lives      |100 |
# phantoms   |  9 |
# posteriors |901 |
# equals     |  7 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 901
# nposterior =                 901
# nequals    =                   6
# nlike      =                1020
# <nlike>    =           0.20   (           0.02 per slice )
# log(Z)     =         -776.80 +/-  0.35
# log(Z_1)   =         -776.80 +/-  0.35 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 545 |
# posteriors |1002 |
# equals     |   6 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1002
# nposterior =                1002
# nequals    =                   3
# nlike      =                3951
# <nlike>    =          29.31   (           2.93 per slice )
# log(Z)     =         -750.35 +/-  0.32
# log(Z_1)   =         -750.35 +/-  0.32 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 768 |
# posteriors |1103 |
# equals     |  16 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1103
# nposterior =                1103
# nequals    =                  10
# nlike      =                7293
# <nlike>    =          33.42   (           3.34 per slice )
# log(Z)     =         -739.17 +/-  0.25
# log(Z_1)   =         -739.17 +/-  0.25 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 824 |
# posteriors |1204 |
# equals     |  28 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1204
# nposterior =                1204
# nequals    =                  29
# nlike      =               10593
# <nlike>    =          33.00   (           3.30 per slice )
# log(Z)     =         -731.55 +/-  0.23
# log(Z_1)   =         -731.55 +/-  0.23 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 845 |
# posteriors |1305 |
# equals     |  43 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1305
# nposterior =                1305
# nequals    =                  43
# nlike      =               13996
# <nlike>    =          34.03   (           3.40 per slice )
# log(Z)     =         -727.99 +/-  0.22
# log(Z_1)   =         -727.99 +/-  0.22 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 900 |
# posteriors |1406 |
# equals     |  89 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1406
# nposterior =                1406
# nequals    =                  88
# nlike      =               17597
# <nlike>    =          36.01   (           3.60 per slice )
# log(Z)     =         -726.33 +/-  0.22
# log(Z_1)   =         -726.33 +/-  0.22 (still evaluating)
#
#
#
# _________________
# lives      | 100 |
# phantoms   | 785 |
# posteriors |1507 |
# equals     | 151 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1507
# nposterior =                1507
# nequals    =                 144
# nlike      =               21288
# <nlike>    =          36.91   (           3.69 per slice )
# log(Z)     =         -725.46 +/-  0.22
# log(Z_1)   =         -725.46 +/-  0.22 (still evaluating)
#
#
#
# _____________________________
# lives      |  54 |  38 |   8 |
# phantoms   | 527 | 331 |  27 |
# posteriors |1598 |1515 |1507 |
# equals     | 207 | 150 | 151 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       3
# ndead      =                1606
# nposterior =                1606
# nequals    =                 216
# nlike      =               25343
# <nlike>    =          40.55   (           4.05 per slice )
# log(Z)     =         -724.98 +/-  0.23
# log(Z_1)   =         -725.16 +/-  0.23 (still evaluating)
# log(Z_2)   =         -726.90 +/-  0.24 (still evaluating)
# log(Z_3)   =         -729.22 +/-  0.31 (still evaluating)
#
#
#
# _______________________
# lives      |  80 |  20 |
# phantoms   | 734 | 162 |
# posteriors |1529 |1507 |
# equals     | 161 | 151 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       4
# ndead      =                1697
# nposterior =                1697
# nequals    =                 270
# nlike      =               30302
# <nlike>    =          49.59   (           4.96 per slice )
# log(Z)     =         -724.75 +/-  0.23
# log(Z_1)   =         -725.34 +/-  0.24
# log(Z_2)   =         -726.00 +/-  0.24
# log(Z_3)   =         -726.68 +/-  0.25 (still evaluating)
# log(Z_4)   =         -729.22 +/-  0.31 (still evaluating)
#
#
#
# _______________________
# lives      |  79 |  21 |
# phantoms   | 684 | 169 |
# posteriors |1611 |1526 |
# equals     | 123 |  74 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       4
# ndead      =                1798
# nposterior =                1798
# nequals    =                 171
# nlike      =               35194
# <nlike>    =          48.92   (           4.89 per slice )
# log(Z)     =         -724.38 +/-  0.24
# log(Z_1)   =         -725.34 +/-  0.24
# log(Z_2)   =         -725.48 +/-  0.28 (still evaluating)
# log(Z_3)   =         -726.00 +/-  0.24
# log(Z_4)   =         -726.96 +/-  0.37 (still evaluating)
#
#
#
# _______________________
# lives      |  79 |  21 |
# phantoms   | 819 | 204 |
# posteriors |1688 |1552 |
# equals     | 156 |  96 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       4
# ndead      =                1901
# nposterior =                1901
# nequals    =                 235
# nlike      =               40542
# <nlike>    =          53.48   (           5.35 per slice )
# log(Z)     =         -723.93 +/-  0.26
# log(Z_1)   =         -724.64 +/-  0.29 (still evaluating)
# log(Z_2)   =         -725.34 +/-  0.24
# log(Z_3)   =         -725.99 +/-  0.35 (still evaluating)
# log(Z_4)   =         -726.00 +/-  0.24
#
#
#
# _______________________
# lives      |  80 |  20 |
# phantoms   | 738 | 176 |
# posteriors |1772 |1570 |
# equals     | 184 |  82 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       4
# ndead      =                2003
# nposterior =                2003
# nequals    =                 265
# nlike      =               45552
# <nlike>    =          50.10   (           5.01 per slice )
# log(Z)     =         -723.59 +/-  0.27
# log(Z_1)   =         -724.11 +/-  0.30 (still evaluating)
# log(Z_2)   =         -725.34 +/-  0.24
# log(Z_3)   =         -725.57 +/-  0.36 (still evaluating)
# log(Z_4)   =         -726.00 +/-  0.24
#
#
#
# _______________________
# lives      |  74 |  26 |
# phantoms   | 771 | 238 |
# posteriors |1854 |1589 |
# equals     | 235 |  95 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       4
# ndead      =                2104
# nposterior =                2104
# nequals    =                 322
# nlike      =               50877
# <nlike>    =          53.25   (           5.33 per slice )
# log(Z)     =         -723.26 +/-  0.28
# log(Z_1)   =         -723.69 +/-  0.31 (still evaluating)
# log(Z_2)   =         -725.18 +/-  0.39 (still evaluating)
# log(Z_3)   =         -725.34 +/-  0.24
# log(Z_4)   =         -726.00 +/-  0.24
#
#
#
# _____________________________
# lives      |  21 |  55 |  24 |
# phantoms   | 191 | 475 | 211 |
# posteriors |1619 |1907 |1874 |
# equals     | 120 | 275 | 250 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       5
# ndead      =                2207
# nposterior =                2207
# nequals    =                 399
# nlike      =               56188
# <nlike>    =          53.11   (           5.31 per slice )
# log(Z)     =         -723.05 +/-  0.29
# log(Z_1)   =         -723.78 +/-  0.32 (still evaluating)
# log(Z_2)   =         -724.75 +/-  0.33 (still evaluating)
# log(Z_3)   =         -724.83 +/-  0.41 (still evaluating)
# log(Z_4)   =         -725.34 +/-  0.24
# log(Z_5)   =         -726.00 +/-  0.24
#
#
#
# _____________________________
# lives      |  21 |  56 |  23 |
# phantoms   | 211 | 446 | 209 |
# posteriors |1645 |1961 |1897 |
# equals     | 135 | 319 | 269 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       5
# ndead      =                2310
# nposterior =                2310
# nequals    =                 469
# nlike      =               61114
# <nlike>    =          49.26   (           4.93 per slice )
# log(Z)     =         -722.89 +/-  0.30
# log(Z_1)   =         -723.61 +/-  0.33 (still evaluating)
# log(Z_2)   =         -724.55 +/-  0.33 (still evaluating)
# log(Z_3)   =         -724.62 +/-  0.43 (still evaluating)
# log(Z_4)   =         -725.34 +/-  0.24
# log(Z_5)   =         -726.00 +/-  0.24
#
#
#
# ___________________________________
# lives      |  20 |  67 |  11 |   2 |
# phantoms   | 192 | 729 | 176 |  40 |
# posteriors |1664 |2027 |1911 |1902 |
# equals     | 132 | 375 | 163 | 206 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       4 /       6
# ndead      =                2414
# nposterior =                2414
# nequals    =                 284
# nlike      =               66795
# <nlike>    =          56.81   (           5.68 per slice )
# log(Z)     =         -722.70 +/-  0.30
# log(Z_1)   =         -723.39 +/-  0.34 (still evaluating)
# log(Z_2)   =         -724.46 +/-  0.44 (still evaluating)
# log(Z_3)   =         -724.55 +/-  0.35 (still evaluating)
# log(Z_4)   =         -725.34 +/-  0.24
# log(Z_5)   =         -725.85 +/-  0.38 (still evaluating)
# log(Z_6)   =         -726.00 +/-  0.24
#
#
#
# ___________________________________
# lives      |  23 |  64 |   8 |   5 |
# phantoms   | 207 | 675 | 149 |  67 |
# posteriors |1685 |2095 |1922 |1905 |
# equals     | 149 | 429 | 156 | 128 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       4 /       6
# ndead      =                2517
# nposterior =                2517
# nequals    =                 300
# nlike      =               72321
# <nlike>    =          55.26   (           5.53 per slice )
# log(Z)     =         -722.54 +/-  0.31
# log(Z_1)   =         -723.22 +/-  0.35 (still evaluating)
# log(Z_2)   =         -724.30 +/-  0.46 (still evaluating)
# log(Z_3)   =         -724.34 +/-  0.36 (still evaluating)
# log(Z_4)   =         -725.34 +/-  0.24
# log(Z_5)   =         -725.65 +/-  0.40 (still evaluating)
# log(Z_6)   =         -726.00 +/-  0.24
#
#
#
# ___________________________________
# lives      |  26 |  54 |  16 |   4 |
# phantoms   | 256 | 624 | 164 |  67 |
# posteriors |1714 |2160 |1931 |1909 |
# equals     | 169 | 475 | 153 | 131 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       4 /       6
# ndead      =                2624
# nposterior =                2624
# nequals    =                 308
# nlike      =               78206
# <nlike>    =          58.85   (           5.88 per slice )
# log(Z)     =         -722.42 +/-  0.32
# log(Z_1)   =         -723.09 +/-  0.35 (still evaluating)
# log(Z_2)   =         -724.15 +/-  0.48 (still evaluating)
# log(Z_3)   =         -724.22 +/-  0.38 (still evaluating)
# log(Z_4)   =         -725.34 +/-  0.24
# log(Z_5)   =         -725.49 +/-  0.42 (still evaluating)
# log(Z_6)   =         -726.00 +/-  0.24
#
#
#
# ___________________________________
# lives      |  13 |  62 |  15 |  10 |
# phantoms   | 194 | 575 | 194 | 107 |
# posteriors |1745 |2209 |1948 |1914 |
# equals     | 186 | 509 | 159 | 134 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       4 /       6
# ndead      =                2726
# nposterior =                2726
# nequals    =                 336
# nlike      =               84248
# <nlike>    =          60.42   (           6.04 per slice )
# log(Z)     =         -722.33 +/-  0.32
# log(Z_1)   =         -723.02 +/-  0.36 (still evaluating)
# log(Z_2)   =         -724.03 +/-  0.50 (still evaluating)
# log(Z_3)   =         -724.10 +/-  0.39 (still evaluating)
# log(Z_4)   =         -725.38 +/-  0.44 (still evaluating)
# log(Z_5)   =         -725.34 +/-  0.24
# log(Z_6)   =         -726.00 +/-  0.24
#
#
#
# _________________________________________
# lives      |   8 |  58 |   9 |   8 |  17 |
# phantoms   | 127 | 472 | 127 |  83 | 195 |
# posteriors |1763 |2271 |1928 |1957 |1953 |
# equals     | 193 | 533 | 136 | 162 | 160 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       5 /       7
# ndead      =                2834
# nposterior =                2834
# nequals    =                 361
# nlike      =               89383
# <nlike>    =          51.35   (           5.13 per slice )
# log(Z)     =         -722.29 +/-  0.33
# log(Z_1)   =         -722.97 +/-  0.36 (still evaluating)
# log(Z_2)   =         -724.00 +/-  0.50 (still evaluating)
# log(Z_3)   =         -724.49 +/-  0.40 (still evaluating)
# log(Z_4)   =         -725.10 +/-  0.42 (still evaluating)
# log(Z_5)   =         -725.28 +/-  0.47 (still evaluating)
# log(Z_6)   =         -725.34 +/-  0.24
# log(Z_7)   =         -726.00 +/-  0.24
#
#
#
# _________________________________________
# lives      |   4 |  59 |  14 |  12 |  11 |
# phantoms   |  99 | 537 | 159 | 121 | 101 |
# posteriors |1775 |2338 |1932 |1965 |1969 |
# equals     | 197 | 546 | 136 | 163 | 164 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       5 /       7
# ndead      =                2941
# nposterior =                2941
# nequals    =                 368
# nlike      =               94950
# <nlike>    =          55.67   (           5.57 per slice )
# log(Z)     =         -722.26 +/-  0.33
# log(Z_1)   =         -722.95 +/-  0.36 (still evaluating)
# log(Z_2)   =         -723.99 +/-  0.50 (still evaluating)
# log(Z_3)   =         -724.44 +/-  0.41 (still evaluating)
# log(Z_4)   =         -725.08 +/-  0.42 (still evaluating)
# log(Z_5)   =         -725.26 +/-  0.47 (still evaluating)
# log(Z_6)   =         -725.34 +/-  0.24
# log(Z_7)   =         -726.00 +/-  0.24
#
#
#
# _________________________________________
# lives      |   7 |  39 |  22 |   9 |  23 |
# phantoms   |  79 | 374 | 212 |  93 | 219 |
# posteriors |1779 |2407 |1947 |1976 |1980 |
# equals     | 198 | 553 | 137 | 165 | 164 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       5 /       7
# ndead      =                3051
# nposterior =                3051
# nequals    =                 370
# nlike      =              101099
# <nlike>    =          61.49   (           6.15 per slice )
# log(Z)     =         -722.25 +/-  0.33
# log(Z_1)   =         -722.93 +/-  0.36 (still evaluating)
# log(Z_2)   =         -723.99 +/-  0.51 (still evaluating)
# log(Z_3)   =         -724.42 +/-  0.41 (still evaluating)
# log(Z_4)   =         -725.06 +/-  0.42 (still evaluating)
# log(Z_5)   =         -725.23 +/-  0.48 (still evaluating)
# log(Z_6)   =         -725.34 +/-  0.24
# log(Z_7)   =         -726.00 +/-  0.24
#
#
#
# _________________________________________________________________
# lives      |  35 |   2 |   4 |   8 |  10 |   5 |   9 |   9 |  18 |
# phantoms   | 403 |  17 |  51 |  92 |  78 |  81 |  88 |  80 | 166 |
# posteriors |2452 |1781 |1782 |1959 |1961 |1981 |1990 |1988 |1981 |
# equals     | 554 | 198 | 198 | 138 | 137 | 165 | 164 | 164 | 164 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       9 /      13
# ndead      =                3160
# nposterior =                3160
# nequals    =                 376
# nlike      =              106918
# <nlike>    =          58.19   (           5.82 per slice )
# log(Z)     =         -722.24 +/-  0.33
# log(Z_1)   =         -722.93 +/-  0.36 (still evaluating)
# log(Z_2)   =         -724.55 +/-  0.52 (still evaluating)
# log(Z_3)   =         -724.85 +/-  0.52 (still evaluating)
# log(Z_4)   =         -725.26 +/-  0.43 (still evaluating)
# log(Z_5)   =         -725.34 +/-  0.24
# log(Z_6)   =         -725.46 +/-  0.43 (still evaluating)
# log(Z_7)   =         -725.59 +/-  0.43 (still evaluating)
# log(Z_8)   =         -725.94 +/-  0.44 (still evaluating)
# log(Z_9)   =         -725.95 +/-  0.45
# log(Z_10)  =         -726.00 +/-  0.50 (still evaluating)
# log(Z_11)  =         -726.06 +/-  0.50 (still evaluating)
# log(Z_12)  =         -726.00 +/-  0.24
# log(Z_13)  =         -727.32 +/-  0.53
#
#
#
# ___________________________________________________________________________________
# lives      |   4 |   9 |   1 |   4 |  13 |  11 |  21 |  16 |   7 |   1 |   7 |   6 |
# phantoms   |  44 |  72 |  14 |  39 |  86 | 142 | 220 | 182 |  63 |   8 |  69 |  87 |
# posteriors |1783 |1782 |1980 |1987 |1999 |2000 |2473 |2474 |1966 |1963 |1992 |1991 |
# equals     | 198 | 198 | 137 | 165 | 164 | 164 | 554 | 556 | 138 | 138 | 164 | 164 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =      12 /      16
# ndead      =                3276
# nposterior =                3276
# nequals    =                 377
# nlike      =              112914
# <nlike>    =          59.96   (           6.00 per slice )
# log(Z)     =         -722.24 +/-  0.33
# log(Z_1)   =         -723.61 +/-  0.37 (still evaluating)
# log(Z_2)   =         -723.62 +/-  0.37 (still evaluating)
# log(Z_3)   =         -724.55 +/-  0.52 (still evaluating)
# log(Z_4)   =         -724.85 +/-  0.52 (still evaluating)
# log(Z_5)   =         -725.34 +/-  0.24
# log(Z_6)   =         -725.45 +/-  0.43 (still evaluating)
# log(Z_7)   =         -725.58 +/-  0.44 (still evaluating)
# log(Z_8)   =         -725.79 +/-  0.44 (still evaluating)
# log(Z_9)   =         -725.92 +/-  0.44 (still evaluating)
# log(Z_10)  =         -725.98 +/-  0.51 (still evaluating)
# log(Z_11)  =         -725.95 +/-  0.45
# log(Z_12)  =         -726.00 +/-  0.24
# log(Z_13)  =         -726.14 +/-  0.45 (still evaluating)
# log(Z_14)  =         -726.48 +/-  0.51 (still evaluating)
# log(Z_15)  =         -727.11 +/-  0.53 (still evaluating)
# log(Z_16)  =         -727.32 +/-  0.53
#
#
#
# _____________________________________________________________________________________________________
# lives      |   2 |  11 |   2 |   8 |  11 |   4 |  10 |   5 |   5 |  11 |   5 |   6 |   2 |  12 |   6 |
# phantoms   |  38 | 119 |  23 |  93 |  86 |  36 | 114 |  48 |  51 | 116 |  42 |  59 |  28 | 102 |  77 |
# posteriors |1789 |1791 |1993 |2014 |1973 |1998 |1999 |2008 |2008 |2484 |2474 |2477 |2478 |2479 |2482 |
# equals     | 198 | 198 | 165 | 164 | 138 | 164 | 164 | 164 | 164 | 554 | 554 | 554 | 554 | 556 | 556 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =      15 /      21
# ndead      =                3386
# nposterior =                3386
# nequals    =                 379
# nlike      =              118553
# <nlike>    =          56.39   (           5.64 per slice )
# log(Z)     =         -722.23 +/-  0.33
# log(Z_1)   =         -724.09 +/-  0.37 (still evaluating)
# log(Z_2)   =         -724.27 +/-  0.37 (still evaluating)
# log(Z_3)   =         -724.55 +/-  0.52 (still evaluating)
# log(Z_4)   =         -724.62 +/-  0.38 (still evaluating)
# log(Z_5)   =         -724.85 +/-  0.52 (still evaluating)
# log(Z_6)   =         -725.06 +/-  0.39 (still evaluating)
# log(Z_7)   =         -725.34 +/-  0.24
# log(Z_8)   =         -725.55 +/-  0.41 (still evaluating)
# log(Z_9)   =         -725.58 +/-  0.44 (still evaluating)
# log(Z_10)  =         -725.78 +/-  0.44 (still evaluating)
# log(Z_11)  =         -725.91 +/-  0.44 (still evaluating)
# log(Z_12)  =         -725.98 +/-  0.51
# log(Z_13)  =         -725.95 +/-  0.45
# log(Z_14)  =         -725.97 +/-  0.43 (still evaluating)
# log(Z_15)  =         -726.04 +/-  0.44 (still evaluating)
# log(Z_16)  =         -726.00 +/-  0.24
# log(Z_17)  =         -726.14 +/-  0.45 (still evaluating)
# log(Z_18)  =         -726.25 +/-  0.45 (still evaluating)
# log(Z_19)  =         -726.47 +/-  0.52 (still evaluating)
# log(Z_20)  =         -727.11 +/-  0.53
# log(Z_21)  =         -727.32 +/-  0.53
#
#
#
#  too many L steps (       165)
# _______________________________________________________________________________________________
# lives      |   2 |   2 |   8 |  11 |  17 |   6 |   2 |  11 |   6 |  10 |   5 |   4 |  11 |   5 |
# phantoms   |  25 |  35 |  92 |  80 | 128 |  30 |  33 |  97 |  40 |  78 |  48 |  45 |  63 |  65 |
# posteriors |1793 |1996 |2026 |2003 |2009 |2012 |2015 |2495 |2477 |2484 |2479 |2489 |2484 |2482 |
# equals     | 198 | 165 | 164 | 164 | 164 | 164 | 164 | 554 | 554 | 554 | 554 | 556 | 556 | 556 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =      14 /      22
# ndead      =                3499
# nposterior =                3499
# nequals    =                 380
# nlike      =              124957
# <nlike>    =          64.04   (           6.40 per slice )
# log(Z)     =         -722.23 +/-  0.33
# log(Z_1)   =         -724.27 +/-  0.37 (still evaluating)
# log(Z_2)   =         -724.54 +/-  0.52
# log(Z_3)   =         -724.62 +/-  0.38 (still evaluating)
# log(Z_4)   =         -724.75 +/-  0.39 (still evaluating)
# log(Z_5)   =         -724.84 +/-  0.52 (still evaluating)
# log(Z_6)   =         -724.82 +/-  0.39 (still evaluating)
# log(Z_7)   =         -725.06 +/-  0.39 (still evaluating)
# log(Z_8)   =         -725.34 +/-  0.24
# log(Z_9)   =         -725.55 +/-  0.41 (still evaluating)
# log(Z_10)  =         -725.58 +/-  0.44 (still evaluating)
# log(Z_11)  =         -725.78 +/-  0.44 (still evaluating)
# log(Z_12)  =         -725.91 +/-  0.44 (still evaluating)
# log(Z_13)  =         -725.98 +/-  0.51
# log(Z_14)  =         -725.95 +/-  0.45
# log(Z_15)  =         -725.97 +/-  0.43 (still evaluating)
# log(Z_16)  =         -726.04 +/-  0.44 (still evaluating)
# log(Z_17)  =         -726.00 +/-  0.24
# log(Z_18)  =         -726.13 +/-  0.45 (still evaluating)
# log(Z_19)  =         -726.25 +/-  0.45 (still evaluating)
# log(Z_20)  =         -726.46 +/-  0.52
# log(Z_21)  =         -727.11 +/-  0.53
# log(Z_22)  =         -727.32 +/-  0.53
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =         3610                              |
# | log(Z) =         -722.23248 +/-            0.33067 |
# |____________________________________________________|
# [polychord] Loading PolyChord's results: samples and evidences.
# [polychord] Finished! Raw PolyChord output stored in 'chains/P22/PPHz_22_polychord_raw', with prefix 'PPHz_22'
# [polychord] log(Z) = -722.595 +/- 0.330674 ; Z in [1.0898155e-314, 2.1114127e-314] (68% C.L. log-gaussian)
# ----- RETIRANDO O INICIO -----
# [output] Output to be read-from/written-into folder 'chains/P22', with prefix 'PPHz_22'
# [output] Found existing info files with the requested output prefix: 'chains/P22/PPHz_22'
# [samplecollection] Loaded 3332 sample points from 'chains/P22/PPHz_22.1.txt'
# [post] Will process 3332 sample points.
# [output] Output to be read-from/written-into folder 'chains/P22', with prefix 'PPHz_22.post._post'
# [post] Running post-processing...
# [post]  |--------------------|   0%  (0/3332)
# [post]  |@-------------------|   5%  (150/3332)
# [post]  |@@------------------|  10%  (317/3332)
# [post]  |@@@-----------------|  15%  (484/3332)
# [post]  |@@@@----------------|  20%  (650/3332)
# [post]  |@@@@@---------------|  25%  (817/3332)
# [post]  |@@@@@@--------------|  30%  (983/3332)
# [post]  |@@@@@@@-------------|  35%  (1150/3332)
# [post]  |@@@@@@@@------------|  40%  (1317/3332)
# [post]  |@@@@@@@@@-----------|  45%  (1483/3332)
# [post]  |@@@@@@@@@@----------|  50%  (1650/3332)
# [post]  |@@@@@@@@@@@---------|  55%  (1816/3332)
# [post]  |@@@@@@@@@@@@--------|  60%  (1983/3332)
# [post]  |@@@@@@@@@@@@@-------|  65%  (2150/3332)
# [post]  |@@@@@@@@@@@@@@------|  70%  (2316/3332)
# [post]  |@@@@@@@@@@@@@@@-----|  75%  (2483/3332)
# [post]  |@@@@@@@@@@@@@@@@----|  80%  (2649/3332)
# [post]  |@@@@@@@@@@@@@@@@@---|  85%  (2816/3332)
# [post]  |@@@@@@@@@@@@@@@@@@--|  90%  (2983/3332)
# [post]  |@@@@@@@@@@@@@@@@@@@-|  95%  (3149/3332)
# [post]  |@@@@@@@@@@@@@@@@@@@@| 100%  (3316/3332)
# [post] Finished! Final number of distinct sample points: 3332
# [post] Importance weight range: 0.9999 -- 1
# [post] Effective number of single samples if independent (sum w)/max(w): 385
# [post] Effective number of weighted samples if independent (sum w)^2/sum(w^2): 1258
# Tempo de execução: 939.7551610469818 s

# %% [markdown]
# ### P31

# %% [markdown]
# #### CC+SH0ES+Pantheon+

# %%
par_mlHzPS_31 = par0_22

# %%
resultHzPS_31 = find_bestfit(getpar_PSHz_31, parnames_22, par_mlHzPS_31)
par_mlHzPS_31 = resultHzPS_31['x']
print('\n',par_mlHzPS_31,'\n')
print(resultHzPS_31,'\n')
# Out:
# /home/nirk20/jupyter_venv/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:596: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# Maximum likelihood result:
# M  =  -28.404419746059546
# H0  =  41.50507621952556
# q0  =  -1.5156357687444546
# j0  =  1.5202005587199514
# s0  =  -2.7377241804170707
# chi2min = 100004.2236439458
# tempo total: 1390.853 seg
#
#  [-28.40441975  41.50507622  -1.51563577   1.52020056  -2.73772418]
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 100004.2236439458
#              x: [-2.840e+01  4.151e+01 -1.516e+00  1.520e+00 -2.738e+00]
#            nit: 886
#           nfev: 1540
#  final_simplex: (array([[-2.840e+01,  4.151e+01, ...,  1.520e+00,
#                         -2.738e+00],
#                        [-2.840e+01,  4.151e+01, ...,  1.520e+00,
#                         -2.738e+00],
#                        ...,
#                        [-2.840e+01,  4.151e+01, ...,  1.520e+00,
#                         -2.738e+00],
#                        [-2.840e+01,  4.151e+01, ...,  1.520e+00,
#                         -2.738e+00]], shape=(6, 5)), array([ 1.000e+05,  1.000e+05,  1.000e+05,  1.000e+05,
#                         1.000e+05,  1.000e+05]))

# %%
info_PSHz31 = {
    "likelihood": {
        "lnlikehz": lnprobPSHz_31
    },

    "params": {
        "M": {"prior": {"min": -19.5, "max": 19.5}, "proposal": par_mlHzPS_31[0], "latex": "M"},
        "h0": {"prior": {"min": 40.0, "max": 100.0}, "proposal": par_mlHzPS_31[1], "latex": r"H_{0}"},
        "q0": {"prior": {"min": -2, "max": 2}, "proposal": par_mlHzPS_31[2], "latex": r"q_{0}"},
        "j0": {"prior": {"min": -5, "max": 5}, "proposal": par_mlHzPS_31[3], "latex": r"j_{0}"},
        "s0": {"prior": {"min": -10, "max": 10}, "proposal": par_mlHzPS_31[4], "latex": r"s_{0}"}
    },

    "sampler": {
        "polychord": {
            "nlive": 100
        }
    },

    "output": "chains/P31/PSHz_31"
}

info_post_PSHz31 = {
    "output": "chains/P31/PSHz_31",
    "post": {
        "skip_samples": 0.3,
        "suffix": "_post"
    }
}

# %%
_, sampler_PSHz_31 = run_cobaya(info_PSHz31, info_post_PSHz31)
# Out:
# ----- INICIANDO SAMPLER -----
# [output] Output to be read-from/written-into folder 'chains/P31', with prefix 'PSHz_31'
# [lnlikehz] Initialized external likelihood.
# [polychord] `pypolychord` module loaded successfully from /home/nirk20/jupyter_venv/lib/python3.12/site-packages/pypolychord
# [polychord] Storing raw PolyChord output in 'chains/P31/PSHz_31_polychord_raw'.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {lnlikehz: 0.915}
# [polychord] Parameter blocks and their oversampling factors:
# [polychord] * 1 : ['M', 'h0', 'q0', 'j0', 's0']
# [polychord] Calling PolyChord...
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     100
# nDims    :       5
# nDerived :       2
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/P31/PSHz_31_polychord_raw/PSHz_31.resume
#
# generating live points
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# ...
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
# /tmp/ipykernel_86239/3288264863.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 _, sampler_PSHz_31 = run_cobaya(info_PSHz31, info_post_PSHz31)
#
# Cell In[13], line 25, in run_cobaya(info, info_post)
#      22 t1 = time.time()
#      24 # Roda o sampler
# ---> 25 updated_info, sampler = run(info)
#      27 # Retira o início
#      28 print("----- RETIRANDO O INICIO -----")
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/run.py:146, in run(info_or_yaml_or_file, packages_path, output, debug, stop_at_error, resume, force, minimize, no_mpi, test, override, allow_changes)
#     144                 return updated_info, sampler
#     145             # Run the sampler
# --> 146             sampler.run()
#     147 return updated_info, sampler
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/samplers/polychord/polychord.py:266, in polychord.run(self)
#     264 sync_processes()
#     265 self.mpi_info("Calling PolyChord...")
# --> 266 self.pc.run_polychord(logpost, self.nDims, self.nDerived, self.pc_settings,
#     267                       self.pc_prior, self.dumper)
#     268 self.process_raw_output()
#
# File ~/jupyter_venv/lib/python3.12/site-packages/pypolychord/polychord.py:177, in run_polychord(loglikelihood, nDims, nDerived, settings, prior, dumper)
#     174 settings.nlives = {float(logL):int(nlive) for logL, nlive in settings.nlives.items()}
#     176 # Run polychord from module library
# --> 177 _pypolychord.run(wrap_loglikelihood,
#     178                  wrap_prior,
#     179                  dumper,
#     180                  nDims,
#     181                  nDerived,
#     182                  settings.nlive,
#     183                  settings.num_repeats,
#     184                  settings.nprior,
#     185                  settings.nfail,
#     186                  settings.do_clustering,
#     187                  settings.feedback,
#     188                  settings.precision_criterion,
#     189                  settings.logzero,
#     190                  settings.max_ndead,
#     191                  settings.boost_posterior,
#     192                  settings.posteriors,
#     193                  settings.equals,
#     194                  settings.cluster_posteriors,
#     195                  settings.write_resume,
#     196                  settings.write_paramnames,
#     197                  settings.read_resume,
#     198                  settings.write_stats,
#     199                  settings.write_live,
#     200                  settings.write_dead,
#     201                  settings.write_prior,
#     202                  settings.maximise,
#     203                  settings.compression_factor,
#     204                  settings.synchronous,
#     205                  settings.base_dir,
#     206                  settings.file_root,
#     207                  settings.grade_frac,
#     208                  settings.grade_dims,
#     209                  settings.nlives,
#     210                  settings.seed)
#     212 if settings.cube_samples is not None:
#     213     settings.read_resume = read_resume
#
# File ~/jupyter_venv/lib/python3.12/site-packages/pypolychord/polychord.py:163, in run_polychord.<locals>.wrap_loglikelihood(theta, phi)
#     162 def wrap_loglikelihood(theta, phi):
# --> 163     logL = loglikelihood(theta)
#     164     try:
#     165         logL, phi[:] = logL
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/samplers/polychord/polychord.py:253, in polychord.run.<locals>.logpost(params_values)
#     252 def logpost(params_values):
# --> 253     result = self.model.logposterior(params_values)
#     254     loglikes = result.loglikes
#     255     if len(loglikes) != self.n_likes:
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/model.py:558, in Model.logposterior(self, params_values, as_dict, make_finite, return_derived, cached, _no_check)
#     555         logpriors.extend(self.prior.logps_external(input_params))
#     556 if -np.inf not in logpriors:
#     557     # noinspection PyUnboundLocalVariable
# --> 558     like = self._loglikes_input_params(input_params,
#     559                                        return_derived=return_derived,
#     560                                        cached=cached, make_finite=make_finite)
#     561     loglikes, derived_sampler = like if return_derived else (like, [])
#     562 else:
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/model.py:378, in Model._loglikes_input_params(self, input_params, return_derived, return_output_params, as_dict, make_finite, cached)
#     376 depend_list = [input_params[p] for p in param_dep]
#     377 params = {p: input_params[p] for p in component.input_params}
# --> 378 compute_success = component.check_cache_and_compute(
#     379     params, want_derived=need_derived,
#     380     dependency_params=depend_list, cached=cached)
#     381 if not compute_success:
#     382     loglikes[:] = -np.inf
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/theory.py:253, in Theory.check_cache_and_compute(self, params_values_dict, dependency_params, want_derived, cached)
#     251     self.timer.start()
#     252 try:
# --> 253     if self.calculate(state, want_derived, **params_values_dict) is False:
#     254         return False
#     255 except always_stop_exceptions:
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/likelihood.py:128, in Likelihood.calculate(self, state, want_derived, **params_values_dict)
#     126 derived: Optional[ParamValuesDict] = {} if want_derived else None
#     127 state["logp"] = -np.inf  # in case of exception
# --> 128 state["logp"] = self.logp(_derived=derived, **params_values_dict)
#     129 self.log.debug("Computed log-likelihood = %s", state["logp"])
#     130 if derived is not None:
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/likelihood.py:214, in LikelihoodExternalFunction.logp(self, **params_values)
#     212     params_values[self._self_arg] = self
#     213 try:
# --> 214     return_value = self.external_function(**params_values)
#     215 except Exception:
#     216     self.log.debug("External function failed at evaluation.")
#
# Cell In[12], line 65, in lnprobPSHz_31(M, h0, q0, j0, s0)
#      63 def lnprobPSHz_31(M, h0, q0, j0, s0):
#      64     theta = [M, h0, q0, j0, s0]
# ---> 65     return lnlikePS_31(theta)+lnlikeHz_31(theta)
#
# Cell In[12], line 55, in lnlikePS_31(theta)
#      54 def lnlikePS_31(theta):
# ---> 55     return -0.5*chi2PS_31(theta)
#
# Cell In[12], line 15, in chi2PS_31(theta)
#      12 if np.any(Ez2i <= 0):
#      13     return np.inf
# ---> 15 dAt = daModelP31(zt,theta)
#      16 NegDist = False
#      17 mmod = extract_theory_points(zt, dAt, theta, SH0ES=True)
#
# Cell In[9], line 58, in daModelP31(z, theta)
#      57 def daModelP31(z,theta):
# ---> 58     return dmModelP31(z,theta)/(1+z)
#
# Cell In[9], line 46, in dmModelP31(z, theta)
#      44 dH = c/H0
#      45 wk = 0
# ---> 46 Dcm = DcModelP31(z, theta)
#      47 if wk < 0:
#      48     return dH*np.sin(np.sqrt(-wk)*Dcm)/np.sqrt(-wk)
#
# Cell In[9], line 34, in DcModelP31(z, theta)
#      31 b1 = (-24 - 8*j0 - 4*j0**2 - 60*q0 + 22*j0*q0 - 42*q0**2 + 25*j0*q0**2 - 24*q0**3 - 15*q0**4 + 13*s0 + 7*q0*s0)/(4.*(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0))
#      33 for i in range(len(z)):
# ---> 34     dc[i], _ = quad(EzP31, 0, z[i], args=(theta))
#      35     if not np.isfinite(dc[i]):
#      36         dc[i] = np.inf
#
# File ~/jupyter_venv/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:459, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     456     return retval
#     458 if weight is None:
# --> 459     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     460                    points)
#     461 else:
#     462     if points is not None:
#
# File ~/jupyter_venv/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:606, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     604 if points is None:
#     605     if infbounds == 0:
# --> 606         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     607     else:
#     608         return _quadpack._qagie(func, bound, infbounds, args, full_output,
#     609                                 epsabs, epsrel, limit)
#
# Cell In[9], line 1, in EzP31(z, theta)
# ----> 1 def EzP31(z, theta):
#       2     M, H0, q0, j0, s0 = theta
#       3     a0 = H0
#
# KeyboardInterrupt:

# %% [markdown]
# #### CC+Pantheon+

# %%
par_mlHzPP_31 = par0_22

# %%
resultHzPP_31 = find_bestfit(getpar_PPHz_31, parnames_22, par_mlHzPP_31)
par_mlHzPP_31 = resultHzPP_31['x']
print('\n',par_mlHzPP_31,'\n')
print(resultHzPP_31,'\n')

# %%
info_PPHz31 = {
    "likelihood": {
        "lnlikehz": lnprobPPHz_31
    },

    "params": {
        "M": {"prior": {"min": -19.5, "max": 19.5}, "proposal": par_mlHzPP_31[0], "latex": "M"},
        "h0": {"prior": {"min": 40.0, "max": 100.0}, "proposal": par_mlHzPP_31[1], "latex": r"H_{0}"},
        "q0": {"prior": {"min": -2, "max": 2}, "proposal": par_mlHzPP_31[2], "latex": r"q_{0}"},
        "j0": {"prior": {"min": -5, "max": 5}, "proposal": par_mlHzPP_31[3], "latex": r"j_{0}"},
        "s0": {"prior": {"min": -10, "max": 10}, "proposal": par_mlHzPP_31[4], "latex": r"s_{0}"}
    },

    "sampler": {
        "polychord": {
            "nlive": 100
        }
    },

    "output": "chains/P31/PPHz_31"
}

info_post_PPHz31 = {
    "output": "chains/P31/PPHz_31",
    "post": {
        "skip_samples": 0.3,
        "suffix": "_post"
    }
}

# %%
_, sampler_PPHz_31 = run_cobaya(info_PPHz31, info_post_PPHz31)
