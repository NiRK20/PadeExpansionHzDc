# %%
import numpy as np
import numpy.linalg as linalg
import scipy.optimize as op
import scipy.interpolate
from scipy.integrate import quad
import pandas as pd
import time
from cobaya import run
import getdist.plots as gdplt
from getdist import MCSamples
import matplotlib.pyplot as plt
import os

c = 299792.458#km/s

# %% [markdown]
# ## CC data

# %%
zHz, Hzi, errHz = np.genfromtxt('data/32CCdata.dat', comments='#', usecols=(0,1,2), unpack=True, delimiter=',')
zmod, imf, slib, sps, spsooo = np.genfromtxt('data/data_MM20.dat', comments='#', usecols=(0,1,2,3,4), unpack=True)

cov_mat_diag = np.zeros((len(zHz), len(zHz)), dtype='float64') 

for i in range(len(zHz)):
    cov_mat_diag[i,i] = errHz[i]**2#Erros estatísticos

#Erros sistemáticos
imf_intp = np.interp(zHz, zmod, imf)/100
spsooo_intp = np.interp(zHz, zmod, spsooo)/100

cov_mat_imf = np.zeros((len(zHz), len(zHz)), dtype='float64')
cov_mat_spsooo = np.zeros((len(zHz), len(zHz)), dtype='float64')

for i in range(len(zHz)):
    for j in range(len(zHz)):
        cov_mat_imf[i,j] = Hzi[i] * imf_intp[i] * Hzi[j] * imf_intp[j]
        cov_mat_spsooo[i,j] = Hzi[i] * spsooo_intp[i] * Hzi[j] * spsooo_intp[j]
        
#Sistemático+estatístico:
cov_mat = cov_mat_spsooo+cov_mat_imf+cov_mat_diag
inv_cov_mat = np.linalg.inv(cov_mat)

# %% [markdown]
# ## Pantheon+SH0ES data

# %%
def build_data(datafile,SH0ES):
    """
    Run once at the start to load in the data vectors.
    
    Returns x, y where x is the independent variable (redshift in this case)
    and y is the Gaussian-distribured measured variable (magnitude in this case).
    """
    
    global origlen, wwPS, wwPPlus, cepheid_distance, is_calibrator, zHELPS, zHELPPlus

    print("Loading data from {}".format(datafile))
    data = pd.read_csv(datafile, sep=r'\s+')
    origlen = len(data)
    
    if SH0ES:
        ww = (data['zHD']>0.01) | (np.array(data['IS_CALIBRATOR'],dtype=bool))
        wwPS = ww
        zHELPS = data['zHEL'][ww]
    else:
        ww = (data['zHD']>0.01)
        wwPPlus = ww
        zHELPPlus = data['zHEL'][ww]

    zCMB = data['zHD'][ww] #use the vpec corrected redshift for zCMB 
    
    m_obs = data['m_b_corr'][ww]
    if SH0ES:
        is_calibrator = data['IS_CALIBRATOR'][ww]
        cepheid_distance = data['CEPH_DIST'][ww]

    return zCMB, m_obs

def build_covariance(covdatafile, SH0ES):
    """
    Run once at the start to build the covariance matrix for the data
    The file format for the covariance has the first line as an integer
    indicating the number of covariance elements, and the the subsequent
    lines being the elements.
    This function reads in the file and the nasty for loops trim down the covariance
    to match the only rows of data that are used for cosmology    
    """
    print("Loading covariance from {}".format(covdatafile))


    f = open(covdatafile)
    line = f.readline()
    if SH0ES:
        n = int(len(zCMBPS))
        ww = wwPS
    else:
        n = int(len(zCMBPPlus))
        ww = wwPPlus
    C = np.zeros((n,n))
    ii = -1
    jj = -1
    mine = 999
    maxe = -999
    for i in range(origlen):
        jj = -1
        if ww[i]:
            ii += 1
        for j in range(origlen):
            if ww[j]:
                jj += 1
            val = float(f.readline())
            if ww[i]:
                if ww[j]:
                    C[ii,jj] = val
    f.close()
    
    print('Done')

        # Return the covariance; the parent class knows to invert this
        # later to get the precision matrix that we need for the likelihood.
    return C

# %% [markdown]
# ### Pantheon+SH0ES

# %%
zCMBPS, m_obsPS = build_data('data/Pantheon+SH0ES.dat',SH0ES=True)

covPS = build_covariance('data/Pantheon+SH0ES_STAT+SYS.cov', SH0ES=True)
invcovPS = linalg.inv(covPS)
# Out:
# Loading data from data/Pantheon+SH0ES.dat
# Loading covariance from data/Pantheon+SH0ES_STAT+SYS.cov
# Done

# %% [markdown]
# ### Pantheon+

# %%
zCMBPPlus, m_obsPPlus = build_data('data/Pantheon+SH0ES.dat',SH0ES=False)

covPPlus = build_covariance('data/Pantheon+SH0ES_STAT+SYS.cov', SH0ES=False)
invcovPPlus = linalg.inv(covPPlus)
# Out:
# Loading data from data/Pantheon+SH0ES.dat
# Loading covariance from data/Pantheon+SH0ES_STAT+SYS.cov
# Done

# %% [markdown]
# ## Model functions

# %%
#Theory points for Pantheon+ and Pantheon+&SH0ES
def extract_theory_points(theory_x, theory_y, pars, SH0ES):
    """
    Run once per parameter set to extract the mean vector that our
    data points are compared to.  For the Hubble flow set, we compare to the 
    cosmological model. For the calibrators we compare to the Cepheid distances.
    """
    M = pars[0]

    # Pull out theory mu and z from the block.
    #theory_x = block[self.x_section, self.x_name]
    #theory_y = block[self.y_section, self.y_name]

    # Interpolation function of theory so we can evaluate at redshifts of the data
    f = scipy.interpolate.interp1d(theory_x, theory_y)#, kind=self.kind)
    
    if SH0ES:
        theory_ynew = zCMBPS*np.nan
        #Here we use the Cepheid host distances as the "theory". 
        #This is the 2nd rung of the distance ladder and is what calibrates M
        theory_ynew[np.array(is_calibrator,dtype='bool')] = cepheid_distance[np.array(is_calibrator,dtype='bool')]
        
        # Actually do the interpolation at the data redshifts
        zcmb = zCMBPS[~np.array(is_calibrator,dtype='bool')]
        zhel = zHELPS[~np.array(is_calibrator,dtype='bool')]
    else:
        theory_ynew = zCMBPPlus*np.nan
        # Actually do the interpolation at the data redshifts
        zcmb = zCMBPPlus
        zhel = zHELPPlus
    
    fz = f(zcmb)
    if np.any(fz<=0):
        NegDist = True
        return 1
    if SH0ES:
        theory_ynew[~np.array(is_calibrator,dtype='bool')] = 5.0*np.log10((1.0+zcmb)*(1.0+zhel)*\
                                                                          np.atleast_1d(fz))+25.
    else:
        theory_ynew = 5.0*np.log10((1.0+zcmb)*(1.0+zhel)*np.atleast_1d(fz))+25.
                
    # Add the absolute supernova magnitude and return
    #M = block[names.supernova_params, "M"]
    return theory_ynew + M

def extract_theory_pointsHz(theory_x, theory_y, pars):
    theory_ynew = zHz*np.nan  

    f = scipy.interpolate.interp1d(theory_x, theory_y)#, kind=self.kind)
    theory_ynew = np.atleast_1d(f(zHz))
    return theory_ynew

#Points for theory interpolation
N = 3000
zt = np.linspace(0,2.5,N)

# %% [markdown]
# ### P21

# %%
def EzP21(z,theta):
    M, H0, q0, j0, s0 = theta
    a0 = H0
    a1 = (H0*(7*j0*q0+6*j0-6*q0**2-6*q0**2+s0))/(3*(j0-q0**2))
    a2 = (H0*(3*j0**2+2*j0*q0**2+14*j0*q0+6*j0-3*q0**4-12*q0**3-6*q0**2+2*q0*s0+2*s0))/(6*(j0-q0**2))
    b1 = (4*j0*q0+3*j0-3*q0**3-3*q0**2+s0)/(3*(j0 - q0**2))
        
    H = (a0+a1*z+a2*z**2)/(1+b1*z)

    return H/H0

#Distancia comovel adimensional
def DcModelP21(z,theta):#Integrando e substituindo
    M, H0, q0, j0, s0 = theta
    a0 = H0
    a1 = (H0*(7*j0*q0+6*j0-6*q0**2-6*q0**2+s0))/(3*(j0-q0**2))
    a2 = (H0*(3*j0**2+2*j0*q0**2+14*j0*q0+6*j0-3*q0**4-12*q0**3-6*q0**2+2*q0*s0+2*s0))/(6*(j0-q0**2))
    b1 = (4*j0*q0+3*j0-3*q0**3-3*q0**2+s0)/(3*(j0 - q0**2))

    if (a1**2-4*a0*a2) > 0:
        r1 = (-a1 + np.sqrt(a1**2-4*a2*a0))/(2*a2)
        r2 = (-a1 - np.sqrt(a1**2-4*a2*a0))/(2*a2)

        dc = (((1+b1*r2)/(r2-r1))*np.log(np.abs((z-r2)/(-r2)))-((1+b1*r1)/(r2-r1))*np.log(np.abs((z-r1)/(-r1))))/a2
        
    elif (a1**2-4*a0*a2) == 0:
        dc = ((1 + (a1*b1)/(2*a2))*2*a2*z)/(a1*(a1/(2*a2) + z)) + (b1*np.log(2*np.abs((a2*(a1/(2*a2) + z))/a1)))/a2
        
    elif (a1**2-4*a0*a2) < 0:
        dc = (b1/(2*a2))*np.log(np.abs((a0+a1*z+a2*z**2)/a0)) + (((2*a2-b1*a1))/(a2*np.sqrt(4*a2*a0-a1**2)))*(np.arctan((2*a2*z+a1)/np.sqrt(4*a2*a0-a1**2)) - np.arctan(a1/np.sqrt(4*a2*a0-a1**2)))

    return H0*dc

#Distancia comovel transversal in pc
def dmModelP21(z, theta):
    M, H0, q0, j0, s0 = theta
    
    dH = c/H0
    wk = 0
    Dcm = DcModelP21(z, theta)
    if wk < 0:
        return dH*np.sin(np.sqrt(-wk)*Dcm)/np.sqrt(-wk)
    elif wk > 0:
        return dH*np.sinh(np.sqrt(wk)*Dcm)/np.sqrt(wk)
    return dH*Dcm

#Distancia comovel transversal in pc
def dmModelP21(z, theta):
    M, H0, q0, j0, s0 = theta
    
    dH = c/H0
    wk = 0
    Dcm = DcModelP21(z, theta)
    if wk < 0:
        return dH*np.sin(np.sqrt(-wk)*Dcm)/np.sqrt(-wk)
    elif wk > 0:
        return dH*np.sinh(np.sqrt(wk)*Dcm)/np.sqrt(wk)
    return dH*Dcm

#distancia de luminosidade in pc
def dlModelP21(z,theta):
    return (1+z)*dmModelP21(z,theta)

def daModelP21(z,theta):
    return dmModelP21(z,theta)/(1+z)

def muModelP21(z,pars):
    return 5.*np.log10(dlModelP21(z,pars))+25

# %% [markdown]
# ### P22

# %%
def EzP22(z, theta):
    M, H0, q0, j0, s0 = theta
    a0 = H0
    a1 = (H0*(-24 + 4*j0 + 8*j0**2 - 84*q0 + 54*j0*q0 + 10*j0**2*q0 - 114*q0**2 + 67*j0*q0**2 - 102*q0**3 + 15*j0*q0**3 - 63*q0**4 - 15*q0**5
              + 17*s0 + 2*j0*s0 + 28*q0*s0 + 9*q0**2*s0))/(2.*(6*j0 + 3*j0**2 + 14*j0*q0 - 6*q0**2 + 2*j0*q0**2 - 12*q0**3 - 3*q0**4 + 2*s0 + 2*q0*s0))
    a2 = (H0*(-144 + 24*j0 + 108*j0**2 + 30*j0**3 - 648*q0 + 216*j0*q0 + 150*j0**2*q0 - 1188*q0**2 + 252*j0*q0**2 - 5*j0**2*q0**2 - 1188*q0**3
              + 90*j0*q0**3 - 648*q0**4 + 60*j0*q0**4 - 180*q0**5 - 45*q0**6 + 78*s0 + 9*j0*s0 + 198*q0*s0 + 35*j0*q0*s0 + 153*q0**2*s0 +
              15*q0**3*s0 + 4*s0**2))/(12.*(6*j0 + 3*j0**2 + 14*j0*q0 - 6*q0**2 + 2*j0*q0**2 - 12*q0**3 - 3*q0**4 + 2*s0 + 2*q0*s0))
    b1 = (24 + 8*j0 - 2*j0**2 + 84*q0 - 14*j0*q0 - 4*j0**2*q0 + 102*q0**2 - 35*j0*q0**2 + 66*q0**3 - 11*j0*q0**3 + 33*q0**4 + 9*q0**5 -
              13*s0 - 2*j0*s0 - 20*q0*s0 - 5*q0**2*s0)/(-12*j0 - 6*j0**2 - 28*j0*q0 + 12*q0**2 - 4*j0*q0**2 + 24*q0**3 + 6*q0**4 - 4*s0 - 4*q0*s0)
    b2 = (-72*j0 - 60*j0**2 - 12*j0**3 - 180*j0*q0 - 30*j0**2*q0 + 72*q0**2 - 30*j0*q0**2 + 23*j0**2*q0**2 + 180*q0**3 + 30*j0*q0**3 +
          90*q0**4 - 24*j0*q0**4 + 9*q0**6 + 15*j0*s0 - 11*j0*q0*s0 - 15*q0**2*s0 + 3*q0**3*s0 - 4*s0**2)/(-72*j0 - 36*j0**2 - 168*j0*q0 
                                                                                                           + 72*q0**2 - 24*j0*q0**2 + 144*q0**3 + 36*q0**4 - 24*s0 - 24*q0*s0)
        
    H = (a0+a1*z+a2*z**2)/(1+b1*z+b2*z**2)

    return H/H0

def DcModelP22(z, theta):#Integrando e substituindo
    M, H0, q0, j0, s0 = theta
    a0 = H0
    a1 = (H0*(-24 + 4*j0 + 8*j0**2 - 84*q0 + 54*j0*q0 + 10*j0**2*q0 - 114*q0**2 + 67*j0*q0**2 - 102*q0**3 + 15*j0*q0**3 - 63*q0**4 - 15*q0**5
              + 17*s0 + 2*j0*s0 + 28*q0*s0 + 9*q0**2*s0))/(2.*(6*j0 + 3*j0**2 + 14*j0*q0 - 6*q0**2 + 2*j0*q0**2 - 12*q0**3 - 3*q0**4 + 2*s0 + 2*q0*s0))
    a2 = (H0*(-144 + 24*j0 + 108*j0**2 + 30*j0**3 - 648*q0 + 216*j0*q0 + 150*j0**2*q0 - 1188*q0**2 + 252*j0*q0**2 - 5*j0**2*q0**2 - 1188*q0**3
              + 90*j0*q0**3 - 648*q0**4 + 60*j0*q0**4 - 180*q0**5 - 45*q0**6 + 78*s0 + 9*j0*s0 + 198*q0*s0 + 35*j0*q0*s0 + 153*q0**2*s0 +
              15*q0**3*s0 + 4*s0**2))/(12.*(6*j0 + 3*j0**2 + 14*j0*q0 - 6*q0**2 + 2*j0*q0**2 - 12*q0**3 - 3*q0**4 + 2*s0 + 2*q0*s0))
    b1 = (24 + 8*j0 - 2*j0**2 + 84*q0 - 14*j0*q0 - 4*j0**2*q0 + 102*q0**2 - 35*j0*q0**2 + 66*q0**3 - 11*j0*q0**3 + 33*q0**4 + 9*q0**5 -
              13*s0 - 2*j0*s0 - 20*q0*s0 - 5*q0**2*s0)/(-12*j0 - 6*j0**2 - 28*j0*q0 + 12*q0**2 - 4*j0*q0**2 + 24*q0**3 + 6*q0**4 - 4*s0 - 4*q0*s0)
    b2 = (-72*j0 - 60*j0**2 - 12*j0**3 - 180*j0*q0 - 30*j0**2*q0 + 72*q0**2 - 30*j0*q0**2 + 23*j0**2*q0**2 + 180*q0**3 + 30*j0*q0**3 +
          90*q0**4 - 24*j0*q0**4 + 9*q0**6 + 15*j0*s0 - 11*j0*q0*s0 - 15*q0**2*s0 + 3*q0**3*s0 - 4*s0**2)/(-72*j0 - 36*j0**2 - 168*j0*q0
              + 72*q0**2 - 24*j0*q0**2 + 144*q0**3 + 36*q0**4 - 24*s0 - 24*q0*s0)

    if (a1**2-4*a0*a2) > 0:
        r1 = (-a1 + np.sqrt(a1**2-4*a2*a0))/(2*a2)
        r2 = (-a1 - np.sqrt(a1**2-4*a2*a0))/(2*a2)
        dc = (((1 + b1*r2 + b2*r2**2)/(r2 - r1))*np.log(np.abs((z - r2)/(-r2))) - ((1 + b1*r1 + b2*r1**2)/(r2 - r1))*np.log(np.abs((z-r1)/(-r1))) + b2*z)/a2
        
    elif (a1**2-4*a0*a2) == 0:
        dc = ((b1 + 2*r*b2)*np.log(np.abs((z-r)/r)) + ((1+b1*r-b2*r)*z)/((z-r)*r) +b2*r)/a2
        
    elif (a1**2-4*a0*a2) < 0:
        dc = ((b2*z + (b1/(2) - (b2*a1)/(2*a2)))*np.log(np.abs((a0+a1*z+a2*z**2)/a0)) + ((2*a2-a1*b1-2*a0*a2+a1**2)/(a2*np.sqrt(4*a2*a0-a1**2)))*(np.arctan((2*a2*z+a1)/np.sqrt(4*a2*a0-a1**2))
                    - np.arctan(a1/np.sqrt(4*a2*a0-a1**2))))/a2

    return H0*dc

#Distancia comovel transversal in pc
def dmModelP22(z, theta):
    M, H0, q0, j0, s0 = theta
    
    dH = c/H0
    wk = 0
    Dcm = DcModelP22(z, theta)
    if wk < 0:
        return dH*np.sin(np.sqrt(-wk)*Dcm)/np.sqrt(-wk)
    elif wk > 0:
        return dH*np.sinh(np.sqrt(wk)*Dcm)/np.sqrt(wk)
    return dH*Dcm

#distancia de luminosidade in pc
def dlModelP22(z,theta):
    return (1+z)*dmModelP22(z,theta)

def daModelP22(z,theta):
    return dmModelP22(z,theta)/(1+z)

def muModelP22(z,pars):
    return 5.*np.log10(dlModelP22(z,pars))+25

# %% [markdown]
# ### P31

# %%
def EzP31(z, theta):
    M, H0, q0, j0, s0 = theta
    a0 = H0
    a1 = -0.25*(H0*(24 - 4*j0 + 4*j0**2 + 60*q0 - 50*j0*q0 + 54*q0**2 - 41*j0*q0**2 + 48*q0**3 + 27*q0**4 - 17*s0 - 11*q0*s0))/(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0)
    a2 = (H0*(-24 - 8*j0 + 2*j0**2 - 84*q0 + 14*j0*q0 + 4*j0**2*q0 - 102*q0**2 + 35*j0*q0**2 - 66*q0**3 + 
              11*j0*q0**3 - 33*q0**4 - 9*q0**5 + 13*s0 + 2*j0*s0 + 20*q0*s0 + 5*q0**2*s0))/(4.*(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0))
    a3 = -0.0417*(H0*(72*j0 + 60*j0**2 + 12*j0**3 + 180*j0*q0 + 30*j0**2*q0 - 72*q0**2 + 30*j0*q0**2 - 
                      23*j0**2*q0**2 - 180*q0**3 - 30*j0*q0**3 - 90*q0**4 + 24*j0*q0**4 - 9*q0**6 - 15*j0*s0 + 11*j0*q0*s0 + 
                      15*q0**2*s0 - 3*q0**3*s0 + 4*s0**2))/(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0) #0.041666666666666664
    b1 = (-24 - 8*j0 - 4*j0**2 - 60*q0 + 22*j0*q0 - 42*q0**2 + 25*j0*q0**2 - 24*q0**3 - 15*q0**4 + 13*s0 + 7*q0*s0)/(4.*(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0))

    H = (a0 + a1*z + a2*z**2 + a3*z**3)/(1 + b1*z)

    return H/H0

#Distancia comovel adimensional
def DcModelP31(z,theta):#Integrando e substituindo
    M, H0, q0, j0, s0 = theta
    dc = np.zeros_like(z)
    
    a0 = H0
    a1 = -0.25*(H0*(24 - 4*j0 + 4*j0**2 + 60*q0 - 50*j0*q0 + 54*q0**2 - 41*j0*q0**2 + 48*q0**3 + 27*q0**4 - 17*s0 - 11*q0*s0))/(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0)
    
    a2 = (H0*(-24 - 8*j0 + 2*j0**2 - 84*q0 + 14*j0*q0 + 4*j0**2*q0 - 102*q0**2 + 35*j0*q0**2 - 66*q0**3 + 11*j0*q0**3 - 
              33*q0**4 - 9*q0**5 + 13*s0 + 2*j0*s0 + 20*q0*s0 + 5*q0**2*s0))/(4.*(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0))
    
    a3 = -0.0417*(H0*(72*j0 + 60*j0**2 + 12*j0**3 + 180*j0*q0 + 30*j0**2*q0 - 72*q0**2 + 30*j0*q0**2 - 
                      23*j0**2*q0**2 - 180*q0**3 - 30*j0*q0**3 - 90*q0**4 + 24*j0*q0**4 - 9*q0**6 - 15*j0*s0 + 11*j0*q0*s0 + 
                      15*q0**2*s0 - 3*q0**3*s0 + 4*s0**2))/(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0) #0.041666666666666664
    
    b1 = (-24 - 8*j0 - 4*j0**2 - 60*q0 + 22*j0*q0 - 42*q0**2 + 25*j0*q0**2 - 24*q0**3 - 15*q0**4 + 13*s0 + 7*q0*s0)/(4.*(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0))

    ez = lambda z2, theta: 1/EzP31(z2, theta)
    
    for i in range(len(z)):
        if i == 0:
            dc[i], _ = quad(ez, 0, z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
            if not np.isfinite(dc[i]):
                return -np.inf
        else:
            dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
            dc[i] = dc_aux + dc[i-1]
            if not np.isfinite(dc[i]):
                return -np.inf

    return dc

#Distancia comovel transversal in pc
def dmModelP31(z, theta):
    M, H0, q0, j0, s0= theta
    
    dH = c/H0
    wk = 0
    Dcm = DcModelP31(z, theta)
    if wk < 0:
        return dH*np.sin(np.sqrt(-wk)*Dcm)/np.sqrt(-wk)
    elif wk > 0:
        return dH*np.sinh(np.sqrt(wk)*Dcm)/np.sqrt(wk)
    return dH*Dcm

#distancia de luminosidade in pc
def dlModelP31(z,theta):
    return (1+z)*dmModelP31(z,theta)

def daModelP31(z,theta):
    return dmModelP31(z,theta)/(1+z)

def muModelP31(z,pars):
    return 5.*np.log10(dlModelP31(z,pars))+25

# %% [markdown]
# ## Statistical functions

# %% [markdown]
# ### P21

# %%
def getpar_PSHz_21(theta):
    M, H0, q0, j0, s0 = theta
    return lnprobPSHz_21(M, H0, q0, j0, s0)

def getpar_PPHz_21(theta):
    M, H0, q0, j0, s0 = theta
    return lnprobPPHz_21(M, H0, q0, j0, s0)

def chi2PS_21(theta):#Pantheon+SH0ES
    zsni = zCMBPS
    Ez2i = EzP21(zsni,theta)
    if np.any(Ez2i <= 0):
        return np.inf

    dAt = daModelP21(zt,theta)
    NegDist = False
    mmod = extract_theory_points(zt, dAt, theta, SH0ES=True)
    if NegDist:
        return np.inf
    dm = mmod-m_obsPS
    
    return np.dot(np.dot(dm.T,invcovPS),dm)
        
def chi2PP_21(theta):#Pantheon+
    zsni = zCMBPPlus
    Ez2i = EzP21(zsni,theta)
    if np.any(Ez2i <= 0):
        return np.inf

    dAt = daModelP21(zt,theta)
    NegDist = False
    mmod = extract_theory_points(zt, dAt, theta,SH0ES=False) #5.*np.log10((1+zsni)*(1+zheli)*dAmodi/10)#(dlmodi/10)
    if NegDist:
        return np.inf
    dmu = mmod-m_obsPPlus
    SA  = np.sum(invcovPPlus)
    Sr  = np.sum(np.dot(dmu.T,invcovPPlus))#np.sum(dmu*invcov)
    Srr = np.dot(np.dot(dmu.T,invcovPPlus),dmu)#np.sum(dmu*dmu*invcov)
    return Srr - Sr**2./SA
        
def chi2Hz_21(theta):#CC Hz
    M, H0, q0, j0, s0 = theta
        
    Ezt = EzP21(zt,theta)
    if np.any(Ezt<0):
        return np.inf
    Hzt = H0*Ezt#Hz(zt,pars)
    Hzm = extract_theory_pointsHz(zt, Hzt, theta)
   
    dh = Hzm-Hzi
    
    return np.dot(np.dot(dh.T,inv_cov_mat),dh)

def lnlikePS_21(theta):
    return -0.5*chi2PS_21(theta)

def lnlikePP_21(theta):
    return -0.5*chi2PP_21(theta)

def lnlikeHz_21(theta):
    return -0.5*chi2Hz_21(theta)

def lnprobPSHz_21(M, H0, q0, j0, s0):
    theta = [M, H0, q0, j0, s0]
    return lnlikePS_21(theta)+lnlikeHz_21(theta)
    
def lnprobPPHz_21(M, H0, q0, j0, s0):
    theta = [M, H0, q0, j0, s0]
    return lnlikePP_21(theta)+lnlikeHz_21(theta)

# %% [markdown]
# ### P22

# %%
def getpar_PSHz_22(theta):
    M, h0, q0, j0, s0 = theta
    return lnprobPSHz_22(M, h0, q0, j0, s0)

def getpar_PPHz_22(theta):
    M, h0, q0, j0, s0 = theta
    return lnprobPPHz_22(M, h0, q0, j0, s0)

def chi2PS_22(theta):#Pantheon+SH0ES
    zsni = zCMBPS
    Ez2i = EzP22(zsni,theta)
    if np.any(Ez2i <= 0):
        return np.inf

    dAt = daModelP22(zt,theta)
    NegDist = False
    mmod = extract_theory_points(zt, dAt, theta, SH0ES=True)
    if NegDist:
        return np.inf
    dm = mmod-m_obsPS
    
    return np.dot(np.dot(dm.T,invcovPS),dm)
        
def chi2PP_22(theta):#Pantheon+
    zsni = zCMBPPlus
    Ez2i = EzP22(zsni,theta)
    if np.any(Ez2i <= 0):
        return np.inf

    dAt = daModelP22(zt,theta)
    NegDist = False
    mmod = extract_theory_points(zt, dAt, theta,SH0ES=False) #5.*np.log10((1+zsni)*(1+zheli)*dAmodi/10)#(dlmodi/10)
    if NegDist:
        return np.inf
    dmu = mmod-m_obsPPlus
    SA  = np.sum(invcovPPlus)
    Sr  = np.sum(np.dot(dmu.T,invcovPPlus))#np.sum(dmu*invcov)
    Srr = np.dot(np.dot(dmu.T,invcovPPlus),dmu)#np.sum(dmu*dmu*invcov)
    return Srr - Sr**2./SA
        
def chi2Hz_22(theta):#CC Hz
    M, H0, q0, j0, s0 = theta
        
    Ezt = EzP22(zt,theta)
    if np.any(Ezt<0):
        return np.inf
    Hzt = H0*Ezt#Hz(zt,pars)
    Hzm = extract_theory_pointsHz(zt, Hzt, theta)
   
    dh = Hzm-Hzi
    
    return np.dot(np.dot(dh.T,inv_cov_mat),dh)

def lnlikePS_22(theta):
    return -0.5*chi2PS_22(theta)

def lnlikePP_22(theta):
    return -0.5*chi2PP_22(theta)

def lnlikeHz_22(theta):
    return -0.5*chi2Hz_22(theta)

def lnprobPSHz_22(M, h0, q0, j0, s0):
    theta = [M, h0, q0, j0, s0]
    return lnlikePS_22(theta)+lnlikeHz_22(theta)
    
def lnprobPPHz_22(M, h0, q0, j0, s0):
    theta = [M, h0, q0, j0, s0]
    return lnlikePP_22(theta)+lnlikeHz_22(theta)

# %% [markdown]
# ### P31

# %%
def getpar_PSHz_31(theta):
    M, h0, q0, j0, s0 = theta
    return lnprobPSHz_31(M, h0, q0, j0, s0)

def getpar_PPHz_31(theta):
    M, h0, q0, j0, s0 = theta
    return lnprobPPHz_31(M, h0, q0, j0, s0)

def chi2PS_31(theta):#Pantheon+SH0ES
    zsni = zCMBPS
    Ez2i = EzP31(zsni,theta)
    if np.any(Ez2i <= 0):
        return np.inf

    dAt = daModelP31(zt,theta)
    NegDist = False
    mmod = extract_theory_points(zt, dAt, theta, SH0ES=True)
    if NegDist:
        return np.inf
    dm = mmod-m_obsPS
    
    return np.dot(np.dot(dm.T,invcovPS),dm)
        
def chi2PP_31(theta):#Pantheon+
    zsni = zCMBPPlus
    Ez2i = EzP31(zsni,theta)
    if np.any(Ez2i <= 0):
        return np.inf

    dAt = daModelP31(zt,theta)
    NegDist = False
    mmod = extract_theory_points(zt, dAt, theta,SH0ES=False) #5.*np.log10((1+zsni)*(1+zheli)*dAmodi/10)#(dlmodi/10)
    if NegDist:
        return np.inf
    dmu = mmod-m_obsPPlus
    SA  = np.sum(invcovPPlus)
    Sr  = np.sum(np.dot(dmu.T,invcovPPlus))#np.sum(dmu*invcov)
    Srr = np.dot(np.dot(dmu.T,invcovPPlus),dmu)#np.sum(dmu*dmu*invcov)
    return Srr - Sr**2./SA
        
def chi2Hz_31(theta):#CC Hz
    M, H0, q0, j0, s0 = theta
        
    Ezt = EzP31(zt,theta)
    if np.any(Ezt<0):
        return np.inf
    Hzt = H0*Ezt#Hz(zt,pars)
    Hzm = extract_theory_pointsHz(zt, Hzt, theta)
   
    dh = Hzm-Hzi
    
    return np.dot(np.dot(dh.T,inv_cov_mat),dh)

def lnlikePS_31(theta):
    return -0.5*chi2PS_31(theta)

def lnlikePP_31(theta):
    return -0.5*chi2PP_31(theta)

def lnlikeHz_31(theta):
    return -0.5*chi2Hz_31(theta)

def lnprobPSHz_31(M, h0, q0, j0, s0):
    theta = [M, h0, q0, j0, s0]
    return lnlikePS_31(theta)+lnlikeHz_31(theta)
    
def lnprobPPHz_31(M, h0, q0, j0, s0):
    theta = [M, h0, q0, j0, s0]
    return lnlikePP_31(theta)+lnlikeHz_31(theta)

# %% [markdown]
# ## Analysis functions

# %%
def find_bestfit(lnlike, parnames, par_ml):#,data):
    t1 = time.time()
    ndim = len(par_ml)
    chi2 = lambda *args: -2 * lnlike(*args)
    result = op.minimize(chi2, par_ml)#, args=data)
    if not result['success']:
        result = op.minimize(chi2, par_ml, method='Nelder-Mead',options={'maxiter': 10000})#, args=data
    par_ml = result["x"]
    print('Maximum likelihood result:')
    for i in range(ndim):
        print(parnames[i],' = ',par_ml[i])
    print('chi2min =',result['fun'])
    #ndof = len(data[0])-ndim
    #print('chi2red =',result['fun']/ndof)
    #print(result)
    t2 = time.time()
    print("tempo total: {0:5.3f} seg".format(t2-t1))
    return result

def run_cobaya(info, info_post):
    print("----- INICIANDO SAMPLER -----")
    t1 = time.time()

    # Roda o sampler
    updated_info, sampler = run(info)

    # Retira o início 
    print("----- RETIRANDO O INICIO -----")
    updated_info_post, sampler_post = run(info_post)

    print(f"Tempo de execução: {time.time()-t1} s")

    return sampler, sampler_post

def MCResult_cobaya(sampler):
    gdsamples = sampler.products()["sample"][0].to_getdist()
    stats = gdsamples.getMargeStats()

    for par in stats.names[:gdsamples.samples.shape[1]-2]:
        par_stats = stats.parWithName(par.name)
        mean = par_stats.mean

        # Erros de 1-sigma (68% CL)
        lower_1s = par_stats.limits[0].lower
        upper_1s = par_stats.limits[0].upper
        err_plus_1s = upper_1s - mean
        err_minus_1s = mean - lower_1s

        # Erros de 2-sigma (95% CL)
        lower_2s = par_stats.limits[1].lower
        upper_2s = par_stats.limits[1].upper
        err_plus_2s = upper_2s - mean
        err_minus_2s = mean - lower_2s
            
        label = f"{par.name}"
        
            
        print(f"{label} = {mean:.4f} +{err_plus_1s:.4f} +{err_plus_2s:.4f} -{err_plus_1s:.4f} -{err_plus_2s:.4f}") 
    
def plot_getdist(samples, params, legends, width=8, fill=False):
    gsamples = []
    for i in samples:
        gsamples.append(i.products()["sample"][0].to_getdist())

    g = gdplt.getSubplotPlotter(width_inch=width)
    g.triangle_plot(gsamples, params, filled=fill, legend_labels=legends)
    plt.show()

def lnlikePPHz_21(M, h0, q0, j0):
    theta = [M, h0, q0, j0]
    return lnlikePP_21(theta)+lnlikeHz_21(theta)

# %% [markdown]
# ## Models analysis

# %% [markdown]
# ### P21

# %%
parlabels_21 = ["M","H_0",'q_0','j_0', 's_0']
parlabtex_21 = ["$M$","$H_0$",'$q_0$','$j_0$', '$s_0$']
parnames_21 = ['M','H0','q0','j0', 's0']
par0_21=[-19.2, 73.03398760350208, -0.5280171275112104, 1, -0.35]
ndim_21 = len(par0_21)

# %% [markdown]
# #### CC+SH0ES+Pantheon+

# %%
par_mlHzPS_21 = par0_21

# %%
resultHzPS_21 = find_bestfit(getpar_PSHz_21, parnames_21, par_mlHzPS_21)
par_mlHzPS_21=resultHzPS_21['x']
print('\n',par_mlHzPS_21,'\n')
print(resultHzPS_21,'\n')
# Out:
# Maximum likelihood result:
# M  =  -19.255048763641415
# H0  =  73.1101671680467
# q0  =  -0.23004284227988775
# j0  =  0.5695774210653272
# s0  =  -0.502377434711987
# chi2min = 1468.6454094533033
# tempo total: 8.115 seg
#
#  [-19.25504876  73.11016717  -0.23004284   0.56957742  -0.50237743]
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1468.6454094533033
#              x: [-1.926e+01  7.311e+01 -2.300e-01  5.696e-01 -5.024e-01]
#            nit: 418
#           nfev: 677
#  final_simplex: (array([[-1.926e+01,  7.311e+01, ...,  5.696e-01,
#                         -5.024e-01],
#                        [-1.926e+01,  7.311e+01, ...,  5.696e-01,
#                         -5.023e-01],
#                        ...,
#                        [-1.926e+01,  7.311e+01, ...,  5.696e-01,
#                         -5.024e-01],
#                        [-1.926e+01,  7.311e+01, ...,  5.696e-01,
#                         -5.024e-01]], shape=(6, 5)), array([ 1.469e+03,  1.469e+03,  1.469e+03,  1.469e+03,
#                         1.469e+03,  1.469e+03]))

# %%
info_PSHz21 = {
    "likelihood": {
        "lnlikehz": lnprobPSHz_21
    },

    "params": {
        "M": {"prior": {"min": -19.5, "max": 19.5}, "proposal": par_mlHzPS_21[0], "latex": "M"},
        "H0": {"prior": {"min": 40.0, "max": 100.0}, "proposal": par_mlHzPS_21[1], "latex": r"H_{0}"},
        "q0": {"prior": {"min": -2, "max": 2}, "proposal": par_mlHzPS_21[2], "latex": r"q_{0}"},
        "j0": {"prior": {"min": -5, "max": 5}, "proposal": par_mlHzPS_21[3], "latex": r"j_{0}"},
        "s0": {"prior": {"min": -4, "max": 3}, "proposal": par_mlHzPS_21[4], "latex": r"s_{0}"}
    },

    "sampler": {
        "polychord": {
            "nlive": 250
        }
    },

    "output": "chains/P21/PS/PSHz_21"
}

info_post_PSHz21 = {
    "output": "chains/P21/PS/PSHz_21",
    "post": {
        "skip_samples": 0.3,
        "suffix": "_post"
    }
}

# %%
_, sampler_PSHz_21 = run_cobaya(info_PSHz21, info_post_PSHz21)
# Out:
# ----- INICIANDO SAMPLER -----
# [output] Output to be read-from/written-into folder 'chains/P21/PS', with prefix 'PSHz_21'
# [lnlikehz] Initialized external likelihood.
# [polychord] `pypolychord` module loaded successfully from /home/nirk20/jupyter_venv/lib/python3.12/site-packages/pypolychord
# [polychord] Storing raw PolyChord output in 'chains/P21/PS/PSHz_21_polychord_raw'.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {lnlikehz: 181.0}
# [polychord] Parameter blocks and their oversampling factors:
# [polychord] * 1 : ['M', 'H0', 'q0', 'j0', 's0']
# [polychord] Calling PolyChord...
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     250
# nDims    :       5
# nDerived :       2
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/P21/PS/PSHz_21_polychord_raw/PSHz_21.resume
#
# generating live points
#
#
# all live points generated
#
# number of repeats:           10
# started sampling
#
# _________________
# lives      | 250 |
# phantoms   |   9 |
# posteriors |2251 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2251
# nposterior =                2251
# nequals    =                   1
# nlike      =                2517
# <nlike>    =           0.07   (           0.01 per slice )
# log(Z)     =      -499926.25 +/-  0.83
# log(Z_1)   =      -499926.25 +/-  0.83 (still evaluating)
#
#
#
# _________________
# lives      | 250 |
# phantoms   |1376 |
# posteriors |2502 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2502
# nposterior =                2502
# nequals    =                   1
# nlike      =                7783
# <nlike>    =          21.06   (           2.11 per slice )
# log(Z)     =       -54658.28 +/-  0.83
# log(Z_1)   =       -54658.28 +/-  0.83 (still evaluating)
#
#
#
# _________________
# lives      | 250 |
# phantoms   |1924 |
# posteriors |2753 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2753
# nposterior =                2753
# nequals    =                   1
# nlike      =               13388
# <nlike>    =          22.42   (           2.24 per slice )
# log(Z)     =        -8959.76 +/-  0.84
# log(Z_1)   =        -8959.76 +/-  0.84 (still evaluating)
#
#
#
# _________________
# lives      | 250 |
# phantoms   |2047 |
# posteriors |3004 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3004
# nposterior =                3004
# nequals    =                   1
# nlike      =               19687
# <nlike>    =          25.20   (           2.52 per slice )
# log(Z)     =        -2537.46 +/-  0.73
# log(Z_1)   =        -2537.46 +/-  0.73 (still evaluating)
#
#
#
# _________________
# lives      | 250 |
# phantoms   |2229 |
# posteriors |3255 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3255
# nposterior =                3255
# nequals    =                   2
# nlike      =               26440
# <nlike>    =          27.01   (           2.70 per slice )
# log(Z)     =        -1487.17 +/-  0.59
# log(Z_1)   =        -1487.17 +/-  0.59 (still evaluating)
#
#
#
# _________________
# lives      | 250 |
# phantoms   |2286 |
# posteriors |3506 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3506
# nposterior =                3506
# nequals    =                   1
# nlike      =               33906
# <nlike>    =          29.86   (           2.99 per slice )
# log(Z)     =        -1144.47 +/-  0.72
# log(Z_1)   =        -1144.47 +/-  0.72 (still evaluating)
#
#
#
# _________________
# lives      | 250 |
# phantoms   |2338 |
# posteriors |3757 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3757
# nposterior =                3757
# nequals    =                   3
# nlike      =               42391
# <nlike>    =          33.94   (           3.39 per slice )
# log(Z)     =         -982.60 +/-  0.46
# log(Z_1)   =         -982.60 +/-  0.46 (still evaluating)
#
#
#
# _________________
# lives      | 250 |
# phantoms   |2322 |
# posteriors |4008 |
# equals     |   6 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4008
# nposterior =                4008
# nequals    =                   5
# nlike      =               50886
# <nlike>    =          33.98   (           3.40 per slice )
# log(Z)     =         -882.82 +/-  0.35
# log(Z_1)   =         -882.82 +/-  0.35 (still evaluating)
#
#
#
# _________________
# lives      | 250 |
# phantoms   |2325 |
# posteriors |4259 |
# equals     |  16 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4259
# nposterior =                4259
# nequals    =                  13
# nlike      =               60208
# <nlike>    =          37.29   (           3.73 per slice )
# log(Z)     =         -832.57 +/-  0.29
# log(Z_1)   =         -832.57 +/-  0.29 (still evaluating)
#
#
#
# _________________
# lives      | 250 |
# phantoms   |2204 |
# posteriors |4510 |
# equals     |  11 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4510
# nposterior =                4510
# nequals    =                   9
# nlike      =               70345
# <nlike>    =          40.55   (           4.05 per slice )
# log(Z)     =         -803.97 +/-  0.30
# log(Z_1)   =         -803.97 +/-  0.30 (still evaluating)
#
#
#
# _________________
# lives      | 250 |
# phantoms   |2300 |
# posteriors |4761 |
# equals     |  21 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4761
# nposterior =                4761
# nequals    =                  23
# nlike      =               80673
# <nlike>    =          41.31   (           4.13 per slice )
# log(Z)     =         -786.92 +/-  0.26
# log(Z_1)   =         -786.92 +/-  0.26 (still evaluating)
#
#
#
# _______________________
# lives      |  25 | 225 |
# phantoms   | 244 |2096 |
# posteriors |4861 |4908 |
# equals     |   5 |  24 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                5008
# nposterior =                5008
# nequals    =                  19
# nlike      =               90880
# <nlike>    =          40.83   (           4.08 per slice )
# log(Z)     =         -775.70 +/-  0.25
# log(Z_1)   =         -776.02 +/-  0.26 (still evaluating)
# log(Z_2)   =         -777.02 +/-  0.34 (still evaluating)
#
#
#
# _________________
# lives      | 250 |
# phantoms   |2144 |
# posteriors |5120 |
# equals     |  25 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                5252
# nposterior =                5252
# nequals    =                  26
# nlike      =              100660
# <nlike>    =          39.12   (           3.91 per slice )
# log(Z)     =         -766.25 +/-  0.25
# log(Z_1)   =         -766.27 +/-  0.25 (still evaluating)
# log(Z_2)   =         -770.30 +/-  0.56
#
#
#
# _________________
# lives      | 250 |
# phantoms   |2212 |
# posteriors |5371 |
# equals     |  59 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                5503
# nposterior =                5503
# nequals    =                  59
# nlike      =              110890
# <nlike>    =          40.92   (           4.09 per slice )
# log(Z)     =         -759.91 +/-  0.24
# log(Z_1)   =         -759.91 +/-  0.24 (still evaluating)
# log(Z_2)   =         -770.30 +/-  0.56
#
#
#
# _________________
# lives      | 250 |
# phantoms   |2217 |
# posteriors |5622 |
# equals     | 119 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                5754
# nposterior =                5754
# nequals    =                 104
# nlike      =              120981
# <nlike>    =          40.36   (           4.04 per slice )
# log(Z)     =         -756.72 +/-  0.24
# log(Z_1)   =         -756.72 +/-  0.24 (still evaluating)
# log(Z_2)   =         -770.30 +/-  0.56
#
#
#
# _________________
# lives      | 250 |
# phantoms   |2153 |
# posteriors |5873 |
# equals     | 206 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                6005
# nposterior =                6005
# nequals    =                 186
# nlike      =              131449
# <nlike>    =          41.87   (           4.19 per slice )
# log(Z)     =         -754.85 +/-  0.24
# log(Z_1)   =         -754.85 +/-  0.24 (still evaluating)
# log(Z_2)   =         -770.30 +/-  0.56
#
#
#
# _________________
# lives      | 250 |
# phantoms   |2158 |
# posteriors |6124 |
# equals     | 405 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                6256
# nposterior =                6256
# nequals    =                 399
# nlike      =              141867
# <nlike>    =          41.67   (           4.17 per slice )
# log(Z)     =         -753.96 +/-  0.24
# log(Z_1)   =         -753.96 +/-  0.24 (still evaluating)
# log(Z_2)   =         -770.30 +/-  0.56
#
#
#
# _________________
# lives      | 250 |
# phantoms   |2202 |
# posteriors |6375 |
# equals     | 617 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                6507
# nposterior =                6507
# nequals    =                 604
# nlike      =              152660
# <nlike>    =          43.17   (           4.32 per slice )
# log(Z)     =         -753.56 +/-  0.25
# log(Z_1)   =         -753.56 +/-  0.25 (still evaluating)
# log(Z_2)   =         -770.30 +/-  0.56
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 _, sampler_PSHz_21 = run_cobaya(info_PSHz21, info_post_PSHz21)
#
# Cell In[13], line 25, in run_cobaya(info, info_post)
#      22 t1 = time.time()
#      24 # Roda o sampler
# ---> 25 updated_info, sampler = run(info)
#      27 # Retira o início
#      28 print("----- RETIRANDO O INICIO -----")
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/run.py:146, in run(info_or_yaml_or_file, packages_path, output, debug, stop_at_error, resume, force, minimize, no_mpi, test, override, allow_changes)
#     144                 return updated_info, sampler
#     145             # Run the sampler
# --> 146             sampler.run()
#     147 return updated_info, sampler
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/samplers/polychord/polychord.py:266, in polychord.run(self)
#     264 sync_processes()
#     265 self.mpi_info("Calling PolyChord...")
# --> 266 self.pc.run_polychord(logpost, self.nDims, self.nDerived, self.pc_settings,
#     267                       self.pc_prior, self.dumper)
#     268 self.process_raw_output()
#
# File ~/jupyter_venv/lib/python3.12/site-packages/pypolychord/polychord.py:177, in run_polychord(loglikelihood, nDims, nDerived, settings, prior, dumper)
#     174 settings.nlives = {float(logL):int(nlive) for logL, nlive in settings.nlives.items()}
#     176 # Run polychord from module library
# --> 177 _pypolychord.run(wrap_loglikelihood,
#     178                  wrap_prior,
#     179                  dumper,
#     180                  nDims,
#     181                  nDerived,
#     182                  settings.nlive,
#     183                  settings.num_repeats,
#     184                  settings.nprior,
#     185                  settings.nfail,
#     186                  settings.do_clustering,
#     187                  settings.feedback,
#     188                  settings.precision_criterion,
#     189                  settings.logzero,
#     190                  settings.max_ndead,
#     191                  settings.boost_posterior,
#     192                  settings.posteriors,
#     193                  settings.equals,
#     194                  settings.cluster_posteriors,
#     195                  settings.write_resume,
#     196                  settings.write_paramnames,
#     197                  settings.read_resume,
#     198                  settings.write_stats,
#     199                  settings.write_live,
#     200                  settings.write_dead,
#     201                  settings.write_prior,
#     202                  settings.maximise,
#     203                  settings.compression_factor,
#     204                  settings.synchronous,
#     205                  settings.base_dir,
#     206                  settings.file_root,
#     207                  settings.grade_frac,
#     208                  settings.grade_dims,
#     209                  settings.nlives,
#     210                  settings.seed)
#     212 if settings.cube_samples is not None:
#     213     settings.read_resume = read_resume
#
# File ~/jupyter_venv/lib/python3.12/site-packages/pypolychord/polychord.py:163, in run_polychord.<locals>.wrap_loglikelihood(theta, phi)
#     162 def wrap_loglikelihood(theta, phi):
# --> 163     logL = loglikelihood(theta)
#     164     try:
#     165         logL, phi[:] = logL
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/samplers/polychord/polychord.py:253, in polychord.run.<locals>.logpost(params_values)
#     252 def logpost(params_values):
# --> 253     result = self.model.logposterior(params_values)
#     254     loglikes = result.loglikes
#     255     if len(loglikes) != self.n_likes:
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/model.py:558, in Model.logposterior(self, params_values, as_dict, make_finite, return_derived, cached, _no_check)
#     555         logpriors.extend(self.prior.logps_external(input_params))
#     556 if -np.inf not in logpriors:
#     557     # noinspection PyUnboundLocalVariable
# --> 558     like = self._loglikes_input_params(input_params,
#     559                                        return_derived=return_derived,
#     560                                        cached=cached, make_finite=make_finite)
#     561     loglikes, derived_sampler = like if return_derived else (like, [])
#     562 else:
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/model.py:378, in Model._loglikes_input_params(self, input_params, return_derived, return_output_params, as_dict, make_finite, cached)
#     376 depend_list = [input_params[p] for p in param_dep]
#     377 params = {p: input_params[p] for p in component.input_params}
# --> 378 compute_success = component.check_cache_and_compute(
#     379     params, want_derived=need_derived,
#     380     dependency_params=depend_list, cached=cached)
#     381 if not compute_success:
#     382     loglikes[:] = -np.inf
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/theory.py:253, in Theory.check_cache_and_compute(self, params_values_dict, dependency_params, want_derived, cached)
#     251     self.timer.start()
#     252 try:
# --> 253     if self.calculate(state, want_derived, **params_values_dict) is False:
#     254         return False
#     255 except always_stop_exceptions:
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/likelihood.py:128, in Likelihood.calculate(self, state, want_derived, **params_values_dict)
#     126 derived: Optional[ParamValuesDict] = {} if want_derived else None
#     127 state["logp"] = -np.inf  # in case of exception
# --> 128 state["logp"] = self.logp(_derived=derived, **params_values_dict)
#     129 self.log.debug("Computed log-likelihood = %s", state["logp"])
#     130 if derived is not None:
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/likelihood.py:214, in LikelihoodExternalFunction.logp(self, **params_values)
#     212     params_values[self._self_arg] = self
#     213 try:
# --> 214     return_value = self.external_function(**params_values)
#     215 except Exception:
#     216     self.log.debug("External function failed at evaluation.")
#
# Cell In[10], line 65, in lnprobPSHz_21(M, H0, q0, j0, s0)
#      63 def lnprobPSHz_21(M, H0, q0, j0, s0):
#      64     theta = [M, H0, q0, j0, s0]
# ---> 65     return lnlikePS_21(theta)+lnlikeHz_21(theta)
#
# Cell In[10], line 55, in lnlikePS_21(theta)
#      54 def lnlikePS_21(theta):
# ---> 55     return -0.5*chi2PS_21(theta)
#
# Cell In[10], line 22, in chi2PS_21(theta)
#      19     return np.inf
#      20 dm = mmod-m_obsPS
# ---> 22 return np.dot(np.dot(dm.T,invcovPS),dm)
#
# KeyboardInterrupt:

# %% [markdown]
# #### CC+Pantheon+

# %%
par_mlHzPP_21 = par0_21

# %%
resultHzPP_21 = find_bestfit(getpar_PPHz_21, parnames_21, par_mlHzPP_21)
par_mlHzPP_21=resultHzPP_21['x']
print('\n',par_mlHzPP_21,'\n')
print(resultHzPP_21,'\n')
# Out:
# Maximum likelihood result:
# M  =  -12.351193838336917
# H0  =  69.1043329589236
# q0  =  -0.5961098582696993
# j0  =  2.4549315819076085
# chi2min = 1418.4627051569305
# tempo total: 3.075 seg
#
#  [-12.35119384  69.10433296  -0.59610986   2.45493158]
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1418.4627051569305
#              x: [-1.235e+01  6.910e+01 -5.961e-01  2.455e+00]
#            nit: 127
#           nfev: 224
#  final_simplex: (array([[-1.235e+01,  6.910e+01, -5.961e-01,  2.455e+00],
#                        [-1.235e+01,  6.910e+01, -5.961e-01,  2.455e+00],
#                        ...,
#                        [-1.235e+01,  6.910e+01, -5.961e-01,  2.455e+00],
#                        [-1.235e+01,  6.910e+01, -5.961e-01,  2.455e+00]],
#                       shape=(5, 4)), array([ 1.418e+03,  1.418e+03,  1.418e+03,  1.418e+03,
#                         1.418e+03]))

# %%
info_PPHz21 = {
    "likelihood": {
        "lnlikehz": lnprobPPHz_21
    },

    "params": {
        "M": {"prior": {"min": -19.5, "max": 19.5}, "proposal": par_mlHzPP_21[0], "latex": "M"},
        "h0": {"prior": {"min": 40.0, "max": 100.0}, "proposal": par_mlHzPP_21[1], "latex": r"H_{0}"},
        "q0": {"prior": {"min": -2, "max": 2}, "proposal": par_mlHzPP_21[2], "latex": r"q_{0}"},
        "j0": {"prior": {"min": -5, "max": 5}, "proposal": par_mlHzPP_21[3], "latex": r"j_{0}"}
    },

    "sampler": {
        "polychord": {
            "nlive": 200
        }
    },

    "output": "chains/P21/PP/PPHz_21"
}

info_post_PPHz21 = {
    "output": "chains/P21/PP/PPHz_21",
    "post": {
        "skip_samples": 0.3,
        "suffix": "_post"
    }
}

# %%
_, sampler_PPHz_21 = run_cobaya(info_PPHz21, info_post_PPHz21)
# Out:
# ----- INICIANDO SAMPLER -----
# [output] Output to be read-from/written-into folder 'chains/P21/PP', with prefix 'PPHz_21'
# [lnlikehz] Initialized external likelihood.
# [polychord] `pypolychord` module loaded successfully from /home/nirk20/jupyter_venv/lib/python3.12/site-packages/pypolychord
# [polychord] Storing raw PolyChord output in 'chains/P21/PP/PPHz_21_polychord_raw'.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {lnlikehz: 199.0}
# [polychord] Parameter blocks and their oversampling factors:
# [polychord] * 1 : ['M', 'h0', 'q0', 'j0']
# [polychord] Calling PolyChord...
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     200
# nDims    :       4
# nDerived :       2
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/P21/PP/PPHz_21_polychord_raw/PPHz_21.resume
#
# generating live points
#
#
# all live points generated
#
# number of repeats:            8
# started sampling
#
# _________________
# lives      | 200 |
# phantoms   |   7 |
# posteriors |1801 |
# equals     |  10 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1801
# nposterior =                1801
# nequals    =                  10
# nlike      =                2024
# <nlike>    =           0.12   (           0.01 per slice )
# log(Z)     =         -763.95 +/-  0.26
# log(Z_1)   =         -763.95 +/-  0.26 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   | 944 |
# posteriors |2002 |
# equals     |  14 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2002
# nposterior =                2002
# nequals    =                   6
# nlike      =                6905
# <nlike>    =          24.41   (           3.05 per slice )
# log(Z)     =         -742.79 +/-  0.23
# log(Z_1)   =         -742.79 +/-  0.23 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1271 |
# posteriors |2203 |
# equals     |  23 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2203
# nposterior =                2203
# nequals    =                  20
# nlike      =               12322
# <nlike>    =          27.09   (           3.39 per slice )
# log(Z)     =         -728.93 +/-  0.19
# log(Z_1)   =         -728.93 +/-  0.19 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1256 |
# posteriors |2404 |
# equals     |  51 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2404
# nposterior =                2404
# nequals    =                  45
# nlike      =               18255
# <nlike>    =          29.66   (           3.71 per slice )
# log(Z)     =         -722.22 +/-  0.16
# log(Z_1)   =         -722.22 +/-  0.16 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1407 |
# posteriors |2605 |
# equals     | 118 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2605
# nposterior =                2605
# nequals    =                 110
# nlike      =               24341
# <nlike>    =          30.43   (           3.80 per slice )
# log(Z)     =         -719.40 +/-  0.15
# log(Z_1)   =         -719.40 +/-  0.15 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1434 |
# posteriors |2806 |
# equals     | 226 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2806
# nposterior =                2806
# nequals    =                 218
# nlike      =               30477
# <nlike>    =          30.68   (           3.83 per slice )
# log(Z)     =         -718.17 +/-  0.15
# log(Z_1)   =         -718.17 +/-  0.15 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1351 |
# posteriors |3007 |
# equals     | 417 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3007
# nposterior =                3007
# nequals    =                 406
# nlike      =               36724
# <nlike>    =          31.23   (           3.90 per slice )
# log(Z)     =         -717.58 +/-  0.15
# log(Z_1)   =         -717.58 +/-  0.15 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1481 |
# posteriors |3208 |
# equals     | 552 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3208
# nposterior =                3208
# nequals    =                 538
# nlike      =               42942
# <nlike>    =          31.09   (           3.89 per slice )
# log(Z)     =         -717.30 +/-  0.16
# log(Z_1)   =         -717.30 +/-  0.16 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1499 |
# posteriors |3409 |
# equals     | 631 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3409
# nposterior =                3409
# nequals    =                 605
# nlike      =               49161
# <nlike>    =          31.10   (           3.89 per slice )
# log(Z)     =         -717.19 +/-  0.16
# log(Z_1)   =         -717.19 +/-  0.16 (still evaluating)
#
#
#
# _______________________
# lives      |  71 | 129 |
# phantoms   | 591 | 988 |
# posteriors |3485 |3535 |
# equals     | 642 | 648 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                3611
# nposterior =                3611
# nequals    =                 644
# nlike      =               59874
# <nlike>    =          53.56   (           6.70 per slice )
# log(Z)     =         -717.14 +/-  0.16
# log(Z_1)   =         -717.63 +/-  0.16 (still evaluating)
# log(Z_2)   =         -718.09 +/-  0.16 (still evaluating)
#
#
#
# _______________________
# lives      |  75 | 125 |
# phantoms   | 637 | 974 |
# posteriors |3555 |3667 |
# equals     | 643 | 661 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                3813
# nposterior =                3813
# nequals    =                 655
# nlike      =               70140
# <nlike>    =          51.33   (           6.42 per slice )
# log(Z)     =         -717.12 +/-  0.16
# log(Z_1)   =         -717.62 +/-  0.16 (still evaluating)
# log(Z_2)   =         -718.07 +/-  0.16 (still evaluating)
#
#
#
# _______________________
# lives      |  68 | 132 |
# phantoms   | 553 | 992 |
# posteriors |3627 |3797 |
# equals     | 644 | 668 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                4015
# nposterior =                4015
# nequals    =                 657
# nlike      =               80147
# <nlike>    =          50.04   (           6.25 per slice )
# log(Z)     =         -717.12 +/-  0.16
# log(Z_1)   =         -717.61 +/-  0.16 (still evaluating)
# log(Z_2)   =         -718.06 +/-  0.16 (still evaluating)
#
#
#
# _____________________________
# lives      |  73 | 104 |  23 |
# phantoms   | 612 | 870 | 156 |
# posteriors |3703 |3910 |3811 |
# equals     | 644 | 672 | 668 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       3
# ndead      =                4218
# nposterior =                4218
# nequals    =                 657
# nlike      =               91640
# <nlike>    =          57.47   (           7.18 per slice )
# log(Z)     =         -717.11 +/-  0.16
# log(Z_1)   =         -717.74 +/-  0.16 (still evaluating)
# log(Z_2)   =         -718.06 +/-  0.16 (still evaluating)
# log(Z_3)   =         -719.66 +/-  0.18 (still evaluating)
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =         4504                              |
# | log(Z) =         -717.11266 +/-            0.15788 |
# |____________________________________________________|
# [polychord] Loading PolyChord's results: samples and evidences.
# [polychord] Finished! Raw PolyChord output stored in 'chains/P21/PP/PPHz_21_polychord_raw', with prefix 'PPHz_21'
# [polychord] log(Z) = -717.532 +/- 0.157879 ; Z in [2.0475457e-312, 2.8077964e-312] (68% C.L. log-gaussian)
# ----- RETIRANDO O INICIO -----
# [output] Output to be read-from/written-into folder 'chains/P21/PP', with prefix 'PPHz_21'
# [output] Found existing info files with the requested output prefix: 'chains/P21/PP/PPHz_21'
# [samplecollection] Loaded 4109 sample points from 'chains/P21/PP/PPHz_21.1.txt'
# [post] Will process 4109 sample points.
# [output] Output to be read-from/written-into folder 'chains/P21/PP', with prefix 'PPHz_21.post._post'
# [post] Running post-processing...
# [post]  |--------------------|   0%  (0/4109)
# [post]  |@-------------------|   5%  (185/4109)
# [post]  |@@------------------|  10%  (391/4109)
# [post]  |@@@-----------------|  15%  (596/4109)
# [post]  |@@@@----------------|  20%  (802/4109)
# [post]  |@@@@@---------------|  25%  (1007/4109)
# [post]  |@@@@@@--------------|  30%  (1213/4109)
# [post]  |@@@@@@@-------------|  35%  (1418/4109)
# [post]  |@@@@@@@@------------|  40%  (1624/4109)
# [post]  |@@@@@@@@@-----------|  45%  (1829/4109)
# [post]  |@@@@@@@@@@----------|  50%  (2034/4109)
# [post]  |@@@@@@@@@@@---------|  55%  (2240/4109)
# [post]  |@@@@@@@@@@@@--------|  60%  (2445/4109)
# [post]  |@@@@@@@@@@@@@-------|  65%  (2651/4109)
# [post]  |@@@@@@@@@@@@@@------|  70%  (2856/4109)
# [post]  |@@@@@@@@@@@@@@@-----|  75%  (3062/4109)
# [post]  |@@@@@@@@@@@@@@@@----|  80%  (3267/4109)
# [post]  |@@@@@@@@@@@@@@@@@---|  85%  (3473/4109)
# [post]  |@@@@@@@@@@@@@@@@@@--|  90%  (3678/4109)
# [post]  |@@@@@@@@@@@@@@@@@@@-|  95%  (3884/4109)
# [post]  |@@@@@@@@@@@@@@@@@@@@| 100%  (4089/4109)
# [post] Finished! Final number of distinct sample points: 4109
# [post] Importance weight range: 1 -- 1
# [post] Effective number of single samples if independent (sum w)/max(w): 668
# [post] Effective number of weighted samples if independent (sum w)^2/sum(w^2): 977
# Tempo de execução: 529.5749237537384 s

# %% [markdown]
# ### P22

# %%
parlabels_22 = ["M","H_0",'q_0','j_0', 's_0']
parlabtex_22 = ["$M$","$H_0$",'$q_0$','$j_0$', '$s_0$']
parnames_22 = ['M','H0','q0','j0', 's0']
par0_22=[-19.2, 73.03398760350208, -0.5280171275112104, 1, 4]
ndim_22 = len(par0_22)

# %% [markdown]
# #### CC+SH0ES+Pantheon+

# %%
par_mlHzPS_22 = par0_22

# %%
resultHzPS_22 = find_bestfit(getpar_PSHz_22, parnames_22, par_mlHzPS_22)
par_mlHzPS_22 = resultHzPS_22['x']
print('\n',par_mlHzPS_22,'\n')
print(resultHzPS_22,'\n')
# Out:
# Maximum likelihood result:
# M  =  -19.45314018374367
# H0  =  82.68286413447896
# q0  =  -0.8019233071701728
# j0  =  0.6057510573373469
# s0  =  0.546158732716164
# chi2min = 2407.5208965397096
# tempo total: 10.641 seg
#
#  [-19.45314018  82.68286413  -0.80192331   0.60575106   0.54615873]
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2407.5208965397096
#              x: [-1.945e+01  8.268e+01 -8.019e-01  6.058e-01  5.462e-01]
#            nit: 821
#           nfev: 1327
#  final_simplex: (array([[-1.945e+01,  8.268e+01, ...,  6.058e-01,
#                          5.462e-01],
#                        [-1.945e+01,  8.268e+01, ...,  6.058e-01,
#                          5.462e-01],
#                        ...,
#                        [-1.945e+01,  8.268e+01, ...,  6.058e-01,
#                          5.462e-01],
#                        [-1.945e+01,  8.268e+01, ...,  6.058e-01,
#                          5.462e-01]], shape=(6, 5)), array([ 2.408e+03,  2.408e+03,  2.408e+03,  2.408e+03,
#                         2.408e+03,  2.408e+03]))

# %%
info_PSHz22 = {
    "likelihood": {
        "lnlikehz": lnprobPSHz_22
    },

    "params": {
        "M": {"prior": {"min": -19.5, "max": 19.5}, "proposal": par_mlHzPS_22[0], "latex": "M"},
        "h0": {"prior": {"min": 40.0, "max": 100.0}, "proposal": par_mlHzPS_22[1], "latex": r"H_{0}"},
        "q0": {"prior": {"min": -2, "max": 2}, "proposal": par_mlHzPS_22[2], "latex": r"q_{0}"},
        "j0": {"prior": {"min": -5, "max": 5}, "proposal": par_mlHzPS_22[3], "latex": r"j_{0}"},
        "s0": {"prior": {"min": -10, "max": 10}, "proposal": par_mlHzPS_22[4], "latex": r"s_{0}"}
    },

    "sampler": {
        "polychord": {
            "nlive":200
        }
    },

    "output": "chains/P22/PS/PSHz_22"
}

info_post_PSHz22 = {
    "output": "chains/P22/PS/PSHz_22",
    "post": {
        "skip_samples": 0.3,
        "suffix": "_post"
    }
}

# %%
_, sampler_PSHz_22 = run_cobaya(info_PSHz22, info_post_PSHz22)
# Out:
# ----- INICIANDO SAMPLER -----
# [output] Output to be read-from/written-into folder 'chains/P22/PS', with prefix 'PSHz_22'
# [lnlikehz] Initialized external likelihood.
# [polychord] `pypolychord` module loaded successfully from /home/nirk20/jupyter_venv/lib/python3.12/site-packages/pypolychord
# [polychord] Storing raw PolyChord output in 'chains/P22/PS/PSHz_22_polychord_raw'.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {lnlikehz: 120.0}
# [polychord] Parameter blocks and their oversampling factors:
# [polychord] * 1 : ['M', 'h0', 'q0', 'j0', 's0']
# [polychord] Calling PolyChord...
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     200
# nDims    :       5
# nDerived :       2
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/P22/PS/PSHz_22_polychord_raw/PSHz_22.resume
#
# generating live points
#
#
# all live points generated
#
# number of repeats:           10
# started sampling
#
# _________________
# lives      | 200 |
# phantoms   |   9 |
# posteriors |1801 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1801
# nposterior =                1801
# nequals    =                   1
# nlike      =                2016
# <nlike>    =           0.08   (           0.01 per slice )
# log(Z)     =      -921563.64 +/-  0.83
# log(Z_1)   =      -921563.64 +/-  0.83 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1089 |
# posteriors |2002 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2002
# nposterior =                2002
# nequals    =                   1
# nlike      =                6601
# <nlike>    =          22.93   (           2.29 per slice )
# log(Z)     =      -111400.03 +/-  0.84
# log(Z_1)   =      -111400.03 +/-  0.84 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1672 |
# posteriors |2203 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2203
# nposterior =                2203
# nequals    =                   1
# nlike      =               11306
# <nlike>    =          23.53   (           2.35 per slice )
# log(Z)     =       -18906.53 +/-  0.84
# log(Z_1)   =       -18906.53 +/-  0.84 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1782 |
# posteriors |2404 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2404
# nposterior =                2404
# nequals    =                   1
# nlike      =               16240
# <nlike>    =          24.67   (           2.47 per slice )
# log(Z)     =        -4731.78 +/-  0.84
# log(Z_1)   =        -4731.78 +/-  0.84 (still evaluating)
#
#
#
# _______________________
# lives      | 199 |   1 |
# phantoms   |1768 |  16 |
# posteriors |2603 |2407 |
# equals     |   1 |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                2606
# nposterior =                2606
# nequals    =                   1
# nlike      =               21673
# <nlike>    =          27.16   (           2.72 per slice )
# log(Z)     =        -2023.05 +/-  0.84
# log(Z_1)   =        -2023.05 +/-  0.84 (still evaluating)
# log(Z_2)   =        -2841.82 +/-  0.76 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1780 |
# posteriors |2801 |
# equals     |   3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                2805
# nposterior =                2805
# nequals    =                   2
# nlike      =               27325
# <nlike>    =          28.26   (           2.83 per slice )
# log(Z)     =        -1452.78 +/-  0.61
# log(Z_1)   =        -1452.78 +/-  0.61 (still evaluating)
# log(Z_2)   =        -1889.95 +/-  0.76
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1817 |
# posteriors |3002 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                3006
# nposterior =                3006
# nequals    =                   1
# nlike      =               33495
# <nlike>    =          30.85   (           3.08 per slice )
# log(Z)     =        -1137.95 +/-  0.67
# log(Z_1)   =        -1137.95 +/-  0.67 (still evaluating)
# log(Z_2)   =        -1889.95 +/-  0.76
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1761 |
# posteriors |3203 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                3207
# nposterior =                3207
# nequals    =                   2
# nlike      =               39871
# <nlike>    =          31.88   (           3.19 per slice )
# log(Z)     =         -966.59 +/-  0.56
# log(Z_1)   =         -966.59 +/-  0.56 (still evaluating)
# log(Z_2)   =        -1889.95 +/-  0.76
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1757 |
# posteriors |3404 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                3408
# nposterior =                3408
# nequals    =                   2
# nlike      =               46499
# <nlike>    =          33.14   (           3.31 per slice )
# log(Z)     =         -876.63 +/-  0.47
# log(Z_1)   =         -876.63 +/-  0.47 (still evaluating)
# log(Z_2)   =        -1889.95 +/-  0.76
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1754 |
# posteriors |3605 |
# equals     |   6 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                3609
# nposterior =                3609
# nequals    =                   4
# nlike      =               53574
# <nlike>    =          35.38   (           3.54 per slice )
# log(Z)     =         -828.58 +/-  0.36
# log(Z_1)   =         -828.58 +/-  0.36 (still evaluating)
# log(Z_2)   =        -1889.95 +/-  0.76
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1613 |
# posteriors |3806 |
# equals     |  10 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                3810
# nposterior =                3810
# nequals    =                   9
# nlike      =               61072
# <nlike>    =          37.49   (           3.75 per slice )
# log(Z)     =         -798.86 +/-  0.33
# log(Z_1)   =         -798.86 +/-  0.33 (still evaluating)
# log(Z_2)   =        -1889.95 +/-  0.76
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1861 |
# posteriors |4007 |
# equals     |  10 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                4011
# nposterior =                4011
# nequals    =                  13
# nlike      =               68936
# <nlike>    =          39.32   (           3.93 per slice )
# log(Z)     =         -783.49 +/-  0.30
# log(Z_1)   =         -783.49 +/-  0.30 (still evaluating)
# log(Z_2)   =        -1889.95 +/-  0.76
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1891 |
# posteriors |4208 |
# equals     |  30 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                4212
# nposterior =                4212
# nequals    =                  28
# nlike      =               76789
# <nlike>    =          39.27   (           3.93 per slice )
# log(Z)     =         -772.05 +/-  0.28
# log(Z_1)   =         -772.05 +/-  0.28 (still evaluating)
# log(Z_2)   =        -1889.95 +/-  0.76
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1667 |
# posteriors |4409 |
# equals     |  31 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                4413
# nposterior =                4413
# nequals    =                  31
# nlike      =               84996
# <nlike>    =          41.04   (           4.10 per slice )
# log(Z)     =         -764.43 +/-  0.28
# log(Z_1)   =         -764.43 +/-  0.28 (still evaluating)
# log(Z_2)   =        -1889.95 +/-  0.76
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1707 |
# posteriors |4610 |
# equals     |  71 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                4614
# nposterior =                4614
# nequals    =                  70
# nlike      =               93346
# <nlike>    =          41.75   (           4.17 per slice )
# log(Z)     =         -760.16 +/-  0.27
# log(Z_1)   =         -760.16 +/-  0.27 (still evaluating)
# log(Z_2)   =        -1889.95 +/-  0.76
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1809 |
# posteriors |4811 |
# equals     | 124 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                4815
# nposterior =                4815
# nequals    =                 124
# nlike      =              101990
# <nlike>    =          43.22   (           4.32 per slice )
# log(Z)     =         -757.93 +/-  0.27
# log(Z_1)   =         -757.93 +/-  0.27 (still evaluating)
# log(Z_2)   =        -1889.95 +/-  0.76
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1785 |
# posteriors |5012 |
# equals     | 223 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                5016
# nposterior =                5016
# nequals    =                 217
# nlike      =              110922
# <nlike>    =          44.66   (           4.47 per slice )
# log(Z)     =         -756.68 +/-  0.28
# log(Z_1)   =         -756.68 +/-  0.28 (still evaluating)
# log(Z_2)   =        -1889.95 +/-  0.76
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1730 |
# posteriors |5213 |
# equals     | 355 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                5217
# nposterior =                5217
# nequals    =                 342
# nlike      =              120028
# <nlike>    =          45.53   (           4.55 per slice )
# log(Z)     =         -755.94 +/-  0.28
# log(Z_1)   =         -755.94 +/-  0.28 (still evaluating)
# log(Z_2)   =        -1889.95 +/-  0.76
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1760 |
# posteriors |5414 |
# equals     | 531 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                5418
# nposterior =                5418
# nequals    =                 519
# nlike      =              129318
# <nlike>    =          46.45   (           4.64 per slice )
# log(Z)     =         -755.51 +/-  0.28
# log(Z_1)   =         -755.51 +/-  0.28 (still evaluating)
# log(Z_2)   =        -1889.95 +/-  0.76
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1690 |
# posteriors |5615 |
# equals     | 670 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                5619
# nposterior =                5619
# nequals    =                 647
# nlike      =              138634
# <nlike>    =          46.58   (           4.66 per slice )
# log(Z)     =         -755.30 +/-  0.28
# log(Z_1)   =         -755.30 +/-  0.28 (still evaluating)
# log(Z_2)   =        -1889.95 +/-  0.76
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1706 |
# posteriors |5816 |
# equals     | 743 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                5820
# nposterior =                5820
# nequals    =                 721
# nlike      =              148071
# <nlike>    =          47.19   (           4.72 per slice )
# log(Z)     =         -755.19 +/-  0.29
# log(Z_1)   =         -755.19 +/-  0.29 (still evaluating)
# log(Z_2)   =        -1889.95 +/-  0.76
#
#
#
# _______________________
# lives      |  39 | 161 |
# phantoms   | 392 |1509 |
# posteriors |5872 |5961 |
# equals     | 752 | 766 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       3
# ndead      =                6021
# nposterior =                6021
# nequals    =                 750
# nlike      =              159980
# <nlike>    =          59.55   (           5.95 per slice )
# log(Z)     =         -755.14 +/-  0.29
# log(Z_1)   =         -755.54 +/-  0.29 (still evaluating)
# log(Z_2)   =         -756.27 +/-  0.29 (still evaluating)
# log(Z_3)   =        -1889.95 +/-  0.76
#
#
#
# _____________________________
# lives      |  12 |  39 | 149 |
# phantoms   | 179 | 383 |1388 |
# posteriors |5921 |5975 |6081 |
# equals     | 756 | 767 | 774 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       4
# ndead      =                6204
# nposterior =                6204
# nequals    =                 762
# nlike      =              170191
# <nlike>    =          51.05   (           5.11 per slice )
# log(Z)     =         -755.12 +/-  0.29
# log(Z_1)   =         -755.66 +/-  0.29 (still evaluating)
# log(Z_2)   =         -756.25 +/-  0.29 (still evaluating)
# log(Z_3)   =         -757.54 +/-  0.29 (still evaluating)
# log(Z_4)   =        -1889.95 +/-  0.76
#
#
#
# _______________________
# lives      |  70 | 130 |
# phantoms   | 674 |1205 |
# posteriors |5993 |6231 |
# equals     | 768 | 777 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       4
# ndead      =                6387
# nposterior =                6387
# nequals    =                 769
# nlike      =              177813
# <nlike>    =          38.11   (           3.81 per slice )
# log(Z)     =         -755.11 +/-  0.29
# log(Z_1)   =         -755.65 +/-  0.29 (still evaluating)
# log(Z_2)   =         -756.24 +/-  0.29
# log(Z_3)   =         -757.54 +/-  0.29 (still evaluating)
# log(Z_4)   =        -1889.95 +/-  0.76
#
#
#
# _______________________
# lives      | 135 |  65 |
# phantoms   |1223 | 626 |
# posteriors |6014 |6405 |
# equals     | 769 | 782 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       4
# ndead      =                6582
# nposterior =                6582
# nequals    =                 771
# nlike      =              184475
# <nlike>    =          33.31   (           3.33 per slice )
# log(Z)     =         -755.11 +/-  0.29
# log(Z_1)   =         -755.64 +/-  0.29 (still evaluating)
# log(Z_2)   =         -756.24 +/-  0.29
# log(Z_3)   =         -757.53 +/-  0.29 (still evaluating)
# log(Z_4)   =        -1889.95 +/-  0.76
#
#
#
# _______________________
# lives      | 199 |   1 |
# phantoms   |1690 |   8 |
# posteriors |6124 |6028 |
# equals     | 772 | 769 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       6
# ndead      =                6782
# nposterior =                6782
# nequals    =                 772
# nlike      =              187417
# <nlike>    =          14.71   (           1.47 per slice )
# log(Z)     =         -755.11 +/-  0.29
# log(Z_1)   =         -756.16 +/-  0.29
# log(Z_2)   =         -756.24 +/-  0.29
# log(Z_3)   =         -756.55 +/-  0.29
# log(Z_4)   =         -757.56 +/-  0.29 (still evaluating)
# log(Z_5)   =         -760.73 +/-  0.32 (still evaluating)
# log(Z_6)   =        -1889.95 +/-  0.76
#
#
#
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# _____________________________
# lives      |   1 | 185 |  14 |
# phantoms   |  17 |1584 | 128 |
# posteriors |6131 |6316 |6126 |
# equals     | 772 | 773 | 772 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       8
# ndead      =                6985
# nposterior =                6984
# nequals    =                 773
# nlike      =              189864
# <nlike>    =          12.23   (           1.22 per slice )
# log(Z)     =         -755.11 +/-  0.29
# log(Z_1)   =         -756.16 +/-  0.29
# log(Z_2)   =         -756.24 +/-  0.29
# log(Z_3)   =         -756.55 +/-  0.29
# log(Z_4)   =         -757.60 +/-  0.29 (still evaluating)
# log(Z_5)   =         -760.73 +/-  0.32
# log(Z_6)   =         -761.11 +/-  0.32 (still evaluating)
# log(Z_7)   =         -761.48 +/-  0.34 (still evaluating)
# log(Z_8)   =        -1889.95 +/-  0.76
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =         7257                              |
# | log(Z) =         -755.10755 +/-            0.28684 |
# |____________________________________________________|
# [polychord] Loading PolyChord's results: samples and evidences.
# [polychord] Finished! Raw PolyChord output stored in 'chains/P22/PS/PSHz_22_polychord_raw', with prefix 'PSHz_22'
# [polychord] log(Z) = -755.468 +/- 0.286839 ; Z in [0, 0] (68% C.L. log-gaussian)
# ----- RETIRANDO O INICIO -----
# [output] Output to be read-from/written-into folder 'chains/P22/PS', with prefix 'PSHz_22'
# [output] Found existing info files with the requested output prefix: 'chains/P22/PS/PSHz_22'
# [samplecollection] Loaded 4490 sample points from 'chains/P22/PS/PSHz_22.1.txt'
# [post] Will process 4490 sample points.
# [output] Output to be read-from/written-into folder 'chains/P22/PS', with prefix 'PSHz_22.post._post'
# [post] Running post-processing...
# [post]  |--------------------|   0%  (0/4490)
# [post]  |@-------------------|   5%  (203/4490)
# [post]  |@@------------------|  10%  (427/4490)
# [post]  |@@@-----------------|  15%  (652/4490)
# [post]  |@@@@----------------|  20%  (876/4490)
# [post]  |@@@@@---------------|  25%  (1101/4490)
# [post]  |@@@@@@--------------|  30%  (1325/4490)
# [post]  |@@@@@@@-------------|  35%  (1550/4490)
# [post]  |@@@@@@@@------------|  40%  (1774/4490)
# [post]  |@@@@@@@@@-----------|  45%  (1999/4490)
# [post]  |@@@@@@@@@@----------|  50%  (2223/4490)
# [post]  |@@@@@@@@@@@---------|  55%  (2448/4490)
# [post]  |@@@@@@@@@@@@--------|  60%  (2672/4490)
# [post]  |@@@@@@@@@@@@@-------|  65%  (2897/4490)
# [post]  |@@@@@@@@@@@@@@------|  70%  (3121/4490)
# [post]  |@@@@@@@@@@@@@@@-----|  75%  (3346/4490)
# [post]  |@@@@@@@@@@@@@@@@----|  80%  (3570/4490)
# [post]  |@@@@@@@@@@@@@@@@@---|  85%  (3795/4490)
# [post]  |@@@@@@@@@@@@@@@@@@--|  90%  (4019/4490)
# [post]  |@@@@@@@@@@@@@@@@@@@-|  95%  (4244/4490)
# [post]  |@@@@@@@@@@@@@@@@@@@@| 100%  (4468/4490)
# [post] Finished! Final number of distinct sample points: 4490
# [post] Importance weight range: 0.9999 -- 1
# [post] Effective number of single samples if independent (sum w)/max(w): 788
# [post] Effective number of weighted samples if independent (sum w)^2/sum(w^2): 1181
# Tempo de execução: 1142.1732113361359 s

# %% [markdown]
# #### CC+Pantheon+

# %%
par_mlHzPP_22 = par0_22

# %%
resultHzPP_22 = find_bestfit(getpar_PPHz_22, parnames_22, par_mlHzPP_22)
par_mlHzPP_22 = resultHzPP_22['x']
print('\n',par_mlHzPP_22,'\n')
print(resultHzPP_22,'\n')
# Out:
# /home/nirk20/jupyter_venv/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:596: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0
# /home/nirk20/jupyter_venv/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:596: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0
# /home/nirk20/jupyter_venv/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:596: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0
# /tmp/ipykernel_62392/314665809.py:40: RuntimeWarning: divide by zero encountered in log
#   dc = (((1 + b1*r2 + b2*r2**2)/(r2 - r1))*np.log(np.abs((z - r2)/(-r2))) - ((1 + b1*r1 + b2*r1**2)/(r2 - r1))*np.log(np.abs((z-r1)/(-r1))) + b2*z)/a2
# /home/nirk20/jupyter_venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# Maximum likelihood result:
# M  =  -33.59476148229231
# H0  =  67.64428198134729
# q0  =  -0.41537578494135435
# j0  =  0.44439904629035365
# s0  =  -0.1649078674182121
# chi2min = 1418.1417459143918
# tempo total: 546.664 seg
#
#  [-33.59476148  67.64428198  -0.41537578   0.44439905  -0.16490787]
#
#        message: Maximum number of iterations has been exceeded.
#        success: False
#         status: 2
#            fun: 1418.1417459143918
#              x: [-3.359e+01  6.764e+01 -4.154e-01  4.444e-01 -1.649e-01]
#            nit: 10000
#           nfev: 67949
#  final_simplex: (array([[-3.359e+01,  6.764e+01, ...,  4.444e-01,
#                         -1.649e-01],
#                        [-3.359e+01,  6.764e+01, ...,  4.444e-01,
#                         -1.649e-01],
#                        ...,
#                        [-3.359e+01,  6.764e+01, ...,  4.444e-01,
#                         -1.649e-01],
#                        [-3.359e+01,  6.764e+01, ...,  4.444e-01,
#                         -1.649e-01]], shape=(6, 5)), array([ 1.418e+03,  1.418e+03,  1.418e+03,  1.418e+03,
#                         1.418e+03,  1.418e+03]))

# %%
info_PPHz22 = {
    "likelihood": {
        "lnlikehz": lnprobPPHz_22
    },

    "params": {
        "M": {"prior": {"min": -19.5, "max": 19.5}, "proposal": par_mlHzPP_22[0], "latex": "M"},
        "h0": {"prior": {"min": 40.0, "max": 100.0}, "proposal": par_mlHzPP_22[1], "latex": r"H_{0}"},
        "q0": {"prior": {"min": -2, "max": 2}, "proposal": par_mlHzPP_22[2], "latex": r"q_{0}"},
        "j0": {"prior": {"min": -5, "max": 5}, "proposal": par_mlHzPP_22[3], "latex": r"j_{0}"},
        "s0": {"prior": {"min": -10, "max": 10}, "proposal": par_mlHzPP_22[4], "latex": r"s_{0}"}
    },

    "sampler": {
        "polychord": {
            "nlive": 200
        }
    },

    "output": "chains/P22/PP/PPHz_22"
}

info_post_PPHz22 = {
    "output": "chains/P22/PP/PPHz_22",
    "post": {
        "skip_samples": 0.3,
        "suffix": "_post"
    }
}

# %%
_, sampler_PPHz_22 = run_cobaya(info_PPHz22, info_post_PPHz22)
# Out:
# ----- INICIANDO SAMPLER -----
# [output] Output to be read-from/written-into folder 'chains/P22/PP', with prefix 'PPHz_22'
# [lnlikehz] Initialized external likelihood.
# [polychord] `pypolychord` module loaded successfully from /home/nirk20/jupyter_venv/lib/python3.12/site-packages/pypolychord
# [polychord] Storing raw PolyChord output in 'chains/P22/PP/PPHz_22_polychord_raw'.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {lnlikehz: 102.0}
# [polychord] Parameter blocks and their oversampling factors:
# [polychord] * 1 : ['M', 'h0', 'q0', 'j0', 's0']
# [polychord] Calling PolyChord...
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     200
# nDims    :       5
# nDerived :       2
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/P22/PP/PPHz_22_polychord_raw/PPHz_22.resume
#
# generating live points
#
#
# all live points generated
#
# number of repeats:           10
# started sampling
#
# _________________
# lives      | 200 |
# phantoms   |   9 |
# posteriors |1801 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1801
# nposterior =                1801
# nequals    =                   3
# nlike      =                2025
# <nlike>    =           0.12   (           0.01 per slice )
# log(Z)     =         -907.75 +/-  0.52
# log(Z_1)   =         -907.75 +/-  0.52 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1208 |
# posteriors |2002 |
# equals     |   3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2002
# nposterior =                2002
# nequals    =                   3
# nlike      =                7254
# <nlike>    =          26.14   (           2.61 per slice )
# log(Z)     =         -795.27 +/-  0.42
# log(Z_1)   =         -795.27 +/-  0.42 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1489 |
# posteriors |2203 |
# equals     |   8 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2203
# nposterior =                2203
# nequals    =                   8
# nlike      =               13176
# <nlike>    =          29.61   (           2.96 per slice )
# log(Z)     =         -758.81 +/-  0.29
# log(Z_1)   =         -758.81 +/-  0.29 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1645 |
# posteriors |2404 |
# equals     |  18 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2404
# nposterior =                2404
# nequals    =                  17
# nlike      =               19597
# <nlike>    =          32.11   (           3.21 per slice )
# log(Z)     =         -741.14 +/-  0.22
# log(Z_1)   =         -741.14 +/-  0.22 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1805 |
# posteriors |2605 |
# equals     |  29 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2605
# nposterior =                2605
# nequals    =                  28
# nlike      =               26161
# <nlike>    =          32.82   (           3.28 per slice )
# log(Z)     =         -731.10 +/-  0.19
# log(Z_1)   =         -731.10 +/-  0.19 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1609 |
# posteriors |2806 |
# equals     |  51 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2806
# nposterior =                2806
# nequals    =                  44
# nlike      =               32978
# <nlike>    =          34.09   (           3.41 per slice )
# log(Z)     =         -724.81 +/-  0.19
# log(Z_1)   =         -724.81 +/-  0.19 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1684 |
# posteriors |3007 |
# equals     | 112 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3007
# nposterior =                3007
# nequals    =                 107
# nlike      =               40108
# <nlike>    =          35.65   (           3.56 per slice )
# log(Z)     =         -722.09 +/-  0.18
# log(Z_1)   =         -722.09 +/-  0.18 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1708 |
# posteriors |3208 |
# equals     | 203 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3208
# nposterior =                3208
# nequals    =                 214
# nlike      =               47451
# <nlike>    =          36.72   (           3.67 per slice )
# log(Z)     =         -720.71 +/-  0.18
# log(Z_1)   =         -720.71 +/-  0.18 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1780 |
# posteriors |3409 |
# equals     | 380 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3409
# nposterior =                3409
# nequals    =                 393
# nlike      =               55065
# <nlike>    =          38.07   (           3.81 per slice )
# log(Z)     =         -720.04 +/-  0.18
# log(Z_1)   =         -720.04 +/-  0.18 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1877 |
# posteriors |3610 |
# equals     | 524 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3610
# nposterior =                3610
# nequals    =                 550
# nlike      =               62815
# <nlike>    =          38.75   (           3.88 per slice )
# log(Z)     =         -719.73 +/-  0.19
# log(Z_1)   =         -719.73 +/-  0.19 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1876 |
# posteriors |3811 |
# equals     | 594 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3811
# nposterior =                3811
# nequals    =                 624
# nlike      =               70764
# <nlike>    =          39.74   (           3.97 per slice )
# log(Z)     =         -719.58 +/-  0.19
# log(Z_1)   =         -719.58 +/-  0.19 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1795 |
# posteriors |4012 |
# equals     | 629 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4012
# nposterior =                4012
# nequals    =                 675
# nlike      =               78699
# <nlike>    =          39.68   (           3.97 per slice )
# log(Z)     =         -719.52 +/-  0.19
# log(Z_1)   =         -719.52 +/-  0.19 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1698 |
# posteriors |4213 |
# equals     | 640 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4213
# nposterior =                4213
# nequals    =                 705
# nlike      =               86535
# <nlike>    =          39.18   (           3.92 per slice )
# log(Z)     =         -719.49 +/-  0.19
# log(Z_1)   =         -719.49 +/-  0.19 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1714 |
# posteriors |4414 |
# equals     | 646 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4414
# nposterior =                4414
# nequals    =                 716
# nlike      =               94572
# <nlike>    =          40.19   (           4.02 per slice )
# log(Z)     =         -719.48 +/-  0.19
# log(Z_1)   =         -719.48 +/-  0.19 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |1706 |
# posteriors |4615 |
# equals     | 650 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4615
# nposterior =                4615
# nequals    =                 721
# nlike      =              102653
# <nlike>    =          40.41   (           4.04 per slice )
# log(Z)     =         -719.48 +/-  0.19
# log(Z_1)   =         -719.48 +/-  0.19 (still evaluating)
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =         5000                              |
# | log(Z) =         -719.47780 +/-            0.18931 |
# |____________________________________________________|
# [polychord] Loading PolyChord's results: samples and evidences.
# [polychord] Finished! Raw PolyChord output stored in 'chains/P22/PP/PPHz_22_polychord_raw', with prefix 'PPHz_22'
# [polychord] log(Z) = -719.86 +/- 0.189313 ; Z in [1.9337905e-313, 2.8238719e-313] (68% C.L. log-gaussian)
# ----- RETIRANDO O INICIO -----
# [output] Output to be read-from/written-into folder 'chains/P22/PP', with prefix 'PPHz_22'
# [output] Found existing info files with the requested output prefix: 'chains/P22/PP/PPHz_22'
# [samplecollection] Loaded 3688 sample points from 'chains/P22/PP/PPHz_22.1.txt'
# [post] Will process 3688 sample points.
# [output] Output to be read-from/written-into folder 'chains/P22/PP', with prefix 'PPHz_22.post._post'
# [post] Running post-processing...
# [post]  |--------------------|   0%  (0/3688)
# [post]  |@-------------------|   5%  (166/3688)
# [post]  |@@------------------|  10%  (351/3688)
# [post]  |@@@-----------------|  15%  (535/3688)
# [post]  |@@@@----------------|  20%  (720/3688)
# [post]  |@@@@@---------------|  25%  (904/3688)
# [post]  |@@@@@@--------------|  30%  (1088/3688)
# [post]  |@@@@@@@-------------|  35%  (1273/3688)
# [post]  |@@@@@@@@------------|  40%  (1457/3688)
# [post]  |@@@@@@@@@-----------|  45%  (1642/3688)
# [post]  |@@@@@@@@@@----------|  50%  (1826/3688)
# [post]  |@@@@@@@@@@@---------|  55%  (2010/3688)
# [post]  |@@@@@@@@@@@@--------|  60%  (2195/3688)
# [post]  |@@@@@@@@@@@@@-------|  65%  (2379/3688)
# [post]  |@@@@@@@@@@@@@@------|  70%  (2564/3688)
# [post]  |@@@@@@@@@@@@@@@-----|  75%  (2748/3688)
# [post]  |@@@@@@@@@@@@@@@@----|  80%  (2932/3688)
# [post]  |@@@@@@@@@@@@@@@@@---|  85%  (3117/3688)
# [post]  |@@@@@@@@@@@@@@@@@@--|  90%  (3301/3688)
# [post]  |@@@@@@@@@@@@@@@@@@@-|  95%  (3486/3688)
# [post]  |@@@@@@@@@@@@@@@@@@@@| 100%  (3670/3688)
# [post] Finished! Final number of distinct sample points: 3688
# [post] Importance weight range: 0.9999 -- 1
# [post] Effective number of single samples if independent (sum w)/max(w): 688
# [post] Effective number of weighted samples if independent (sum w)^2/sum(w^2): 1019
# Tempo de execução: 889.9150159358978 s

# %% [markdown]
# ### P31

# %% [markdown]
# #### CC+SH0ES+Pantheon+

# %%
par_mlHzPS_31 = par0_22

# %%
t1 = time.time()
resultHzPS_31 = find_bestfit(getpar_PSHz_31, parnames_22, par_mlHzPS_31)
par_mlHzPS_31 = resultHzPS_31['x']
print('\n',par_mlHzPS_31,'\n')
print(resultHzPS_31,'\n')
print(time.time() - t1)
# Out:
# Maximum likelihood result:
# M  =  -19.236942368729153
# H0  =  73.12112341306496
# q0  =  -0.29715957445560826
# j0  =  0.1908346442240359
# s0  =  1.8359950015025153
# chi2min = 1508.4077857687603
# tempo total: 638.354 seg
#
#  [-19.23694237  73.12112341  -0.29715957   0.19083464   1.835995  ]
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1508.4077857687603
#              x: [-1.924e+01  7.312e+01 -2.972e-01  1.908e-01  1.836e+00]
#            nit: 276
#           nfev: 457
#  final_simplex: (array([[-1.924e+01,  7.312e+01, ...,  1.908e-01,
#                          1.836e+00],
#                        [-1.924e+01,  7.312e+01, ...,  1.909e-01,
#                          1.836e+00],
#                        ...,
#                        [-1.924e+01,  7.312e+01, ...,  1.908e-01,
#                          1.836e+00],
#                        [-1.924e+01,  7.312e+01, ...,  1.908e-01,
#                          1.836e+00]], shape=(6, 5)), array([ 1.508e+03,  1.508e+03,  1.508e+03,  1.508e+03,
#                         1.508e+03,  1.508e+03]))
#
# 638.3550209999084

# %%
info_PSHz31 = {
    "likelihood": {
        "lnlikehz": lnprobPSHz_31
    },

    "params": {
        "M": {"prior": {"min": -19.5, "max": 19.5}, "proposal": par_mlHzPS_31[0], "latex": "M"},
        "h0": {"prior": {"min": 40.0, "max": 100.0}, "proposal": par_mlHzPS_31[1], "latex": r"H_{0}"},
        "q0": {"prior": {"min": -2, "max": 2}, "proposal": par_mlHzPS_31[2], "latex": r"q_{0}"},
        "j0": {"prior": {"min": -5, "max": 5}, "proposal": par_mlHzPS_31[3], "latex": r"j_{0}"},
        "s0": {"prior": {"min": -10, "max": 10}, "proposal": par_mlHzPS_31[4], "latex": r"s_{0}"}
    },

    "sampler": {
        "polychord": {
            "nlive": 100
        }
    },

    "output": "chains/P31/PSHz_31"
}

info_post_PSHz31 = {
    "output": "chains/P31/PSHz_31",
    "post": {
        "skip_samples": 0.3,
        "suffix": "_post"
    }
}

# %%
_, sampler_PSHz_31 = run_cobaya(info_PSHz31, info_post_PSHz31)
# Out:
# ----- INICIANDO SAMPLER -----
# [output] Output to be read-from/written-into folder 'chains/P31', with prefix 'PSHz_31'
# [lnlikehz] Initialized external likelihood.
# [polychord] `pypolychord` module loaded successfully from /home/nirk20/jupyter_venv/lib/python3.12/site-packages/pypolychord
# [polychord] Storing raw PolyChord output in 'chains/P31/PSHz_31_polychord_raw'.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {lnlikehz: 3.62}
# [polychord] Parameter blocks and their oversampling factors:
# [polychord] * 1 : ['M', 'h0', 'q0', 'j0', 's0']
# [polychord] Calling PolyChord...
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     100
# nDims    :       5
# nDerived :       2
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/P31/PSHz_31_polychord_raw/PSHz_31.resume
#
# generating live points
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# all live points generated
#
# number of repeats:           10
# started sampling
#
# ________________
# lives      |100 |
# phantoms   |  9 |
# posteriors |901 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 901
# nposterior =                 901
# nequals    =                   1
# nlike      =                1012
# <nlike>    =           0.12   (           0.01 per slice )
# log(Z)     =      -596747.69 +/-  0.83
# log(Z_1)   =      -596747.69 +/-  0.83 (still evaluating)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# _________________
# lives      | 100 |
# phantoms   | 576 |
# posteriors |1002 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1002
# nposterior =                1002
# nequals    =                   1
# nlike      =                3099
# <nlike>    =          20.87   (           2.09 per slice )
# log(Z)     =       -73743.09 +/-  0.84
# log(Z_1)   =       -73743.09 +/-  0.84 (still evaluating)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:33: RuntimeWarning: divide by zero encountered in scalar divide
#   ez = lambda z2, theta: 1/EzP31(z2, theta)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# ...
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# /tmp/ipykernel_7972/72551824.py:41: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 _, sampler_PSHz_31 = run_cobaya(info_PSHz31, info_post_PSHz31)
#
# Cell In[13], line 25, in run_cobaya(info, info_post)
#      22 t1 = time.time()
#      24 # Roda o sampler
# ---> 25 updated_info, sampler = run(info)
#      27 # Retira o início
#      28 print("----- RETIRANDO O INICIO -----")
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/run.py:146, in run(info_or_yaml_or_file, packages_path, output, debug, stop_at_error, resume, force, minimize, no_mpi, test, override, allow_changes)
#     144                 return updated_info, sampler
#     145             # Run the sampler
# --> 146             sampler.run()
#     147 return updated_info, sampler
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/samplers/polychord/polychord.py:266, in polychord.run(self)
#     264 sync_processes()
#     265 self.mpi_info("Calling PolyChord...")
# --> 266 self.pc.run_polychord(logpost, self.nDims, self.nDerived, self.pc_settings,
#     267                       self.pc_prior, self.dumper)
#     268 self.process_raw_output()
#
# File ~/jupyter_venv/lib/python3.12/site-packages/pypolychord/polychord.py:177, in run_polychord(loglikelihood, nDims, nDerived, settings, prior, dumper)
#     174 settings.nlives = {float(logL):int(nlive) for logL, nlive in settings.nlives.items()}
#     176 # Run polychord from module library
# --> 177 _pypolychord.run(wrap_loglikelihood,
#     178                  wrap_prior,
#     179                  dumper,
#     180                  nDims,
#     181                  nDerived,
#     182                  settings.nlive,
#     183                  settings.num_repeats,
#     184                  settings.nprior,
#     185                  settings.nfail,
#     186                  settings.do_clustering,
#     187                  settings.feedback,
#     188                  settings.precision_criterion,
#     189                  settings.logzero,
#     190                  settings.max_ndead,
#     191                  settings.boost_posterior,
#     192                  settings.posteriors,
#     193                  settings.equals,
#     194                  settings.cluster_posteriors,
#     195                  settings.write_resume,
#     196                  settings.write_paramnames,
#     197                  settings.read_resume,
#     198                  settings.write_stats,
#     199                  settings.write_live,
#     200                  settings.write_dead,
#     201                  settings.write_prior,
#     202                  settings.maximise,
#     203                  settings.compression_factor,
#     204                  settings.synchronous,
#     205                  settings.base_dir,
#     206                  settings.file_root,
#     207                  settings.grade_frac,
#     208                  settings.grade_dims,
#     209                  settings.nlives,
#     210                  settings.seed)
#     212 if settings.cube_samples is not None:
#     213     settings.read_resume = read_resume
#
# File ~/jupyter_venv/lib/python3.12/site-packages/pypolychord/polychord.py:163, in run_polychord.<locals>.wrap_loglikelihood(theta, phi)
#     162 def wrap_loglikelihood(theta, phi):
# --> 163     logL = loglikelihood(theta)
#     164     try:
#     165         logL, phi[:] = logL
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/samplers/polychord/polychord.py:253, in polychord.run.<locals>.logpost(params_values)
#     252 def logpost(params_values):
# --> 253     result = self.model.logposterior(params_values)
#     254     loglikes = result.loglikes
#     255     if len(loglikes) != self.n_likes:
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/model.py:558, in Model.logposterior(self, params_values, as_dict, make_finite, return_derived, cached, _no_check)
#     555         logpriors.extend(self.prior.logps_external(input_params))
#     556 if -np.inf not in logpriors:
#     557     # noinspection PyUnboundLocalVariable
# --> 558     like = self._loglikes_input_params(input_params,
#     559                                        return_derived=return_derived,
#     560                                        cached=cached, make_finite=make_finite)
#     561     loglikes, derived_sampler = like if return_derived else (like, [])
#     562 else:
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/model.py:378, in Model._loglikes_input_params(self, input_params, return_derived, return_output_params, as_dict, make_finite, cached)
#     376 depend_list = [input_params[p] for p in param_dep]
#     377 params = {p: input_params[p] for p in component.input_params}
# --> 378 compute_success = component.check_cache_and_compute(
#     379     params, want_derived=need_derived,
#     380     dependency_params=depend_list, cached=cached)
#     381 if not compute_success:
#     382     loglikes[:] = -np.inf
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/theory.py:253, in Theory.check_cache_and_compute(self, params_values_dict, dependency_params, want_derived, cached)
#     251     self.timer.start()
#     252 try:
# --> 253     if self.calculate(state, want_derived, **params_values_dict) is False:
#     254         return False
#     255 except always_stop_exceptions:
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/likelihood.py:128, in Likelihood.calculate(self, state, want_derived, **params_values_dict)
#     126 derived: Optional[ParamValuesDict] = {} if want_derived else None
#     127 state["logp"] = -np.inf  # in case of exception
# --> 128 state["logp"] = self.logp(_derived=derived, **params_values_dict)
#     129 self.log.debug("Computed log-likelihood = %s", state["logp"])
#     130 if derived is not None:
#
# File ~/jupyter_venv/lib/python3.12/site-packages/cobaya/likelihood.py:214, in LikelihoodExternalFunction.logp(self, **params_values)
#     212     params_values[self._self_arg] = self
#     213 try:
# --> 214     return_value = self.external_function(**params_values)
#     215 except Exception:
#     216     self.log.debug("External function failed at evaluation.")
#
# Cell In[12], line 65, in lnprobPSHz_31(M, h0, q0, j0, s0)
#      63 def lnprobPSHz_31(M, h0, q0, j0, s0):
#      64     theta = [M, h0, q0, j0, s0]
# ---> 65     return lnlikePS_31(theta)+lnlikeHz_31(theta)
#
# Cell In[12], line 55, in lnlikePS_31(theta)
#      54 def lnlikePS_31(theta):
# ---> 55     return -0.5*chi2PS_31(theta)
#
# Cell In[12], line 15, in chi2PS_31(theta)
#      12 if np.any(Ez2i <= 0):
#      13     return np.inf
# ---> 15 dAt = daModelP31(zt,theta)
#      16 NegDist = False
#      17 mmod = extract_theory_points(zt, dAt, theta, SH0ES=True)
#
# Cell In[34], line 66, in daModelP31(z, theta)
#      65 def daModelP31(z,theta):
# ---> 66     return dmModelP31(z,theta)/(1+z)
#
# Cell In[34], line 54, in dmModelP31(z, theta)
#      52 dH = c/H0
#      53 wk = 0
# ---> 54 Dcm = DcModelP31(z, theta)
#      55 if wk < 0:
#      56     return dH*np.sin(np.sqrt(-wk)*Dcm)/np.sqrt(-wk)
#
# Cell In[34], line 41, in DcModelP31(z, theta)
#      39         return -np.inf
#      40 else:
# ---> 41     dc_aux, _ = quad(ez, z[i-1], z[i], args=(theta), epsabs=1e-05, epsrel=1e-05)
#      42     dc[i] = dc_aux + dc[i-1]
#      43     if not np.isfinite(dc[i]):
#
# File ~/jupyter_venv/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:459, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     456     return retval
#     458 if weight is None:
# --> 459     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     460                    points)
#     461 else:
#     462     if points is not None:
#
# File ~/jupyter_venv/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:606, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     604 if points is None:
#     605     if infbounds == 0:
# --> 606         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     607     else:
#     608         return _quadpack._qagie(func, bound, infbounds, args, full_output,
#     609                                 epsabs, epsrel, limit)
#
# Cell In[34], line 33, in DcModelP31.<locals>.<lambda>(z2, theta)
#      27 a3 = -0.0417*(H0*(72*j0 + 60*j0**2 + 12*j0**3 + 180*j0*q0 + 30*j0**2*q0 - 72*q0**2 + 30*j0*q0**2 -
#      28                   23*j0**2*q0**2 - 180*q0**3 - 30*j0*q0**3 - 90*q0**4 + 24*j0*q0**4 - 9*q0**6 - 15*j0*s0 + 11*j0*q0*s0 +
#      29                   15*q0**2*s0 - 3*q0**3*s0 + 4*s0**2))/(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0) #0.041666666666666664
#      31 b1 = (-24 - 8*j0 - 4*j0**2 - 60*q0 + 22*j0*q0 - 42*q0**2 + 25*j0*q0**2 - 24*q0**3 - 15*q0**4 + 13*s0 + 7*q0*s0)/(4.*(3*j0 + 4*j0*q0 - 3*q0**2 - 3*q0**3 + s0))
# ---> 33 ez = lambda z2, theta: 1/EzP31(z2, theta)
#      35 for i in range(len(z)):
#      36     if i == 0:
#
# KeyboardInterrupt:

# %% [markdown]
# #### CC+Pantheon+

# %%
par_mlHzPP_31 = par0_22

# %%
resultHzPP_31 = find_bestfit(getpar_PPHz_31, parnames_22, par_mlHzPP_31)
par_mlHzPP_31 = resultHzPP_31['x']
print('\n',par_mlHzPP_31,'\n')
print(resultHzPP_31,'\n')

# %%
info_PPHz31 = {
    "likelihood": {
        "lnlikehz": lnprobPPHz_31
    },

    "params": {
        "M": {"prior": {"min": -19.5, "max": 19.5}, "proposal": par_mlHzPP_31[0], "latex": "M"},
        "h0": {"prior": {"min": 40.0, "max": 100.0}, "proposal": par_mlHzPP_31[1], "latex": r"H_{0}"},
        "q0": {"prior": {"min": -2, "max": 2}, "proposal": par_mlHzPP_31[2], "latex": r"q_{0}"},
        "j0": {"prior": {"min": -5, "max": 5}, "proposal": par_mlHzPP_31[3], "latex": r"j_{0}"},
        "s0": {"prior": {"min": -10, "max": 10}, "proposal": par_mlHzPP_31[4], "latex": r"s_{0}"}
    },

    "sampler": {
        "polychord": {
            "nlive": 100
        }
    },

    "output": "chains/P31/PPHz_31"
}

info_post_PPHz31 = {
    "output": "chains/P31/PPHz_31",
    "post": {
        "skip_samples": 0.3,
        "suffix": "_post"
    }
}

# %%
_, sampler_PPHz_31 = run_cobaya(info_PPHz31, info_post_PPHz31)
